# %%
# !pip install moviepy

# %%
from moviepy.editor import VideoFileClip

# Define input and output file paths
video_path = r"C:\Users\sjs93\Downloads\subj11_cagemateface_sniff.mp4"
output_gif_path = r"C:\Users\sjs93\Downloads\subj11_cagemateface_sniff.gif"

# Load and convert video to GIF
clip = VideoFileClip(video_path)
clip.write_gif(output_gif_path, fps=10)  

print(f"GIF saved at: {output_gif_path}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from moviepy.editor import VideoFileClip
#       3 # Define input and output file paths
#       4 video_path = r"C:\Users\sjs93\Downloads\subj11_cagemateface_sniff.mp4"
#
# ModuleNotFoundError: No module named 'moviepy.editor'

# %%
import moviepy
print(moviepy.__version__)  # This should print the installed version
# Out:
# 2.1.1

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\sjs93\anaconda3\envs\resp_env\python.exe

# %%
import moviepy
print(moviepy.__file__)
# Out:
# c:\Users\sjs93\anaconda3\envs\resp_env\lib\site-packages\moviepy\__init__.py

# %%
import moviepy.editor
print("MoviePy editor module is accessible!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import moviepy.editor
#       2 print("MoviePy editor module is accessible!")
#
# ModuleNotFoundError: No module named 'moviepy.editor'

# %%
from moviepy.editor import VideoFileClip

# Define input and output file paths
video_path = r"C:\Users\sjs93\Downloads\subj11_cagemateface_sniff.mp4"
output_gif_path = r"C:\Users\sjs93\Downloads\subj11_cagemateface_sniff.gif"

# Load the video file
clip = VideoFileClip(video_path)

# Convert video to GIF (you can adjust fps for a smaller file size)
clip.write_gif(output_gif_path, fps=10)  # Adjust FPS to control GIF smoothness and size

print(f"GIF saved at: {output_gif_path}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from moviepy.editor import VideoFileClip
#       3 # Define input and output file paths
#       4 video_path = r"C:\Users\sjs93\Downloads\subj11_cagemateface_sniff.mp4"
#
# ModuleNotFoundError: No module named 'moviepy.editor'
