# %%
import pandas as pd
import numpy as np
import re
import os
import warnings
from collections import defaultdict
import pathlib
import subprocess
import glob
import h5py
import spikeinterface.preprocessing as sp
import spikeinterface.extractors as se
import analog_trodes_h5 as ath5

# %%
import importlib
importlib.reload(ath5)
# Out:
# <module 'analog_trodes_h5' from 'c:\\Users\\thoma\\Code\\ResearchCode\\respiratory_pilot\\src\\file_conversion\\analog_trodes_h5.py'>

# %%
datapath = r"C:\Users\thoma\Code\ResearchCode\spike_to_h5\ekg_resp_data"

# %% [markdown]
# #### Testing find_merged_rec_files

# %% [markdown]
# ### Passed

# %%
print(ath5.find_merged_rec_files(datapath))
# Out:
# ['C:\\Users\\thoma\\Code\\ResearchCode\\spike_to_h5\\ekg_resp_data\\subj_5_13_baseline_d13_20250526_143515.rec\\subj_5_13_baseline_d13_20250526_143515_merged.rec', 'C:\\Users\\thoma\\Code\\ResearchCode\\spike_to_h5\\ekg_resp_data\\sub_5_13_baseline_20250523_105046.rec\\sub_5_13_baseline_20250523_105046_merged.rec', 'C:\\Users\\thoma\\Code\\ResearchCode\\spike_to_h5\\ekg_resp_data\\sub_5_13_juvenile_20250523_110554.rec\\sub_5_13_juvenile_20250523_110554_merged.rec']

# %% [markdown]
# #### Testing organize_all_trodes_export and organize_single_trodes_export (part of organize_all)

# %% [markdown]
# ### Passed

# %%
rec_path = r'C:\Users\thoma\Code\ResearchCode\respiratory_pilot\src\file_conversion\ekg_resp_data\subj_5_13_baseline_d13_20250526_143515.rec'
print(ath5.organize_all_trodes_export(rec_path))
# Out:
# defaultdict(<class 'dict'>, {'subj_5_13_baseline_d13_20250526_143515.rec': {'analog': {'analog_Controller_Ain1': {'description': 'One analog IO channel. Continuous sampling.', 'byte_order': 'little endian', 'original_file': 'subj_5_13_baseline_d13_20250526_143515_merged.rec', 'clockrate': '20000', 'trodes_version': '2.6.0', 'compile_date': 'Mar 21 2025', 'compile_time': '12:58:48', 'qt_version': '6.7.2', 'commit_tag': 'heads/Release_2.6.0-0-gd2e4343c', 'controller_firmware': '2.0', 'headstage_firmware': '1.0', 'controller_serialnum': '01703 00102', 'headstage_serialnum': '03101 00108', 'autosettle': '0', 'smartref': '0', 'gyro': '1', 'accelerometer': '1', 'magnetometer': '0', 'time_offset': '0', 'system_time_at_creation': '1748284596470', 'timestamp_at_creation': '1729935', 'first_timestamp': '8624463', 'direction': 'input', 'id': 'Controller_Ain1', 'display_order': '20', 'fields': '<voltage int16>', 'data': array([([  0],), ([  0],), ([  0],), ..., ([262],), ([262],), ([262],)],
# ...

# %%
merged_rec_path = r'C:\Users\thoma\Code\ResearchCode\respiratory_pilot\src\file_conversion\ekg_resp_data\subj_5_13_baseline_d13_20250526_143515.rec\subj_5_13_baseline_d13_20250526_143515_merged.rec'

'''
ekg, resp = ath5.get_data_from_rec_file(merged_rec_path)

# plot ekg and resp
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(ekg, label='EKG')
plt.title('EKG Signal')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.legend()
plt.subplot(2, 1, 2)
plt.plot(resp, label='Respiration', color='orange')
plt.title('Respiration Signal')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.legend()
plt.tight_layout()
plt.show()

'''
# Out:
# "\nekg, resp = ath5.get_data_from_rec_file(merged_rec_path)\n\n# plot ekg and resp\nimport matplotlib.pyplot as plt\nplt.figure(figsize=(12, 6))\nplt.subplot(2, 1, 1)\nplt.plot(ekg, label='EKG')\nplt.title('EKG Signal')\nplt.xlabel('Sample Index')\nplt.ylabel('Amplitude')\nplt.legend()\nplt.subplot(2, 1, 2)\nplt.plot(resp, label='Respiration', color='orange')\nplt.title('Respiration Signal')\nplt.xlabel('Sample Index')\nplt.ylabel('Amplitude')\nplt.legend()\nplt.tight_layout()\nplt.show()\n\n"

# %% [markdown]
# #### Testing get data from rec shows it is able to get data but trodes extraction is not working

# %%
other_merged_rec_path = r'C:\Users\thoma\Code\ResearchCode\respiratory_pilot\src\file_conversion\ekg_resp_data\sub_5_13_juvenile_20250523_110554.rec\sub_5_13_juvenile_20250523_110554_merged.rec'

'''
ekg2, resp2 = ath5.get_data_from_rec_file(other_merged_rec_path)


# plot ekg and resp from the other file
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(ekg2, label='EKG')
plt.title('EKG Signal from Other File')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.legend()
plt.subplot(2, 1, 2)
plt.plot(resp2, label='Respiration', color='orange')
plt.title('Respiration Signal from Other File')
plt.xlabel('Sample Index')
plt.ylabel('Amplitude')
plt.legend()
plt.tight_layout()
plt.show()
'''
# Out:
# "\nekg2, resp2 = ath5.get_data_from_rec_file(other_merged_rec_path)\n\n\n# plot ekg and resp from the other file\nplt.figure(figsize=(12, 6))\nplt.subplot(2, 1, 1)\nplt.plot(ekg2, label='EKG')\nplt.title('EKG Signal from Other File')\nplt.xlabel('Sample Index')\nplt.ylabel('Amplitude')\nplt.legend()\nplt.subplot(2, 1, 2)\nplt.plot(resp2, label='Respiration', color='orange')\nplt.title('Respiration Signal from Other File')\nplt.xlabel('Sample Index')\nplt.ylabel('Amplitude')\nplt.legend()\nplt.tight_layout()\nplt.show()\n"

# %% [markdown]
# ### Testing trodes_extract

# %%
trodes_exe_path = r"C:\Users\thoma\Desktop\Trodes_2-6-0_Windows11\Trodes_2-6-0_Windows11"
datapath = r"C:\Users\thoma\Code\ResearchCode\spike_to_h5\ekg_resp_data"


# Loop through each .rec folder in the data directory and use trodes_extract to extract data
ath5.trodes_extract(trodes_exe_path, datapath, mode="-raw -analogio -time")
# Out:
# [INFO] Starting Trodes extraction with mode(s): -raw -analogio -time
# [INFO] Trodes directory: C:\Users\thoma\Desktop\Trodes_2-6-0_Windows11\Trodes_2-6-0_Windows11
# [INFO] Data folder: C:\Users\thoma\Code\ResearchCode\spike_to_h5\ekg_resp_data
# [INFO] Found 3 subdirectories to search for .rec files.
#
# [INFO] Checking folder: C:\Users\thoma\Code\ResearchCode\spike_to_h5\ekg_resp_data\subj_5_13_baseline_d13_20250526_143515.rec
# [INFO] Found 1 merged.rec file(s).
# [DEBUG] Prepared command: trodesexport -raw -analogio -time -rec "C:\Users\thoma\Code\ResearchCode\spike_to_h5\ekg_resp_data\subj_5_13_baseline_d13_20250526_143515.rec\subj_5_13_baseline_d13_20250526_143515_merged.rec" -outputdirectory "C:\Users\thoma\Code\ResearchCode\spike_to_h5\ekg_resp_data\subj_5_13_baseline_d13_20250526_143515.rec"
#
# [INFO] Checking folder: C:\Users\thoma\Code\ResearchCode\spike_to_h5\ekg_resp_data\sub_5_13_baseline_20250523_105046.rec
# [INFO] Found 1 merged.rec file(s).
# ...
