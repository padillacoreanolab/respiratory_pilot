# %%
import sys
import os
import glob
import subprocess

# %%
def convert_h264_trodes(input_folder, vid_type = None):
    """
    This assumes all videos are in .rec folders (typical trodes output folder structure).
    Converts videos to be used for sleap tracking without issues 
    i.e. an mp4 with some other specifications of this command -c:v libx264 -pix_fmt yuv420p -preset superfast -crf 23
    saves all videos with original name plus _converted at the end and saved in their original .rec folder. 

    Args (1 required, 2 total)
        input_folder: str, where your videos exist
        vid_type: str, optional, {'.mp4' or '.h264', whatever the original video type is}
            if not specified, .h264 files are assumed
    """
    if vid_type is None:
        vid_type = '.h264'
    rec_folders = glob.glob(os.path.join(input_folder, r'*.rec'))
    commands = []
    for rec_folder in rec_folders:
        videos = glob.glob(os.path.join(rec_folder, f'*{vid_type}'))
        for video in videos:
            video = os.path.normpath(video.strip())  # Clean path
            video = r'\\?\\' + os.path.abspath(video)
            video_dir, video_name = os.path.split(video)
            new_name = os.path.join(video_dir, video_name.replace(vid_type, '_converted.mp4'))
            if not os.path.exists(new_name):
                command = f'ffmpeg -y -i "{video}" -c:v libx264 -pix_fmt yuv420p -preset superfast -crf 23 "{new_name}"'
                commands.append(command)

    i = 0
    for command in commands:
       subprocess.run(command, shell=True, check=True) #Popen(command, shell=True).wait()
       i +=1
       print(i, 'out of', len(commands), 'videos converted')

    print(commands[0])


convert_h264_trodes(r'E:\sprite32')

#convert_h264_trodes('D:\social_mem_ephys_pilot2\habit_dishabit\data')
# Out:
# Video: '\\\\?\\\\E:\\sprite32\\subj_5_13_baseline_d13_20250526_143515.rec\\subj_5_13_baseline_d13_20250526_143515.1.h264'
# Exists? True
# Dir: '\\\\?\\\\E:\\sprite32\\subj_5_13_baseline_d13_20250526_143515.rec', Exists? True
# Files in dir: ['logger_raw.dat', 'subj_5_13_baseline_d13_20250526_143515.1.h264', 'subj_5_13_baseline_d13_20250526_143515.1.trackgeometry', 'subj_5_13_baseline_d13_20250526_143515.1.videoTimeStamps', 'subj_5_13_baseline_d13_20250526_143515.1.videoTimeStamps.cameraHWSync', 'subj_5_13_baseline_d13_20250526_143515.rec', 'subj_5_13_baseline_d13_20250526_143515_merged.analog', 'subj_5_13_baseline_d13_20250526_143515_merged.rec', 'subj_5_13_baseline_d13_20250526_143515_merged.time', 'subj_5_13_baseline_d13_20250526_143515_merged.timestampoffset', 'subj_5_13_baseline_d13_20250526_143515_merged.trodesconf']
#
# Video: '\\\\?\\\\E:\\sprite32\\sub_5_13_baseline_20250523_105046.rec\\sub_5_13_baseline_20250523_105046.1.h264'
# Exists? True
# Dir: '\\\\?\\\\E:\\sprite32\\sub_5_13_baseline_20250523_105046.rec', Exists? True
# Files in dir: ['logger_raw.dat', 'sub_5_13_baseline_20250523_105046.1.h264', 'sub_5_13_baseline_20250523_105046.1.trackgeometry', 'sub_5_13_baseline_20250523_105046.1.videoTimeStamps', 'sub_5_13_baseline_20250523_105046.1.videoTimeStamps.cameraHWSync', 'sub_5_13_baseline_20250523_105046.rec', 'sub_5_13_baseline_20250523_105046_merged.rec', 'sub_5_13_baseline_20250523_105046_merged.trodesconf']
#
# Video: '\\\\?\\\\E:\\sprite32\\sub_5_13_juvenile_20250523_110554.rec\\sub_5_13_juvenile_20250523_110554.1.h264'
# Exists? True
# Dir: '\\\\?\\\\E:\\sprite32\\sub_5_13_juvenile_20250523_110554.rec', Exists? True
# Files in dir: ['logger_raw.dat', 'sub_5_13_juvenile_20250523_110554.1.h264', 'sub_5_13_juvenile_20250523_110554.1.trackgeometry', 'sub_5_13_juvenile_20250523_110554.1.videoTimeStamps', 'sub_5_13_juvenile_20250523_110554.1.videoTimeStamps.cameraHWSync', 'sub_5_13_juvenile_20250523_110554.rec', 'sub_5_13_juvenile_20250523_110554_merged.rec', 'sub_5_13_juvenile_20250523_110554_merged.trodesconf']
# 1 out of 3 videos converted
# 2 out of 3 videos converted
# 3 out of 3 videos converted
# ffmpeg -y -i "\\?\\E:\sprite32\subj_5_13_baseline_d13_20250526_143515.rec\subj_5_13_baseline_d13_20250526_143515.1.h264" -c:v libx264 -pix_fmt yuv420p -preset superfast -crf 23 "\\?\\E:\sprite32\subj_5_13_baseline_d13_20250526_143515.rec\subj_5_13_baseline_d13_20250526_143515.1_converted.mp4"
