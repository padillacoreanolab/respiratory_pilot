# %%
import pandas as pd

df = pd.read_excel("C:/Users/sjs93/OneDrive - University of Florida/rehouse_6_video_mappings.xlsx")
df.to_json("C:/Users/sjs93/OneDrive - University of Florida/rehouse_6_video_mappings.json", orient="records", indent=2)
