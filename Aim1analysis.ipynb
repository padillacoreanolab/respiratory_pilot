# %% [markdown]
# libaraies

# %%
import os
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt, resample_poly
import neurokit2 as nk
from scipy.signal import find_peaks
import seaborn as sns


# Pandas display settings (optional)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 0)

# %% [markdown]
# load files

# %%
# RESP FILE PATHS
RI1_3_6_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5"
RI2_3_6_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5"
BLRI_s3_6_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\BLRI_s3_6_p5_3_nRB3_20250621_123634_merged.h5"
BLRI_s4_7_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\BLRI_s4_7_p5_2_nRB3_20250621_144806_merged.h5"
RI1_4_7_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5"
RI2_4_7_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5"
RI1_2_3_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s2_3_p5_3_nRB3_20250622_104059_merged (1).h5"
RI2_2_3_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5"
RI1_4_8_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5"
RI2_4_8_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5"
RI1_1_1_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5"
RI2_1_1_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5"
RI1_1_2_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5"
RI2_1_2_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5"
RI1_2_4_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5"
RI2_2_4_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5"
RI2_3_5_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5"
RI1_3_5_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5"


# BORIS CSVs (no comma at the end or it makes a tuple)
RI1_3_6_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s3_6_p5_3_nRB3_HEEPS.csv")
RI2_3_6_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s3_6_p_5_3_nRB3_2025062.csv")
RI1_4_7_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s4_7_p5_2_nRB3_HEEPS.csv")
RI2_4_7_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s4_7_p5_2_nRB3_HEEPS.csv")
RI1_2_3_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s2_3_p5_3_nRB3_20250622_104059.1.csv")
RI2_2_3_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s2_3_p5_3_nRB3_20250622_1102116.1.csv")
RI1_4_8_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s4_8_p5_1_nRB3_HEEPS.csv")
RI2_4_8_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s4_8_p5_1_nRB3_20250621_HEEPS.csv")
RI1_1_1_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s1_1_p5_2_nRB6_20250622_143958.1.csv")
RI2_1_1_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s1_1_p5_2_nRB6_20250622_150457.1.csv")
RI1_1_2_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s1_2_p5_1_nRB6_20250622_170742.1.csv")
RI2_1_2_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s1_2_p5_1_nRB6_20250622_173049.1.csv")
RI1_2_4_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s2_4_p5_4_nRB3_20250622_123424.1.csv")
RI2_2_4_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s2_4_p5_4_nRB3_20250622_125648.1.csv")
RI2_3_5_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s3_5_p5_4_nRB3_20250621.csv")

# %%
ri1_h5_paths = {
    "RI1_3_6": RI1_3_6_h5_path,
    "RI1_4_7": RI1_4_7_h5_path,  
    "RI1_2_3": RI1_2_3_h5_path,
    "RI1_4_8": RI1_4_8_h5_path,
    "RI1_1_1": RI1_1_1_h5_path,
    "RI1_1_2": RI1_1_2_h5_path,
    "RI1_2_4": RI1_2_4_h5_path,
    "RI1_3_5": RI1_3_5_h5_path,
}

# %%
ri2_h5_paths = {
    "RI2_3_6": RI2_3_6_h5_path,
    "RI2_4_7": RI2_4_7_h5_path,
    "RI2_2_3": RI2_2_3_h5_path,
    "RI2_4_8": RI2_4_8_h5_path,
    "RI2_1_1": RI2_1_1_h5_path,
    "RI2_1_2": RI2_1_2_h5_path,
    "RI2_2_4": RI2_2_4_h5_path,
    "RI2_3_5": RI2_3_5_h5_path,
}

# %%
ri1_boris_data = {
    "RI1_3_6": RI1_3_6_boris.copy(),
    "RI1_4_7": RI1_4_7_boris.copy(),
    "RI1_2_3": RI1_2_3_boris.copy(),
    "RI1_4_8": RI1_4_8_boris.copy(),
    "RI1_1_1": RI1_1_1_boris.copy(),
    "RI1_1_2": RI1_1_2_boris.copy(),
    "RI1_2_4": RI1_2_4_boris.copy(),
}

# %%
ri2_boris_data = {
    "RI2_3_6": RI2_3_6_boris.copy(),
    "RI2_4_7": RI2_4_7_boris.copy(),
    "RI2_2_3": RI2_2_3_boris.copy(),
    "RI2_4_8": RI2_4_8_boris.copy(),
    "RI2_1_1": RI2_1_1_boris.copy(),
    "RI2_1_2": RI2_1_2_boris.copy(),
    "RI2_2_4": RI2_2_4_boris.copy(),
    "RI2_3_5": RI2_3_5_boris.copy(),
}

# %% [markdown]
# load_clean_resp_signal function for loading and preprocessing respiration data:
#
# Reads raw resp signal and metadata from .h5
#
# Computes original sampling rate (fs)
#
# Applies a low-pass filter before downsampling to avoid aliasing
#
# Downsamples the signal to your target_rate (default 100 Hz)
#
# Applies a bandpass filter (0.1–20 Hz) with NeuroKit to clean the signal further
#
# Creates a time vector that matches the cleaned signal length and sampling rate
#
# This function returns:
# rsp_cleaned: the cleaned, filtered, downsampled respiratory signal array
#
# time_vector: time points corresponding to each sample in seconds
#
# target_rate: the sampling rate after downsampling (e.g., 100 Hz)
#
# You can then pass these outputs to functions like:
# get_percent_change_resp_rate(signal=rsp_cleaned, times=time_vector, sniff_start, sniff_end)
#
# get_delta_resp_rate(signal=rsp_cleaned, times=time_vector, sniff_end)

# %%
def load_clean_resp_signal(h5_file, target_rate=100):
    """
    Loads, filters, downsamples respiration from .h5, returns cleaned signal and time vector.
    """
    try:
        with h5py.File(h5_file, 'r') as f:
            resp = f['resp'][:].flatten()
            ekg_meta = dict(f['ekg_metadata'].attrs)
        duration_sec = ekg_meta['duration_sec']
        fs = len(resp) / duration_sec
    except Exception as e:
        print(f"Error loading {h5_file}: {e}")
        return None, None, None

    # Pre-filter before downsampling
    nyquist = fs / 2
    norm_cutoff = (target_rate / 2) / nyquist
    b, a = butter(N=4, Wn=norm_cutoff, btype='low')
    filtered_resp = filtfilt(b, a, resp)

    # Downsample
    downsample_factor = int(fs // target_rate)
    downsampled = resample_poly(filtered_resp, up=1, down=downsample_factor)

    # Bandpass filter with neurokit
    rsp_cleaned = nk.signal_filter(
        downsampled,
        lowcut=0.1,
        highcut=20,
        method="butterworth",
        sampling_rate=target_rate,
        order=2
    )

    # Generate matching time vector
    time_vector = np.arange(len(rsp_cleaned)) / target_rate

    return rsp_cleaned, time_vector, target_rate

# %%
h5_paths = {
    "RI1_3_6": RI1_3_6_h5_path,
    "RI2_3_6": RI2_3_6_h5_path,
    "RI1_4_7": RI1_4_7_h5_path,
    "RI2_4_7": RI2_4_7_h5_path,
    "RI1_2_3": RI1_2_3_h5_path,
    "RI2_2_3": RI2_2_3_h5_path,
    "RI1_4_8": RI1_4_8_h5_path,
    "RI2_4_8": RI2_4_8_h5_path,
    "RI1_1_1": RI1_1_1_h5_path,
    "RI2_1_1": RI2_1_1_h5_path,
    "RI1_1_2": RI1_1_2_h5_path,
    "RI2_1_2": RI2_1_2_h5_path,
    "RI1_2_4": RI1_2_4_h5_path,
    "RI2_2_4": RI2_2_4_h5_path,
    "RI1_3_5": RI1_3_5_h5_path,
    "RI2_3_5": RI2_3_5_h5_path,
}

# %%
resp_data = {}

for label, path in h5_paths.items():
    print(f"Processing {label}...")
    signal, time, rate = load_clean_resp_signal(path)
    
    if signal is not None:
        resp_data[label] = {
            "signal": signal,
            "time": time,
            "sampling_rate": rate
        }
    else:
        print(f"Skipping {label}: failed to load.")

print("✅ All available signals loaded.")
# Out:
# Processing RI1_3_6...
# Processing RI2_3_6...
# Processing RI1_4_7...
# Processing RI2_4_7...
# Processing RI1_2_3...
# Processing RI2_2_3...
# Processing RI1_4_8...
# Processing RI2_4_8...
# Processing RI1_1_1...
# Processing RI2_1_1...
# Processing RI1_1_2...
# Processing RI2_1_2...
# Processing RI1_2_4...
# Processing RI2_2_4...
# Processing RI1_3_5...
# Processing RI2_3_5...
# ✅ All available signals loaded.

# %%
for subject, df in ri2_boris_data.items():
    count = df[(df['Behavior'] == 'facial sniffing') & (df['Subject'] == 'social_agent')].shape[0]
    print(f"{subject} facial sniffing count: {count}")
# Out:
# RI2_3_6 facial sniffing count: 26
# RI2_4_7 facial sniffing count: 21
# RI2_2_3 facial sniffing count: 12
# RI2_4_8 facial sniffing count: 38
# RI2_1_1 facial sniffing count: 4
# RI2_1_2 facial sniffing count: 17
# RI2_2_4 facial sniffing count: 13
# RI2_3_5 facial sniffing count: 6

# %%
for subject, df in ri2_boris_data.items():
    count = df[df['Behavior'] == 'fighting'].shape[0]
    print(f"{subject} fight count: {count}")
# Out:
# RI2_3_6 fight count: 18
# RI2_4_7 fight count: 30
# RI2_2_3 fight count: 14
# RI2_4_8 fight count: 28
# RI2_1_1 fight count: 8
# RI2_1_2 fight count: 3
# RI2_2_4 fight count: 13
# RI2_3_5 fight count: 8

# %%
from scipy.signal import find_peaks

for subject, resp_file in ri2_h5_paths.items():
    resp_signal, resp_times, fs = load_clean_resp_signal(resp_file, target_rate=100)
    if resp_signal is None:
        print(f"{subject}: Resp signal failed to load.")
        continue
    peaks, _ = find_peaks(resp_signal, distance=int(fs * 0.0833))
    print(f"{subject}: {len(peaks)} peaks found in respiration signal.")
# Out:
# RI2_3_6: 3692 peaks found in respiration signal.
# RI2_4_7: 4090 peaks found in respiration signal.
# RI2_2_3: 4243 peaks found in respiration signal.
# RI2_4_8: 3550 peaks found in respiration signal.
# RI2_1_1: 3745 peaks found in respiration signal.
# RI2_1_2: 4038 peaks found in respiration signal.
# RI2_2_4: 3916 peaks found in respiration signal.
# RI2_3_5: 1296 peaks found in respiration signal.

# %%
for label, path in h5_paths.items():
    print(f"{label} is type {type(path)}")
# Out:
# RI1_3_6 is type <class 'str'>
# RI2_3_6 is type <class 'str'>
# RI1_4_7 is type <class 'str'>
# RI2_4_7 is type <class 'str'>
# RI1_2_3 is type <class 'str'>
# RI2_2_3 is type <class 'str'>
# RI1_4_8 is type <class 'str'>
# RI2_4_8 is type <class 'str'>
# RI1_1_1 is type <class 'str'>
# RI2_1_1 is type <class 'str'>
# RI1_1_2 is type <class 'str'>
# RI2_1_2 is type <class 'str'>
# RI1_2_4 is type <class 'str'>
# RI2_2_4 is type <class 'str'>
# RI1_3_5 is type <class 'str'>
# RI2_3_5 is type <class 'str'>

# %%
for key in resp_data:
    print(f"{key}: {len(resp_data[key]['signal'])} samples at {resp_data[key]['sampling_rate']} Hz")
# Out:
# RI1_3_6: 60328 samples at 100 Hz
# RI2_3_6: 61001 samples at 100 Hz
# RI1_4_7: 62916 samples at 100 Hz
# RI2_4_7: 60647 samples at 100 Hz
# RI1_2_3: 60295 samples at 100 Hz
# RI2_2_3: 60921 samples at 100 Hz
# RI1_4_8: 60484 samples at 100 Hz
# RI2_4_8: 60324 samples at 100 Hz
# RI1_1_1: 62127 samples at 100 Hz
# RI2_1_1: 60480 samples at 100 Hz
# RI1_1_2: 60448 samples at 100 Hz
# RI2_1_2: 60427 samples at 100 Hz
# RI1_2_4: 60910 samples at 100 Hz
# RI2_2_4: 60545 samples at 100 Hz
# RI1_3_5: 62374 samples at 100 Hz
# RI2_3_5: 21334 samples at 100 Hz

# %% [markdown]
# get_sniff_respiratory_rate function is good for calculating the breathing rate during a sniff bout:
#
# It creates a mask to select the respiratory signal samples between sniff_start and sniff_end.
#
# It uses find_peaks to detect inhalation peaks in that signal segment, with a minimum peak distance of 0.2 seconds (to avoid counting the same breath twice).
#
# It calculates the duration of the sniff bout.
#
# It returns the breathing rate as the number of detected peaks divided by the duration (giving rate in Hz).
#
# A few things to watch out for:
# Sampling rate consistency: Make sure the times array and the signal array are aligned and that sampling_rate matches the sampling frequency of the signal.
#
# Peak detection threshold: You might want to tweak the distance or add a height parameter in find_peaks if you get too many or too few peaks.
#
# Edge cases: If duration is zero or very small, it returns np.nan, which is good.

# %%
def get_sniff_respiratory_rate(signal, time, sniff_start, sniff_end, sampling_rate=100):
    """
    Compute breathing rate (Hz) during a sniff bout.
    """
    sniff_mask = (time >= sniff_start) & (time < sniff_end)
    signal_sniff = signal[sniff_mask]

    peaks, _ = find_peaks(signal_sniff, distance=sampling_rate * 0.0833)

    duration = sniff_end - sniff_start
    rate = len(peaks) / duration if duration > 0 else np.nan

    return rate

# %%
def extract_agent_face_sniffs(df):
    """
    Filters BORIS dataframe for facial sniffing initiated by the social agent.
    """
    df = df.copy()
    df['Start (s)'] = df['Start (s)'].astype(float)
    df['Stop (s)'] = df['Stop (s)'].astype(float)
    df = df.sort_values(by='Start (s)').reset_index(drop=True)

    # Updated filters
    agent_mask = df['Subject'].str.lower() == 'social_agent'
    sniff_mask = df['Behavior'].str.lower() == 'facial sniffing'

    return df[agent_mask & sniff_mask]

# %%
agent_sniffs = extract_agent_face_sniffs(RI2_3_6_boris)
print(agent_sniffs[['Subject', 'Behavior', 'Start (s)', 'Stop (s)']])
# Out:
#           Subject         Behavior  Start (s)  Stop (s)
# 12   social_agent  facial sniffing     25.600    26.100
# 23   social_agent  facial sniffing     68.767    69.600
# 36   social_agent  facial sniffing     91.900    92.267
# 40   social_agent  facial sniffing    153.900   154.400
# 41   social_agent  facial sniffing    156.233   156.567
# 43   social_agent  facial sniffing    195.433   195.767
# 46   social_agent  facial sniffing    196.167   197.500
# 53   social_agent  facial sniffing    218.300   219.367
# 59   social_agent  facial sniffing    226.433   226.900
# 64   social_agent  facial sniffing    234.867   235.367
# 67   social_agent  facial sniffing    249.733   250.567
# 68   social_agent  facial sniffing    257.833   258.367
# 70   social_agent  facial sniffing    267.400   268.933
# 71   social_agent  facial sniffing    269.767   270.600
# 75   social_agent  facial sniffing    273.367   274.200
# 78   social_agent  facial sniffing    282.033   283.067
# 79   social_agent  facial sniffing    288.200   288.767
# 80   social_agent  facial sniffing    290.133   290.900
# 81   social_agent  facial sniffing    318.700   319.567
# 82   social_agent  facial sniffing    343.133   346.733
# 98   social_agent  facial sniffing    503.133   505.233
# 100  social_agent  facial sniffing    537.000   537.333
# 101  social_agent  facial sniffing    548.033   550.667
# 105  social_agent  facial sniffing    554.333   556.400
# 106  social_agent  facial sniffing    559.000   559.267
# 107  social_agent  facial sniffing    596.333   597.533

# %%
agent_sniffs
# Out:
#           Observation id         Observation date  Description  \
# 12   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 23   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 36   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 40   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 41   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 43   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 46   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 53   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 59   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 64   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 67   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 68   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 70   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 71   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 75   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 78   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 79   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 80   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 81   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 82   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 98   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 100  RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 101  RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 105  RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 106  RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
# 107  RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871          NaN
#
#     Observation type  \
# 12        Media file
# 23        Media file
# 36        Media file
# 40        Media file
# 41        Media file
# 43        Media file
# 46        Media file
# 53        Media file
# 59        Media file
# 64        Media file
# 67        Media file
# 68        Media file
# 70        Media file
# 71        Media file
# 75        Media file
# 78        Media file
# 79        Media file
# 80        Media file
# 81        Media file
# 82        Media file
# 98        Media file
# 100       Media file
# 101       Media file
# 105       Media file
# 106       Media file
# 107       Media file
#
#                                                                                                                 Source  \
# 12   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 23   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 36   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 40   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 41   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 43   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 46   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 53   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 59   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 64   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 67   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 68   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 70   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 71   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 75   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 78   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 79   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 80   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 81   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 82   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 98   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 100  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 101  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 105  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 106  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 107  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
#
#      Time offset (s)  Coding duration  Media duration (s)  FPS (frame/s)  \
# 12               0.0            603.9             608.733           30.0
# 23               0.0            603.9             608.733           30.0
# 36               0.0            603.9             608.733           30.0
# 40               0.0            603.9             608.733           30.0
# 41               0.0            603.9             608.733           30.0
# 43               0.0            603.9             608.733           30.0
# 46               0.0            603.9             608.733           30.0
# 53               0.0            603.9             608.733           30.0
# 59               0.0            603.9             608.733           30.0
# 64               0.0            603.9             608.733           30.0
# 67               0.0            603.9             608.733           30.0
# 68               0.0            603.9             608.733           30.0
# 70               0.0            603.9             608.733           30.0
# 71               0.0            603.9             608.733           30.0
# 75               0.0            603.9             608.733           30.0
# 78               0.0            603.9             608.733           30.0
# 79               0.0            603.9             608.733           30.0
# 80               0.0            603.9             608.733           30.0
# 81               0.0            603.9             608.733           30.0
# 82               0.0            603.9             608.733           30.0
# 98               0.0            603.9             608.733           30.0
# 100              0.0            603.9             608.733           30.0
# 101              0.0            603.9             608.733           30.0
# 105              0.0            603.9             608.733           30.0
# 106              0.0            603.9             608.733           30.0
# 107              0.0            603.9             608.733           30.0
#
#           Subject  Observation duration by subject by observation  \
# 12   social_agent                                         146.335
# 23   social_agent                                         146.335
# 36   social_agent                                         146.335
# 40   social_agent                                         146.335
# 41   social_agent                                         146.335
# 43   social_agent                                         146.335
# 46   social_agent                                         146.335
# 53   social_agent                                         146.335
# 59   social_agent                                         146.335
# 64   social_agent                                         146.335
# 67   social_agent                                         146.335
# 68   social_agent                                         146.335
# 70   social_agent                                         146.335
# 71   social_agent                                         146.335
# 75   social_agent                                         146.335
# 78   social_agent                                         146.335
# 79   social_agent                                         146.335
# 80   social_agent                                         146.335
# 81   social_agent                                         146.335
# 82   social_agent                                         146.335
# 98   social_agent                                         146.335
# 100  social_agent                                         146.335
# 101  social_agent                                         146.335
# 105  social_agent                                         146.335
# 106  social_agent                                         146.335
# 107  social_agent                                         146.335
#
#             Behavior Behavioral category Behavior type  Start (s)  Stop (s)  \
# 12   facial sniffing         Not defined         STATE     25.600    26.100
# 23   facial sniffing         Not defined         STATE     68.767    69.600
# 36   facial sniffing         Not defined         STATE     91.900    92.267
# 40   facial sniffing         Not defined         STATE    153.900   154.400
# 41   facial sniffing         Not defined         STATE    156.233   156.567
# 43   facial sniffing         Not defined         STATE    195.433   195.767
# 46   facial sniffing         Not defined         STATE    196.167   197.500
# 53   facial sniffing         Not defined         STATE    218.300   219.367
# 59   facial sniffing         Not defined         STATE    226.433   226.900
# 64   facial sniffing         Not defined         STATE    234.867   235.367
# 67   facial sniffing         Not defined         STATE    249.733   250.567
# 68   facial sniffing         Not defined         STATE    257.833   258.367
# 70   facial sniffing         Not defined         STATE    267.400   268.933
# 71   facial sniffing         Not defined         STATE    269.767   270.600
# 75   facial sniffing         Not defined         STATE    273.367   274.200
# 78   facial sniffing         Not defined         STATE    282.033   283.067
# 79   facial sniffing         Not defined         STATE    288.200   288.767
# 80   facial sniffing         Not defined         STATE    290.133   290.900
# 81   facial sniffing         Not defined         STATE    318.700   319.567
# 82   facial sniffing         Not defined         STATE    343.133   346.733
# 98   facial sniffing         Not defined         STATE    503.133   505.233
# 100  facial sniffing         Not defined         STATE    537.000   537.333
# 101  facial sniffing         Not defined         STATE    548.033   550.667
# 105  facial sniffing         Not defined         STATE    554.333   556.400
# 106  facial sniffing         Not defined         STATE    559.000   559.267
# 107  facial sniffing         Not defined         STATE    596.333   597.533
#
#      Duration (s)  \
# 12          0.500
# 23          0.833
# 36          0.367
# 40          0.500
# 41          0.334
# 43          0.334
# 46          1.333
# 53          1.067
# 59          0.467
# 64          0.500
# 67          0.834
# 68          0.534
# 70          1.533
# 71          0.833
# 75          0.833
# 78          1.034
# 79          0.567
# 80          0.767
# 81          0.867
# 82          3.600
# 98          2.100
# 100         0.333
# 101         2.634
# 105         2.067
# 106         0.267
# 107         1.200
#
#                                                                                              Media file name  \
# 12   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 23   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 36   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 40   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 41   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 43   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 46   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 53   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 59   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 64   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 67   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 68   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 70   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 71   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 75   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 78   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 79   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 80   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 81   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 82   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 98   E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 100  E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 101  E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 105  E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 106  E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 107  E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
#
#      Image index start  Image index stop  Image file path start  \
# 12                 768             783.0                    NaN
# 23                2063            2088.0                    NaN
# 36                2757            2768.0                    NaN
# 40                4617            4632.0                    NaN
# 41                4687            4697.0                    NaN
# 43                5863            5873.0                    NaN
# 46                5885            5925.0                    NaN
# 53                6549            6581.0                    NaN
# 59                6793            6807.0                    NaN
# 64                7046            7061.0                    NaN
# 67                7492            7517.0                    NaN
# 68                7735            7751.0                    NaN
# 70                8022            8068.0                    NaN
# 71                8093            8118.0                    NaN
# 75                8201            8226.0                    NaN
# 78                8461            8492.0                    NaN
# 79                8646            8663.0                    NaN
# 80                8704            8727.0                    NaN
# 81                9562            9588.0                    NaN
# 82               10295           10403.0                    NaN
# 98               15095           15158.0                    NaN
# 100              16111           16121.0                    NaN
# 101              16442           16521.0                    NaN
# 105              16631           16693.0                    NaN
# 106              16771           16779.0                    NaN
# 107              17891           17927.0                    NaN
#
#      Image file path stop  Comment start  Comment stop
# 12                    NaN            NaN           NaN
# 23                    NaN            NaN           NaN
# 36                    NaN            NaN           NaN
# 40                    NaN            NaN           NaN
# 41                    NaN            NaN           NaN
# 43                    NaN            NaN           NaN
# 46                    NaN            NaN           NaN
# 53                    NaN            NaN           NaN
# 59                    NaN            NaN           NaN
# 64                    NaN            NaN           NaN
# 67                    NaN            NaN           NaN
# 68                    NaN            NaN           NaN
# 70                    NaN            NaN           NaN
# 71                    NaN            NaN           NaN
# 75                    NaN            NaN           NaN
# 78                    NaN            NaN           NaN
# 79                    NaN            NaN           NaN
# 80                    NaN            NaN           NaN
# 81                    NaN            NaN           NaN
# 82                    NaN            NaN           NaN
# 98                    NaN            NaN           NaN
# 100                   NaN            NaN           NaN
# 101                   NaN            NaN           NaN
# 105                   NaN            NaN           NaN
# 106                   NaN            NaN           NaN
# 107                   NaN            NaN           NaN

# %%
all_agent_sniffs = []

# Loop through each trial in RI2
for label, boris_df in ri2_boris_data.items():
    agent_sniffs = extract_agent_face_sniffs(boris_df)
    agent_sniffs["Trial"] = label  # Add which trial/mouse it came from
    all_agent_sniffs.append(agent_sniffs)

# Combine all the individual DataFrames into one
combined_sniffs_df = pd.concat(all_agent_sniffs, ignore_index=True)

# Preview the result
print(combined_sniffs_df[['Trial', 'Subject', 'Behavior', 'Start (s)', 'Stop (s)']].head())
# Out:
#      Trial       Subject         Behavior  Start (s)  Stop (s)
# 0  RI2_3_6  social_agent  facial sniffing     25.600    26.100
# 1  RI2_3_6  social_agent  facial sniffing     68.767    69.600
# 2  RI2_3_6  social_agent  facial sniffing     91.900    92.267
# 3  RI2_3_6  social_agent  facial sniffing    153.900   154.400
# 4  RI2_3_6  social_agent  facial sniffing    156.233   156.567

# %%
combined_sniffs_df
# Out:
#                            Observation id         Observation date  \
# 0                     RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 1                     RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 2                     RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 3                     RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 4                     RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 5                     RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 6                     RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 7                     RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 8                     RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 9                     RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 10                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 11                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 12                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 13                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 14                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 15                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 16                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 17                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 18                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 19                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 20                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 21                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 22                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 23                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 24                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 25                    RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 26                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 27                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 28                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 29                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 30                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 31                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 32                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 33                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 34                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 35                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 36                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 37                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 38                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 39                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 40                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 41                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 42                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 43                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 44                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 45                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 46                     RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 47   RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 48   RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 49   RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 50   RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 51   RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 52   RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 53   RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 54   RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 55   RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 56   RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 57   RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 58   RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 59            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 60            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 61            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 62            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 63            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 64            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 65            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 66            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 67            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 68            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 69            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 70            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 71            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 72            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 73            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 74            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 75            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 76            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 77            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 78            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 79            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 80            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 81            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 82            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 83            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 84            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 85            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 86            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 87            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 88            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 89            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 90            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 91            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 92            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 93            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 94            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 95            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 96            RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 97   RI2_s1_1_p5_2_nRB6_20250622_150457.1      2025-07-03 14:09:47
# 98   RI2_s1_1_p5_2_nRB6_20250622_150457.1      2025-07-03 14:09:47
# 99   RI2_s1_1_p5_2_nRB6_20250622_150457.1      2025-07-03 14:09:47
# 100  RI2_s1_1_p5_2_nRB6_20250622_150457.1      2025-07-03 14:09:47
# 101  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 102  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 103  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 104  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 105  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 106  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 107  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 108  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 109  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 110  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 111  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 112  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 113  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 114  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 115  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 116  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 117  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 118  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 119  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 120  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 121  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 122  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 123  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 124  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 125  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 126  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 127  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 128  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 129  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 130  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 131                         RI2_s3_5_nRB3  2025-06-27 12:59:24.834
# 132                         RI2_s3_5_nRB3  2025-06-27 12:59:24.834
# 133                         RI2_s3_5_nRB3  2025-06-27 12:59:24.834
# 134                         RI2_s3_5_nRB3  2025-06-27 12:59:24.834
# 135                         RI2_s3_5_nRB3  2025-06-27 12:59:24.834
# 136                         RI2_s3_5_nRB3  2025-06-27 12:59:24.834
#
#      Description Observation type  \
# 0            NaN       Media file
# 1            NaN       Media file
# 2            NaN       Media file
# 3            NaN       Media file
# 4            NaN       Media file
# 5            NaN       Media file
# 6            NaN       Media file
# 7            NaN       Media file
# 8            NaN       Media file
# 9            NaN       Media file
# 10           NaN       Media file
# 11           NaN       Media file
# 12           NaN       Media file
# 13           NaN       Media file
# 14           NaN       Media file
# 15           NaN       Media file
# 16           NaN       Media file
# 17           NaN       Media file
# 18           NaN       Media file
# 19           NaN       Media file
# 20           NaN       Media file
# 21           NaN       Media file
# 22           NaN       Media file
# 23           NaN       Media file
# 24           NaN       Media file
# 25           NaN       Media file
# 26           NaN       Media file
# 27           NaN       Media file
# 28           NaN       Media file
# 29           NaN       Media file
# 30           NaN       Media file
# 31           NaN       Media file
# 32           NaN       Media file
# 33           NaN       Media file
# 34           NaN       Media file
# 35           NaN       Media file
# 36           NaN       Media file
# 37           NaN       Media file
# 38           NaN       Media file
# 39           NaN       Media file
# 40           NaN       Media file
# 41           NaN       Media file
# 42           NaN       Media file
# 43           NaN       Media file
# 44           NaN       Media file
# 45           NaN       Media file
# 46           NaN       Media file
# 47           NaN              NaN
# 48           NaN              NaN
# 49           NaN              NaN
# 50           NaN              NaN
# 51           NaN              NaN
# 52           NaN              NaN
# 53           NaN              NaN
# 54           NaN              NaN
# 55           NaN              NaN
# 56           NaN              NaN
# 57           NaN              NaN
# 58           NaN              NaN
# 59           NaN       Media file
# 60           NaN       Media file
# 61           NaN       Media file
# 62           NaN       Media file
# 63           NaN       Media file
# 64           NaN       Media file
# 65           NaN       Media file
# 66           NaN       Media file
# 67           NaN       Media file
# 68           NaN       Media file
# 69           NaN       Media file
# 70           NaN       Media file
# 71           NaN       Media file
# 72           NaN       Media file
# 73           NaN       Media file
# 74           NaN       Media file
# 75           NaN       Media file
# 76           NaN       Media file
# 77           NaN       Media file
# 78           NaN       Media file
# 79           NaN       Media file
# 80           NaN       Media file
# 81           NaN       Media file
# 82           NaN       Media file
# 83           NaN       Media file
# 84           NaN       Media file
# 85           NaN       Media file
# 86           NaN       Media file
# 87           NaN       Media file
# 88           NaN       Media file
# 89           NaN       Media file
# 90           NaN       Media file
# 91           NaN       Media file
# 92           NaN       Media file
# 93           NaN       Media file
# 94           NaN       Media file
# 95           NaN       Media file
# 96           NaN       Media file
# 97           NaN              NaN
# 98           NaN              NaN
# 99           NaN              NaN
# 100          NaN              NaN
# 101          NaN              NaN
# 102          NaN              NaN
# 103          NaN              NaN
# 104          NaN              NaN
# 105          NaN              NaN
# 106          NaN              NaN
# 107          NaN              NaN
# 108          NaN              NaN
# 109          NaN              NaN
# 110          NaN              NaN
# 111          NaN              NaN
# 112          NaN              NaN
# 113          NaN              NaN
# 114          NaN              NaN
# 115          NaN              NaN
# 116          NaN              NaN
# 117          NaN              NaN
# 118          NaN              NaN
# 119          NaN              NaN
# 120          NaN              NaN
# 121          NaN              NaN
# 122          NaN              NaN
# 123          NaN              NaN
# 124          NaN              NaN
# 125          NaN              NaN
# 126          NaN              NaN
# 127          NaN              NaN
# 128          NaN              NaN
# 129          NaN              NaN
# 130          NaN              NaN
# 131          NaN       Media file
# 132          NaN       Media file
# 133          NaN       Media file
# 134          NaN       Media file
# 135          NaN       Media file
# 136          NaN       Media file
#
#                                                                                                                 Source  \
# 0    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 1    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 2    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 3    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 4    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 5    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 6    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 7    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 8    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 9    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 10   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 11   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 12   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 13   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 14   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 15   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 16   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 17   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 18   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 19   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 20   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 21   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 22   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 23   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 24   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 25   player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 26                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 27                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 28                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 29                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 30                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 31                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 32                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 33                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 34                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 35                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 36                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 37                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 38                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 39                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 40                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 41                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 42                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 43                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 44                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 45                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 46                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 47                                                                                                                 NaN
# 48                                                                                                                 NaN
# 49                                                                                                                 NaN
# 50                                                                                                                 NaN
# 51                                                                                                                 NaN
# 52                                                                                                                 NaN
# 53                                                                                                                 NaN
# 54                                                                                                                 NaN
# 55                                                                                                                 NaN
# 56                                                                                                                 NaN
# 57                                                                                                                 NaN
# 58                                                                                                                 NaN
# 59                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 60                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 61                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 62                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 63                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 64                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 65                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 66                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 67                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 68                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 69                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 70                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 71                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 72                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 73                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 74                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 75                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 76                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 77                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 78                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 79                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 80                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 81                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 82                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 83                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 84                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 85                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 86                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 87                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 88                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 89                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 90                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 91                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 92                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 93                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 94                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 95                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 96                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 97                                                                                                                 NaN
# 98                                                                                                                 NaN
# 99                                                                                                                 NaN
# 100                                                                                                                NaN
# 101                                                                                                                NaN
# 102                                                                                                                NaN
# 103                                                                                                                NaN
# 104                                                                                                                NaN
# 105                                                                                                                NaN
# 106                                                                                                                NaN
# 107                                                                                                                NaN
# 108                                                                                                                NaN
# 109                                                                                                                NaN
# 110                                                                                                                NaN
# 111                                                                                                                NaN
# 112                                                                                                                NaN
# 113                                                                                                                NaN
# 114                                                                                                                NaN
# 115                                                                                                                NaN
# 116                                                                                                                NaN
# 117                                                                                                                NaN
# 118                                                                                                                NaN
# 119                                                                                                                NaN
# 120                                                                                                                NaN
# 121                                                                                                                NaN
# 122                                                                                                                NaN
# 123                                                                                                                NaN
# 124                                                                                                                NaN
# 125                                                                                                                NaN
# 126                                                                                                                NaN
# 127                                                                                                                NaN
# 128                                                                                                                NaN
# 129                                                                                                                NaN
# 130                                                                                                                NaN
# 131    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_5_p5_4_nRB3_20250621_112618.rec/RI2_s3_5_p5_4_nRB3_20250621_112618.1.mp4
# 132    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_5_p5_4_nRB3_20250621_112618.rec/RI2_s3_5_p5_4_nRB3_20250621_112618.1.mp4
# 133    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_5_p5_4_nRB3_20250621_112618.rec/RI2_s3_5_p5_4_nRB3_20250621_112618.1.mp4
# 134    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_5_p5_4_nRB3_20250621_112618.rec/RI2_s3_5_p5_4_nRB3_20250621_112618.1.mp4
# 135    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_5_p5_4_nRB3_20250621_112618.rec/RI2_s3_5_p5_4_nRB3_20250621_112618.1.mp4
# 136    player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_5_p5_4_nRB3_20250621_112618.rec/RI2_s3_5_p5_4_nRB3_20250621_112618.1.mp4
#
#      Time offset (s)  Coding duration  Media duration (s)  FPS (frame/s)  \
# 0                0.0          603.900             608.733           30.0
# 1                0.0          603.900             608.733           30.0
# 2                0.0          603.900             608.733           30.0
# 3                0.0          603.900             608.733           30.0
# 4                0.0          603.900             608.733           30.0
# 5                0.0          603.900             608.733           30.0
# 6                0.0          603.900             608.733           30.0
# 7                0.0          603.900             608.733           30.0
# 8                0.0          603.900             608.733           30.0
# 9                0.0          603.900             608.733           30.0
# 10               0.0          603.900             608.733           30.0
# 11               0.0          603.900             608.733           30.0
# 12               0.0          603.900             608.733           30.0
# 13               0.0          603.900             608.733           30.0
# 14               0.0          603.900             608.733           30.0
# 15               0.0          603.900             608.733           30.0
# 16               0.0          603.900             608.733           30.0
# 17               0.0          603.900             608.733           30.0
# 18               0.0          603.900             608.733           30.0
# 19               0.0          603.900             608.733           30.0
# 20               0.0          603.900             608.733           30.0
# 21               0.0          603.900             608.733           30.0
# 22               0.0          603.900             608.733           30.0
# 23               0.0          603.900             608.733           30.0
# 24               0.0          603.900             608.733           30.0
# 25               0.0          603.900             608.733           30.0
# 26               0.0          598.466             605.233           30.0
# 27               0.0          598.466             605.233           30.0
# 28               0.0          598.466             605.233           30.0
# 29               0.0          598.466             605.233           30.0
# 30               0.0          598.466             605.233           30.0
# 31               0.0          598.466             605.233           30.0
# 32               0.0          598.466             605.233           30.0
# 33               0.0          598.466             605.233           30.0
# 34               0.0          598.466             605.233           30.0
# 35               0.0          598.466             605.233           30.0
# 36               0.0          598.466             605.233           30.0
# 37               0.0          598.466             605.233           30.0
# 38               0.0          598.466             605.233           30.0
# 39               0.0          598.466             605.233           30.0
# 40               0.0          598.466             605.233           30.0
# 41               0.0          598.466             605.233           30.0
# 42               0.0          598.466             605.233           30.0
# 43               0.0          598.466             605.233           30.0
# 44               0.0          598.466             605.233           30.0
# 45               0.0          598.466             605.233           30.0
# 46               0.0          598.466             605.233           30.0
# 47               NaN              NaN                 NaN            NaN
# 48               NaN              NaN                 NaN            NaN
# 49               NaN              NaN                 NaN            NaN
# 50               NaN              NaN                 NaN            NaN
# 51               NaN              NaN                 NaN            NaN
# 52               NaN              NaN                 NaN            NaN
# 53               NaN              NaN                 NaN            NaN
# 54               NaN              NaN                 NaN            NaN
# 55               NaN              NaN                 NaN            NaN
# 56               NaN              NaN                 NaN            NaN
# 57               NaN              NaN                 NaN            NaN
# 58               NaN              NaN                 NaN            NaN
# 59               0.0          588.934             602.133           30.0
# 60               0.0          588.934             602.133           30.0
# 61               0.0          588.934             602.133           30.0
# 62               0.0          588.934             602.133           30.0
# 63               0.0          588.934             602.133           30.0
# 64               0.0          588.934             602.133           30.0
# 65               0.0          588.934             602.133           30.0
# 66               0.0          588.934             602.133           30.0
# 67               0.0          588.934             602.133           30.0
# 68               0.0          588.934             602.133           30.0
# 69               0.0          588.934             602.133           30.0
# 70               0.0          588.934             602.133           30.0
# 71               0.0          588.934             602.133           30.0
# 72               0.0          588.934             602.133           30.0
# 73               0.0          588.934             602.133           30.0
# 74               0.0          588.934             602.133           30.0
# 75               0.0          588.934             602.133           30.0
# 76               0.0          588.934             602.133           30.0
# 77               0.0          588.934             602.133           30.0
# 78               0.0          588.934             602.133           30.0
# 79               0.0          588.934             602.133           30.0
# 80               0.0          588.934             602.133           30.0
# 81               0.0          588.934             602.133           30.0
# 82               0.0          588.934             602.133           30.0
# 83               0.0          588.934             602.133           30.0
# 84               0.0          588.934             602.133           30.0
# 85               0.0          588.934             602.133           30.0
# 86               0.0          588.934             602.133           30.0
# 87               0.0          588.934             602.133           30.0
# 88               0.0          588.934             602.133           30.0
# 89               0.0          588.934             602.133           30.0
# 90               0.0          588.934             602.133           30.0
# 91               0.0          588.934             602.133           30.0
# 92               0.0          588.934             602.133           30.0
# 93               0.0          588.934             602.133           30.0
# 94               0.0          588.934             602.133           30.0
# 95               0.0          588.934             602.133           30.0
# 96               0.0          588.934             602.133           30.0
# 97               NaN              NaN                 NaN            NaN
# 98               NaN              NaN                 NaN            NaN
# 99               NaN              NaN                 NaN            NaN
# 100              NaN              NaN                 NaN            NaN
# 101              NaN              NaN                 NaN            NaN
# 102              NaN              NaN                 NaN            NaN
# 103              NaN              NaN                 NaN            NaN
# 104              NaN              NaN                 NaN            NaN
# 105              NaN              NaN                 NaN            NaN
# 106              NaN              NaN                 NaN            NaN
# 107              NaN              NaN                 NaN            NaN
# 108              NaN              NaN                 NaN            NaN
# 109              NaN              NaN                 NaN            NaN
# 110              NaN              NaN                 NaN            NaN
# 111              NaN              NaN                 NaN            NaN
# 112              NaN              NaN                 NaN            NaN
# 113              NaN              NaN                 NaN            NaN
# 114              NaN              NaN                 NaN            NaN
# 115              NaN              NaN                 NaN            NaN
# 116              NaN              NaN                 NaN            NaN
# 117              NaN              NaN                 NaN            NaN
# 118              NaN              NaN                 NaN            NaN
# 119              NaN              NaN                 NaN            NaN
# 120              NaN              NaN                 NaN            NaN
# 121              NaN              NaN                 NaN            NaN
# 122              NaN              NaN                 NaN            NaN
# 123              NaN              NaN                 NaN            NaN
# 124              NaN              NaN                 NaN            NaN
# 125              NaN              NaN                 NaN            NaN
# 126              NaN              NaN                 NaN            NaN
# 127              NaN              NaN                 NaN            NaN
# 128              NaN              NaN                 NaN            NaN
# 129              NaN              NaN                 NaN            NaN
# 130              NaN              NaN                 NaN            NaN
# 131              0.0          208.866             602.033           30.0
# 132              0.0          208.866             602.033           30.0
# 133              0.0          208.866             602.033           30.0
# 134              0.0          208.866             602.033           30.0
# 135              0.0          208.866             602.033           30.0
# 136              0.0          208.866             602.033           30.0
#
#           Subject  Observation duration by subject by observation  \
# 0    social_agent                                         146.335
# 1    social_agent                                         146.335
# 2    social_agent                                         146.335
# 3    social_agent                                         146.335
# 4    social_agent                                         146.335
# 5    social_agent                                         146.335
# 6    social_agent                                         146.335
# 7    social_agent                                         146.335
# 8    social_agent                                         146.335
# 9    social_agent                                         146.335
# 10   social_agent                                         146.335
# 11   social_agent                                         146.335
# 12   social_agent                                         146.335
# 13   social_agent                                         146.335
# 14   social_agent                                         146.335
# 15   social_agent                                         146.335
# 16   social_agent                                         146.335
# 17   social_agent                                         146.335
# 18   social_agent                                         146.335
# 19   social_agent                                         146.335
# 20   social_agent                                         146.335
# 21   social_agent                                         146.335
# 22   social_agent                                         146.335
# 23   social_agent                                         146.335
# 24   social_agent                                         146.335
# 25   social_agent                                         146.335
# 26   social_agent                                         158.001
# 27   social_agent                                         158.001
# 28   social_agent                                         158.001
# 29   social_agent                                         158.001
# 30   social_agent                                         158.001
# 31   social_agent                                         158.001
# 32   social_agent                                         158.001
# 33   social_agent                                         158.001
# 34   social_agent                                         158.001
# 35   social_agent                                         158.001
# 36   social_agent                                         158.001
# 37   social_agent                                         158.001
# 38   social_agent                                         158.001
# 39   social_agent                                         158.001
# 40   social_agent                                         158.001
# 41   social_agent                                         158.001
# 42   social_agent                                         158.001
# 43   social_agent                                         158.001
# 44   social_agent                                         158.001
# 45   social_agent                                         158.001
# 46   social_agent                                         158.001
# 47   social_agent                                             NaN
# 48   social_agent                                             NaN
# 49   social_agent                                             NaN
# 50   social_agent                                             NaN
# 51   social_agent                                             NaN
# 52   social_agent                                             NaN
# 53   social_agent                                             NaN
# 54   social_agent                                             NaN
# 55   social_agent                                             NaN
# 56   social_agent                                             NaN
# 57   social_agent                                             NaN
# 58   social_agent                                             NaN
# 59   social_agent                                         202.519
# 60   social_agent                                         202.519
# 61   social_agent                                         202.519
# 62   social_agent                                         202.519
# 63   social_agent                                         202.519
# 64   social_agent                                         202.519
# 65   social_agent                                         202.519
# 66   social_agent                                         202.519
# 67   social_agent                                         202.519
# 68   social_agent                                         202.519
# 69   social_agent                                         202.519
# 70   social_agent                                         202.519
# 71   social_agent                                         202.519
# 72   social_agent                                         202.519
# 73   social_agent                                         202.519
# 74   social_agent                                         202.519
# 75   social_agent                                         202.519
# 76   social_agent                                         202.519
# 77   social_agent                                         202.519
# 78   social_agent                                         202.519
# 79   social_agent                                         202.519
# 80   social_agent                                         202.519
# 81   social_agent                                         202.519
# 82   social_agent                                         202.519
# 83   social_agent                                         202.519
# ...
# 131                   NaN            NaN           NaN  RI2_3_5
# 132                   NaN            NaN           NaN  RI2_3_5
# 133                   NaN            NaN           NaN  RI2_3_5
# 134                   NaN            NaN           NaN  RI2_3_5
# 135                   NaN            NaN           NaN  RI2_3_5
# 136                   NaN            NaN           NaN  RI2_3_5
#
#                                                               Media file  \
# 0                                                                    NaN
# 1                                                                    NaN
# 2                                                                    NaN
# 3                                                                    NaN
# 4                                                                    NaN
# 5                                                                    NaN
# 6                                                                    NaN
# 7                                                                    NaN
# 8                                                                    NaN
# 9                                                                    NaN
# 10                                                                   NaN
# 11                                                                   NaN
# 12                                                                   NaN
# 13                                                                   NaN
# 14                                                                   NaN
# 15                                                                   NaN
# 16                                                                   NaN
# 17                                                                   NaN
# 18                                                                   NaN
# 19                                                                   NaN
# 20                                                                   NaN
# 21                                                                   NaN
# 22                                                                   NaN
# 23                                                                   NaN
# 24                                                                   NaN
# 25                                                                   NaN
# 26                                                                   NaN
# 27                                                                   NaN
# 28                                                                   NaN
# 29                                                                   NaN
# 30                                                                   NaN
# 31                                                                   NaN
# 32                                                                   NaN
# 33                                                                   NaN
# 34                                                                   NaN
# 35                                                                   NaN
# 36                                                                   NaN
# 37                                                                   NaN
# 38                                                                   NaN
# 39                                                                   NaN
# 40                                                                   NaN
# 41                                                                   NaN
# 42                                                                   NaN
# 43                                                                   NaN
# 44                                                                   NaN
# 45                                                                   NaN
# 46                                                                   NaN
# 47   /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 48   /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 49   /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 50   /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 51   /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 52   /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 53   /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 54   /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 55   /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 56   /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 57   /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 58   /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 59                                                                   NaN
# 60                                                                   NaN
# 61                                                                   NaN
# 62                                                                   NaN
# 63                                                                   NaN
# 64                                                                   NaN
# 65                                                                   NaN
# 66                                                                   NaN
# 67                                                                   NaN
# 68                                                                   NaN
# 69                                                                   NaN
# 70                                                                   NaN
# 71                                                                   NaN
# 72                                                                   NaN
# 73                                                                   NaN
# 74                                                                   NaN
# 75                                                                   NaN
# 76                                                                   NaN
# 77                                                                   NaN
# 78                                                                   NaN
# 79                                                                   NaN
# 80                                                                   NaN
# 81                                                                   NaN
# 82                                                                   NaN
# 83                                                                   NaN
# 84                                                                   NaN
# 85                                                                   NaN
# 86                                                                   NaN
# 87                                                                   NaN
# 88                                                                   NaN
# 89                                                                   NaN
# 90                                                                   NaN
# 91                                                                   NaN
# 92                                                                   NaN
# 93                                                                   NaN
# 94                                                                   NaN
# 95                                                                   NaN
# 96                                                                   NaN
# 97   /Users/ayushjain/Downloads/RI2_s1_1_p5_2_nRB6_20250622_150457.1.mov
# 98   /Users/ayushjain/Downloads/RI2_s1_1_p5_2_nRB6_20250622_150457.1.mov
# 99   /Users/ayushjain/Downloads/RI2_s1_1_p5_2_nRB6_20250622_150457.1.mov
# 100  /Users/ayushjain/Downloads/RI2_s1_1_p5_2_nRB6_20250622_150457.1.mov
# 101  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 102  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 103  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 104  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 105  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 106  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 107  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 108  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 109  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 110  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 111  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 112  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 113  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 114  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 115  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 116  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 117  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 118  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 119  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 120  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 121  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 122  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 123  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 124  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 125  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 126  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 127  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 128  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 129  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 130  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 131                                                                  NaN
# 132                                                                  NaN
# 133                                                                  NaN
# 134                                                                  NaN
# 135                                                                  NaN
# 136                                                                  NaN
#
#      Total length   FPS  Modifiers
# 0             NaN   NaN        NaN
# 1             NaN   NaN        NaN
# 2             NaN   NaN        NaN
# 3             NaN   NaN        NaN
# 4             NaN   NaN        NaN
# 5             NaN   NaN        NaN
# 6             NaN   NaN        NaN
# 7             NaN   NaN        NaN
# 8             NaN   NaN        NaN
# 9             NaN   NaN        NaN
# 10            NaN   NaN        NaN
# 11            NaN   NaN        NaN
# 12            NaN   NaN        NaN
# 13            NaN   NaN        NaN
# 14            NaN   NaN        NaN
# 15            NaN   NaN        NaN
# 16            NaN   NaN        NaN
# 17            NaN   NaN        NaN
# 18            NaN   NaN        NaN
# 19            NaN   NaN        NaN
# 20            NaN   NaN        NaN
# 21            NaN   NaN        NaN
# 22            NaN   NaN        NaN
# 23            NaN   NaN        NaN
# 24            NaN   NaN        NaN
# 25            NaN   NaN        NaN
# 26            NaN   NaN        NaN
# 27            NaN   NaN        NaN
# 28            NaN   NaN        NaN
# 29            NaN   NaN        NaN
# 30            NaN   NaN        NaN
# 31            NaN   NaN        NaN
# 32            NaN   NaN        NaN
# 33            NaN   NaN        NaN
# 34            NaN   NaN        NaN
# 35            NaN   NaN        NaN
# 36            NaN   NaN        NaN
# 37            NaN   NaN        NaN
# 38            NaN   NaN        NaN
# 39            NaN   NaN        NaN
# 40            NaN   NaN        NaN
# 41            NaN   NaN        NaN
# 42            NaN   NaN        NaN
# 43            NaN   NaN        NaN
# 44            NaN   NaN        NaN
# 45            NaN   NaN        NaN
# 46            NaN   NaN        NaN
# 47         607.83  30.0        NaN
# 48         607.83  30.0        NaN
# 49         607.83  30.0        NaN
# 50         607.83  30.0        NaN
# 51         607.83  30.0        NaN
# 52         607.83  30.0        NaN
# 53         607.83  30.0        NaN
# 54         607.83  30.0        NaN
# 55         607.83  30.0        NaN
# 56         607.83  30.0        NaN
# 57         607.83  30.0        NaN
# 58         607.83  30.0        NaN
# 59            NaN   NaN        NaN
# 60            NaN   NaN        NaN
# 61            NaN   NaN        NaN
# 62            NaN   NaN        NaN
# 63            NaN   NaN        NaN
# 64            NaN   NaN        NaN
# 65            NaN   NaN        NaN
# 66            NaN   NaN        NaN
# 67            NaN   NaN        NaN
# 68            NaN   NaN        NaN
# 69            NaN   NaN        NaN
# 70            NaN   NaN        NaN
# 71            NaN   NaN        NaN
# 72            NaN   NaN        NaN
# 73            NaN   NaN        NaN
# 74            NaN   NaN        NaN
# 75            NaN   NaN        NaN
# 76            NaN   NaN        NaN
# 77            NaN   NaN        NaN
# 78            NaN   NaN        NaN
# 79            NaN   NaN        NaN
# 80            NaN   NaN        NaN
# 81            NaN   NaN        NaN
# 82            NaN   NaN        NaN
# 83            NaN   NaN        NaN
# 84            NaN   NaN        NaN
# 85            NaN   NaN        NaN
# 86            NaN   NaN        NaN
# 87            NaN   NaN        NaN
# 88            NaN   NaN        NaN
# 89            NaN   NaN        NaN
# 90            NaN   NaN        NaN
# 91            NaN   NaN        NaN
# 92            NaN   NaN        NaN
# 93            NaN   NaN        NaN
# 94            NaN   NaN        NaN
# 95            NaN   NaN        NaN
# 96            NaN   NaN        NaN
# 97         603.53  15.0        NaN
# 98         603.53  15.0        NaN
# 99         603.53  15.0        NaN
# 100        603.53  15.0        NaN
# 101        603.17  30.0        NaN
# 102        603.17  30.0        NaN
# 103        603.17  30.0        NaN
# 104        603.17  30.0        NaN
# 105        603.17  30.0        NaN
# 106        603.17  30.0        NaN
# 107        603.17  30.0        NaN
# 108        603.17  30.0        NaN
# 109        603.17  30.0        NaN
# 110        603.17  30.0        NaN
# 111        603.17  30.0        NaN
# 112        603.17  30.0        NaN
# 113        603.17  30.0        NaN
# 114        603.17  30.0        NaN
# 115        603.17  30.0        NaN
# 116        603.17  30.0        NaN
# 117        603.17  30.0        NaN
# 118        604.33  15.0        NaN
# 119        604.33  15.0        NaN
# 120        604.33  15.0        NaN
# 121        604.33  15.0        NaN
# 122        604.33  15.0        NaN
# 123        604.33  15.0        NaN
# 124        604.33  15.0        NaN
# 125        604.33  15.0        NaN
# 126        604.33  15.0        NaN
# 127        604.33  15.0        NaN
# 128        604.33  15.0        NaN
# 129        604.33  15.0        NaN
# 130        604.33  15.0        NaN
# 131           NaN   NaN        NaN
# 132           NaN   NaN        NaN
# 133           NaN   NaN        NaN
# 134           NaN   NaN        NaN
# 135           NaN   NaN        NaN
# 136           NaN   NaN        NaN

# %%
def calculate_percent_change_ibi(signal, time, sniff_start, sampling_rate=100):
    """
    Calculates % change in IBI using:
    - Baseline: -1.5s to -0.5s before sniff
    - Post-sniff: +0.5s to +1.5s after sniff

    Returns:
        float: % change in IBI, or None if not enough peaks
    """
    # Define time windows
    baseline_mask = (time >= sniff_start - 1.5) & (time < sniff_start - 0.5)
    post_mask = (time >= sniff_start + 0.5) & (time < sniff_start + 1.5)

    baseline_segment = signal[baseline_mask]
    post_segment = signal[post_mask]

    min_distance = int(0.2 * sampling_rate)  # at least 200 ms between peaks

    baseline_peaks, _ = find_peaks(baseline_segment, distance=min_distance)
    post_peaks, _ = find_peaks(post_segment, distance=min_distance)

    baseline_peak_times = time[baseline_mask][baseline_peaks]
    post_peak_times = time[post_mask][post_peaks]

    # Calculate IBIs
    baseline_ibis = np.diff(baseline_peak_times)
    post_ibis = np.diff(post_peak_times)

    if len(baseline_ibis) == 0 or len(post_ibis) == 0:
        return None

    baseline_mean_ibi = np.mean(baseline_ibis)
    post_mean_ibi = np.mean(post_ibis)

    percent_change = ((post_mean_ibi - baseline_mean_ibi) / baseline_mean_ibi) * 100
    return percent_change

# %%
sniff_start = agent_sniffs.iloc[0]["Start (s)"]
signal = resp_data["RI2_3_6"]["signal"]
time = resp_data["RI2_3_6"]["time"]
sr = resp_data["RI2_3_6"]["sampling_rate"]

calculate_percent_change_ibi(signal, time, sniff_start, sr)
# Out:
# 9.090909090909086

# %% [markdown]
# baseline_mask = (time >= sniff_start - 1.5) & (time < sniff_start - 0.5)
# post_mask     = (time >= sniff_start + 0.5) & (time < sniff_start + 1.5)
#
# 🟢 These define time windows:
#
# Baseline window = from 1.5s before to 0.5s before the sniff
#
# Post-sniff window = from 0.5s after to 1.5s after the sniff
#
# So we ignore the sniff itself (−0.5 to +0.5), and only look at clean periods before and after.
#
# baseline_peaks, _ = find_peaks(signal[baseline_mask], distance=0.2 * sampling_rate)
# post_peaks, _     = find_peaks(signal[post_mask], distance=0.2 * sampling_rate)
#
# 🟢 This finds breath peaks in the respiration signal during each window:
#
# find_peaks(...) detects upward spikes (inhalations or cycle peaks)
#
# distance=0.2 * sampling_rate means it skips peaks closer than 200 ms apart ask Dan and Nancy about this threshold.
#
# baseline_times = time[baseline_mask][baseline_peaks]
# post_times     = time[post_mask][post_peaks]
#
# 🟢 This gives you the actual time values of those breath peaks (in seconds).
#
# So you now have the times of each breath in each window.
#
# baseline_ibis = np.diff(baseline_times)
# post_ibis     = np.diff(post_times)
#
# 🟢 This calculates the inter-breath intervals (IBIs):
#
# np.diff(...) gives the time between consecutive breaths
#
# if len(baseline_ibis) == 0 or len(post_ibis) == 0:
#     return None
#
# 🛑 Safety check — if no IBIs found in either window (e.g. too few breaths), skip it.
#
# baseline_rate = 1 / np.mean(baseline_ibis)
# post_rate     = 1 / np.mean(post_ibis)
#
# ✅ This converts IBI to breathing rate (Hz):
#
# Rate = 1 / mean IBI
#
# Units = breaths per second
#
# baseline_rate = 1 / np.mean(baseline_ibis)
# post_rate     = 1 / np.mean(post_ibis)
#
# ✅ This converts IBI to breathing rate (Hz):
#
# Rate = 1 / mean IBI
#
# Units = breaths per second
#
# rate_change = (post_rate - baseline_rate) / baseline_rate * 100
#
# 🧮 This computes % change in breathing rate:
#
# Positive = breathing sped up
#
# Negative = breathing slowed down
#
# 🔁 Summary of Logic:
#
# Get time windows before and after sniff
#
# Find breaths in each window
#
# Calculate IBI → convert to rate
#
# Compare post vs. baseline rate
#
# Return % change

# %%
def percent_change_resp_rate(signal, time, sniff_start, sampling_rate=100):
    baseline_mask = (time >= sniff_start - 1.5) & (time < sniff_start - 0.5)
    post_mask = (time >= sniff_start + 0.5) & (time < sniff_start + 1.5)

    baseline_peaks, _ = find_peaks(signal[baseline_mask], distance=0.2 * sampling_rate)
    post_peaks, _ = find_peaks(signal[post_mask], distance=0.2 * sampling_rate)

    baseline_times = time[baseline_mask][baseline_peaks]
    post_times = time[post_mask][post_peaks]

    baseline_ibis = np.diff(baseline_times)
    post_ibis = np.diff(post_times)

    if len(baseline_ibis) == 0 or len(post_ibis) == 0:
        return None

    baseline_rate = 1 / np.mean(baseline_ibis)
    post_rate = 1 / np.mean(post_ibis)

    rate_change = (post_rate - baseline_rate) / baseline_rate * 100
    return rate_change

# %%
sniff_start = agent_sniffs.iloc[0]["Start (s)"]
signal = resp_data["RI2_3_6"]["signal"]
time = resp_data["RI2_3_6"]["time"]
sr = resp_data["RI2_3_6"]["sampling_rate"]

ibi_pct = calculate_percent_change_ibi(signal, time, sniff_start, sr)
rate_pct = percent_change_resp_rate(signal, time, sniff_start, sr)

print(f"% Change in IBI:   {ibi_pct:.2f}%")
print(f"% Change in Rate: {-ibi_pct:.2f}%  <-- inverted")
print(f"% Change in Rate (from rate): {rate_pct:.2f}%")
# Out:
# % Change in IBI:   9.09%
# % Change in Rate: -9.09%  <-- inverted
# % Change in Rate (from rate): -8.33%

# %%
def extract_agent_face_sniffs(df):
    """
    Filters BORIS dataframe for 'Face Sniff' behaviors initiated by the social agent.
    Assumes 'Behavior' and 'Subject' columns exist.
    """
    df = df.copy()
    df['Start (s)'] = df['Start (s)'].astype(float)
    df['Stop (s)'] = df['Stop (s)'].astype(float)
    df = df.sort_values(by='Start (s)').reset_index(drop=True)
    
    # Adjust these string filters to match your BORIS labels
    mask = (df['Behavior'].str.contains("Face Sniff", case=False)) & \
           (df['Subject'].str.lower().str.contains("agent"))
    return df[mask]

# %%
def extract_agent_sniff_events(df):
    """
    Filter BORIS DataFrame for agent-initiated sniffing events (face, body, anogenital).
    """
    sniff_behaviors = ["facial sniffing", "body sniffing", "anogenital sniffing"]
    
    # Ensure consistent capitalization (BORIS might use different cases)
    df["Behavior"] = df["Behavior"].str.lower()
    df["Subject"] = df["Subject"].str.lower()

    agent_sniffs = df[
        (df["Subject"] == "social_agent") &
        (df["Behavior"].isin(sniff_behaviors))
    ].copy()

    return agent_sniffs.reset_index(drop=True)

# %%
def extract_agent_behavior_events(df, behaviors_to_extract):
    """
    Extracts social agent-initiated events from BORIS dataframe for specified behaviors.
    
    Parameters:
        df (pd.DataFrame): BORIS dataframe
        behaviors_to_extract (list of str): List of behaviors to filter (e.g., ["fighting"])
        
    Returns:
        pd.DataFrame: Filtered BORIS events for those behaviors
    """
    return df[
        (df["Subject"].str.lower() == "social_agent") &
        (df["Behavior"].str.lower().isin([b.lower() for b in behaviors_to_extract]))
    ].copy()

# %%
# Select the dataframe
df = RI2_3_6_boris

# Specify the behavior(s) you want to extract
behaviors = ["fighting"]

# Extract the agent-initiated fighting events
agent_fighting = extract_agent_behavior_events(df, behaviors)

# Preview results
print(agent_fighting[["Subject", "Behavior", "Start (s)", "Stop (s)"]])
# Out:
#           Subject  Behavior  Start (s)  Stop (s)
# 25   social_agent  fighting     70.833    80.533
# 27   social_agent  fighting     80.900    81.567
# 30   social_agent  fighting     83.167    83.332
# 49   social_agent  fighting    201.867   207.033
# 51   social_agent  fighting    207.767   211.333
# 55   social_agent  fighting    220.233   222.900
# 57   social_agent  fighting    224.300   225.833
# 60   social_agent  fighting    227.033   228.267
# 73   social_agent  fighting    272.100   272.833
# 76   social_agent  fighting    274.200   281.400
# 83   social_agent  fighting    351.333   371.167
# 85   social_agent  fighting    376.367   384.867
# 87   social_agent  fighting    391.700   396.167
# 92   social_agent  fighting    456.133   456.567
# 94   social_agent  fighting    457.300   464.800
# 96   social_agent  fighting    465.767   470.233
# 103  social_agent  fighting    552.067   553.267
# 108  social_agent  fighting    598.200   608.733

# %%
fighting_results = []

for label, df in ri2_boris_data.items():
    resp_entry = resp_data.get(label)
    if resp_entry is None:
        print(f"Skipping {label}: no respiration data.")
        continue

    # Extract agent-initiated fighting events
    events = extract_agent_behavior_events(df, ["fighting"])
    signal = resp_entry["signal"]
    time = resp_entry["time"]
    sr = resp_entry["sampling_rate"]

    for _, row in events.iterrows():
        sniff_start = row["Start (s)"]
        rate_change = percent_change_resp_rate(signal, time, sniff_start, sr)
        if rate_change is None:
            continue
        fighting_results.append({
            "Trial": label,
            "Condition": "RI2",
            "Behavior": "fighting",
            "Sniff Time (s)": sniff_start,
            "% Change Rate": rate_change
        })

# Combine results into DataFrame
ri2_fighting_df = pd.DataFrame(fighting_results)
print(ri2_fighting_df.head())
# Out:
#      Trial Condition  Behavior  Sniff Time (s)  % Change Rate
# 0  RI2_3_6       RI2  fighting          70.833      -9.638554
# 1  RI2_3_6       RI2  fighting          80.900       7.692308
# 2  RI2_3_6       RI2  fighting          83.167       2.469136
# 3  RI2_3_6       RI2  fighting         201.867     -31.007752
# 4  RI2_3_6       RI2  fighting         207.767     -10.465116

# %%
plt.figure(figsize=(6, 5))
sns.boxplot(
    data=ri2_fighting_df,
    x='Behavior',
    y='% Change Rate',
    color=(169/255,83/255,118/255)  # RI2 color
)
sns.swarmplot(
    data=ri2_fighting_df,
    x='Behavior',
    y='% Change Rate',
    color='k',
    alpha=0.6
)
plt.title("Respiratory Change During Fighting (RI2 Only)")
plt.ylabel("% Change in Respiration Rate")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 6))

sns.stripplot(
    data=combined_df,
    x='Behavior',
    y='% Change Rate',
    hue='Trial',       # This will show different mice (trials)
    jitter=True,
    dodge=True,
    marker='o',
    alpha=0.6
)

plt.title('Mouse-Level % Resp Change by Behavior')
plt.xticks(rotation=30)
plt.axhline(0, color='gray', linestyle='--')  # horizontal line at 0 change
plt.legend(bbox_to_anchor=(1,1), title="Mouse")
plt.tight_layout()
plt.show()

# %%
agent_events = extract_agent_sniff_events(RI2_3_6_boris)
print(agent_events[["Behavior", "Start (s)"]])
# Out:
#                Behavior  Start (s)
# 0       facial sniffing     25.600
# 1         body sniffing     26.167
# 2   anogenital sniffing     26.600
# 3       facial sniffing     68.767
# 4       facial sniffing     91.900
# 5       facial sniffing    153.900
# 6       facial sniffing    156.233
# 7       facial sniffing    195.433
# 8         body sniffing    195.767
# 9       facial sniffing    196.167
# 10        body sniffing    198.333
# 11      facial sniffing    218.300
# 12        body sniffing    219.433
# 13      facial sniffing    226.433
# 14        body sniffing    228.433
# 15  anogenital sniffing    234.167
# 16      facial sniffing    234.867
# 17  anogenital sniffing    235.567
# 18      facial sniffing    249.733
# 19      facial sniffing    257.833
# 20      facial sniffing    267.400
# 21      facial sniffing    269.767
# 22      facial sniffing    273.367
# 23      facial sniffing    282.033
# 24      facial sniffing    288.200
# 25      facial sniffing    290.133
# 26      facial sniffing    318.700
# 27      facial sniffing    343.133
# 28  anogenital sniffing    430.167
# 29  anogenital sniffing    449.800
# 30        body sniffing    455.067
# 31        body sniffing    502.667
# 32      facial sniffing    503.133
# 33  anogenital sniffing    524.333
# 34      facial sniffing    537.000
# 35      facial sniffing    548.033
# 36        body sniffing    550.833
# 37      facial sniffing    554.333
# 38      facial sniffing    559.000
# 39      facial sniffing    596.333

# %%
# Store results in a list
results = []

# Get respiration info for this trial
resp_entry = resp_data["RI2_3_6"]
signal = resp_entry["signal"]
time = resp_entry["time"]
sr = resp_entry["sampling_rate"]

# Loop through all agent sniff events
for idx, row in agent_events.iterrows():
    behavior = row["Behavior"]
    sniff_start = row["Start (s)"]

    # Calculate % change in rate using your function
    rate_change = percent_change_resp_rate(signal, time, sniff_start, sr)

    # Skip if calculation failed (e.g., not enough breaths)
    if rate_change is None:
        continue

    # Store result
    results.append({
        "Trial": "RI2_3_6",
        "Behavior": behavior,
        "Sniff Time (s)": sniff_start,
        "% Change Rate": rate_change
    })

# %%
rate_df = pd.DataFrame(results)
print(rate_df)
# Out:
#       Trial             Behavior  Sniff Time (s)  % Change Rate
# 0   RI2_3_6      facial sniffing          25.600  -1.182432e+01
# 1   RI2_3_6        body sniffing          26.167  -7.602339e+00
# 2   RI2_3_6  anogenital sniffing          26.600   6.578947e+00
# 3   RI2_3_6      facial sniffing          68.767  -4.000000e+00
# 4   RI2_3_6      facial sniffing          91.900   2.740741e+01
# 5   RI2_3_6      facial sniffing         153.900   3.000000e+01
# 6   RI2_3_6      facial sniffing         156.233  -2.840909e+01
# 7   RI2_3_6      facial sniffing         195.433  -2.266667e+01
# 8   RI2_3_6        body sniffing         195.767  -1.919192e+01
# 9   RI2_3_6      facial sniffing         196.167   0.000000e+00
# 10  RI2_3_6        body sniffing         198.333  -1.534392e+01
# 11  RI2_3_6      facial sniffing         218.300   1.612903e+00
# 12  RI2_3_6        body sniffing         219.433  -2.394366e+01
# 13  RI2_3_6      facial sniffing         226.433  -3.493976e+01
# 14  RI2_3_6        body sniffing         228.433   3.833333e+01
# 15  RI2_3_6  anogenital sniffing         234.167   1.712329e+01
# 16  RI2_3_6      facial sniffing         234.867   3.536585e+01
# 17  RI2_3_6  anogenital sniffing         235.567  -3.257576e+01
# 18  RI2_3_6      facial sniffing         249.733  -7.894737e+00
# 19  RI2_3_6      facial sniffing         257.833   7.042254e+00
# 20  RI2_3_6      facial sniffing         267.400  -4.225352e+00
# 21  RI2_3_6      facial sniffing         269.767  -5.632184e+01
# 22  RI2_3_6      facial sniffing         273.367  -4.716981e+01
# 23  RI2_3_6      facial sniffing         282.033  -4.230769e+01
# 24  RI2_3_6      facial sniffing         288.200  -2.125000e+01
# 25  RI2_3_6      facial sniffing         290.133   3.793103e+01
# 26  RI2_3_6      facial sniffing         318.700  -1.176471e+01
# 27  RI2_3_6      facial sniffing         343.133  -9.628964e-12
# 28  RI2_3_6  anogenital sniffing         430.167   6.764706e+01
# 29  RI2_3_6  anogenital sniffing         449.800  -1.272727e+01
# 30  RI2_3_6        body sniffing         455.067   1.007752e+01
# 31  RI2_3_6        body sniffing         502.667   2.613636e+01
# 32  RI2_3_6      facial sniffing         503.133   4.625000e+01
# 33  RI2_3_6  anogenital sniffing         524.333  -7.526882e+00
# 34  RI2_3_6      facial sniffing         537.000  -3.278689e+00
# 35  RI2_3_6      facial sniffing         548.033  -1.549296e+01
# 36  RI2_3_6        body sniffing         550.833  -2.921348e+01
# 37  RI2_3_6      facial sniffing         554.333  -5.747126e+00
# 38  RI2_3_6      facial sniffing         559.000  -1.518987e+01
# 39  RI2_3_6      facial sniffing         596.333   2.222222e+01

# %%
ri2_results = []

# Loop through all RI2 trials dynamically
for label, boris_df in ri2_boris_data.items():
    resp_entry = resp_data.get(label)

    if resp_entry is None:
        print(f"Skipping {label}: no respiration data.")
        continue

    agent_events = extract_agent_sniff_events(boris_df)
    signal = resp_entry["signal"]
    time = resp_entry["time"]
    sr = resp_entry["sampling_rate"]

    for _, row in agent_events.iterrows():
        behavior = row["Behavior"]
        sniff_start = row["Start (s)"]

        rate_change = percent_change_resp_rate(signal, time, sniff_start, sr)
        if rate_change is None:
            continue

        ri2_results.append({
            "Trial": label,
            "Condition": "RI2",
            "Behavior": behavior,
            "Sniff Time (s)": sniff_start,
            "% Change Rate": rate_change
        })

# Convert to DataFrame
ri2_df = pd.DataFrame(ri2_results)
print(ri2_df.head())
# Out:
#      Trial Condition             Behavior  Sniff Time (s)  % Change Rate
# 0  RI2_3_6       RI2      facial sniffing          25.600     -11.824324
# 1  RI2_3_6       RI2        body sniffing          26.167      -7.602339
# 2  RI2_3_6       RI2  anogenital sniffing          26.600       6.578947
# 3  RI2_3_6       RI2      facial sniffing          68.767      -4.000000
# 4  RI2_3_6       RI2      facial sniffing          91.900      27.407407

# %%
ri2_df
# Out:
#        Trial Condition             Behavior  Sniff Time (s)  % Change Rate
# 0    RI2_3_6       RI2      facial sniffing          25.600  -1.182432e+01
# 1    RI2_3_6       RI2        body sniffing          26.167  -7.602339e+00
# 2    RI2_3_6       RI2  anogenital sniffing          26.600   6.578947e+00
# 3    RI2_3_6       RI2      facial sniffing          68.767  -4.000000e+00
# 4    RI2_3_6       RI2      facial sniffing          91.900   2.740741e+01
# 5    RI2_3_6       RI2      facial sniffing         153.900   3.000000e+01
# 6    RI2_3_6       RI2      facial sniffing         156.233  -2.840909e+01
# 7    RI2_3_6       RI2      facial sniffing         195.433  -2.266667e+01
# 8    RI2_3_6       RI2        body sniffing         195.767  -1.919192e+01
# 9    RI2_3_6       RI2      facial sniffing         196.167   0.000000e+00
# 10   RI2_3_6       RI2        body sniffing         198.333  -1.534392e+01
# 11   RI2_3_6       RI2      facial sniffing         218.300   1.612903e+00
# 12   RI2_3_6       RI2        body sniffing         219.433  -2.394366e+01
# 13   RI2_3_6       RI2      facial sniffing         226.433  -3.493976e+01
# 14   RI2_3_6       RI2        body sniffing         228.433   3.833333e+01
# 15   RI2_3_6       RI2  anogenital sniffing         234.167   1.712329e+01
# 16   RI2_3_6       RI2      facial sniffing         234.867   3.536585e+01
# 17   RI2_3_6       RI2  anogenital sniffing         235.567  -3.257576e+01
# 18   RI2_3_6       RI2      facial sniffing         249.733  -7.894737e+00
# 19   RI2_3_6       RI2      facial sniffing         257.833   7.042254e+00
# 20   RI2_3_6       RI2      facial sniffing         267.400  -4.225352e+00
# 21   RI2_3_6       RI2      facial sniffing         269.767  -5.632184e+01
# 22   RI2_3_6       RI2      facial sniffing         273.367  -4.716981e+01
# 23   RI2_3_6       RI2      facial sniffing         282.033  -4.230769e+01
# 24   RI2_3_6       RI2      facial sniffing         288.200  -2.125000e+01
# 25   RI2_3_6       RI2      facial sniffing         290.133   3.793103e+01
# 26   RI2_3_6       RI2      facial sniffing         318.700  -1.176471e+01
# 27   RI2_3_6       RI2      facial sniffing         343.133  -9.628964e-12
# 28   RI2_3_6       RI2  anogenital sniffing         430.167   6.764706e+01
# 29   RI2_3_6       RI2  anogenital sniffing         449.800  -1.272727e+01
# 30   RI2_3_6       RI2        body sniffing         455.067   1.007752e+01
# 31   RI2_3_6       RI2        body sniffing         502.667   2.613636e+01
# 32   RI2_3_6       RI2      facial sniffing         503.133   4.625000e+01
# 33   RI2_3_6       RI2  anogenital sniffing         524.333  -7.526882e+00
# 34   RI2_3_6       RI2      facial sniffing         537.000  -3.278689e+00
# 35   RI2_3_6       RI2      facial sniffing         548.033  -1.549296e+01
# 36   RI2_3_6       RI2        body sniffing         550.833  -2.921348e+01
# 37   RI2_3_6       RI2      facial sniffing         554.333  -5.747126e+00
# 38   RI2_3_6       RI2      facial sniffing         559.000  -1.518987e+01
# 39   RI2_3_6       RI2      facial sniffing         596.333   2.222222e+01
# 40   RI2_4_7       RI2      facial sniffing           6.767   5.063291e+00
# 41   RI2_4_7       RI2      facial sniffing          13.767  -1.250000e+01
# 42   RI2_4_7       RI2      facial sniffing          29.633   3.846154e+00
# 43   RI2_4_7       RI2        body sniffing          30.767  -6.896552e+00
# 44   RI2_4_7       RI2  anogenital sniffing          31.767  -3.046875e+01
# 45   RI2_4_7       RI2        body sniffing          35.133  -1.250000e+00
# 46   RI2_4_7       RI2  anogenital sniffing          36.600  -1.265823e+00
# 47   RI2_4_7       RI2      facial sniffing          37.567   2.162162e+01
# 48   RI2_4_7       RI2      facial sniffing          66.300   2.000000e+01
# 49   RI2_4_7       RI2  anogenital sniffing          69.900  -1.123596e+01
# 50   RI2_4_7       RI2  anogenital sniffing          73.600   4.444444e+01
# 51   RI2_4_7       RI2        body sniffing          75.633  -1.195652e+01
# 52   RI2_4_7       RI2  anogenital sniffing          77.133  -6.024096e-01
# 53   RI2_4_7       RI2      facial sniffing          99.333  -4.814815e+01
# 54   RI2_4_7       RI2        body sniffing         100.100   3.965517e+01
# 55   RI2_4_7       RI2  anogenital sniffing         100.467   1.506849e+01
# 56   RI2_4_7       RI2      facial sniffing         104.067   5.161290e+01
# 57   RI2_4_7       RI2        body sniffing         166.967  -3.703704e+01
# 58   RI2_4_7       RI2  anogenital sniffing         168.900  -1.142857e+01
# 59   RI2_4_7       RI2  anogenital sniffing         171.967   4.285714e+01
# 60   RI2_4_7       RI2  anogenital sniffing         190.433  -6.818182e+00
# 61   RI2_4_7       RI2  anogenital sniffing         214.033   1.750000e+01
# 62   RI2_4_7       RI2        body sniffing         226.633  -1.256831e+01
# 63   RI2_4_7       RI2  anogenital sniffing         227.133   2.564103e+00
# 64   RI2_4_7       RI2  anogenital sniffing         228.533  -6.250000e+00
# 65   RI2_4_7       RI2      facial sniffing         298.300  -6.601562e+01
# 66   RI2_4_7       RI2  anogenital sniffing         305.100  -2.205882e+01
# 67   RI2_4_7       RI2        body sniffing         334.600  -2.150538e+01
# 68   RI2_4_7       RI2      facial sniffing         334.867  -1.363636e+01
# 69   RI2_4_7       RI2        body sniffing         335.600  -5.617978e+00
# 70   RI2_4_7       RI2        body sniffing         367.700  -3.125000e+01
# 71   RI2_4_7       RI2  anogenital sniffing         380.300  -4.054054e+00
# 72   RI2_4_7       RI2  anogenital sniffing         381.732   3.687500e+01
# 73   RI2_4_7       RI2      facial sniffing         409.867  -5.154639e+00
# 74   RI2_4_7       RI2  anogenital sniffing         429.067   8.196721e+00
# 75   RI2_4_7       RI2  anogenital sniffing         446.667   2.368421e+01
# 76   RI2_4_7       RI2      facial sniffing         454.000   7.792208e+00
# 77   RI2_4_7       RI2        body sniffing         462.933   3.103448e+01
# 78   RI2_4_7       RI2        body sniffing         465.967   0.000000e+00
# 79   RI2_4_7       RI2  anogenital sniffing         467.333  -2.900433e+01
# 80   RI2_4_7       RI2        body sniffing         470.533   2.500000e+01
# 81   RI2_4_7       RI2      facial sniffing         471.633  -1.734694e+01
# 82   RI2_4_7       RI2      facial sniffing         472.367   4.347826e+00
# 83   RI2_4_7       RI2      facial sniffing         495.733   1.746032e+01
# 84   RI2_4_7       RI2      facial sniffing         518.200   2.222222e+01
# 85   RI2_4_7       RI2      facial sniffing         535.867   1.960121e-11
# 86   RI2_4_7       RI2      facial sniffing         549.467   1.079545e+01
# 87   RI2_4_7       RI2  anogenital sniffing         556.833  -1.562500e+01
# 88   RI2_4_7       RI2      facial sniffing         561.567   1.355932e+01
# 89   RI2_4_7       RI2        body sniffing         582.600   5.000000e+00
# 90   RI2_4_7       RI2  anogenital sniffing         583.367  -4.400000e+01
# 91   RI2_4_7       RI2      facial sniffing         586.333   1.935484e+01
# 92   RI2_4_7       RI2        body sniffing         586.667   1.694915e+01
# 93   RI2_4_7       RI2      facial sniffing         587.433  -2.972973e+01
# 94   RI2_4_7       RI2        body sniffing         602.500  -1.410256e+01
# 95   RI2_4_7       RI2      facial sniffing         603.533   2.108434e+01
# 96   RI2_4_7       RI2        body sniffing         605.033  -3.333333e+01
# 97   RI2_2_3       RI2        body sniffing           7.655  -2.456140e+01
# 98   RI2_2_3       RI2  anogenital sniffing           9.905   2.289157e+01
# 99   RI2_2_3       RI2        body sniffing          29.155  -1.414474e+01
# 100  RI2_2_3       RI2        body sniffing          33.654   1.803279e+01
# 101  RI2_2_3       RI2  anogenital sniffing         102.655   1.492537e+01
# 102  RI2_2_3       RI2        body sniffing         104.901   4.423077e+01
# 103  RI2_2_3       RI2      facial sniffing         182.405   3.670886e+01
# 104  RI2_2_3       RI2        body sniffing         190.655  -4.583333e+01
# 105  RI2_2_3       RI2      facial sniffing         192.901   2.343750e+01
# 106  RI2_2_3       RI2      facial sniffing         198.155  -5.333333e+00
# 107  RI2_2_3       RI2      facial sniffing         229.533  -4.819277e+00
# 108  RI2_2_3       RI2        body sniffing         230.400   4.615385e+01
# 109  RI2_2_3       RI2        body sniffing         232.700  -1.547619e+01
# 110  RI2_2_3       RI2        body sniffing         238.533  -2.439024e+00
# 111  RI2_2_3       RI2      facial sniffing         239.033   3.947368e+00
# 112  RI2_2_3       RI2      facial sniffing         241.433  -2.469136e+00
# 113  RI2_2_3       RI2        body sniffing         268.157  -3.586498e+01
# 114  RI2_2_3       RI2      facial sniffing         272.656   2.580645e+01
# 115  RI2_2_3       RI2      facial sniffing         281.656   1.111111e+01
# 116  RI2_2_3       RI2        body sniffing         282.155   7.017544e+00
# 117  RI2_2_3       RI2      facial sniffing         282.901   1.600000e+01
# 118  RI2_2_3       RI2        body sniffing         312.154  -5.769231e+00
# 119  RI2_2_3       RI2        body sniffing         343.500  -1.639344e+00
# 120  RI2_2_3       RI2        body sniffing         345.033  -6.250000e+00
# 121  RI2_2_3       RI2      facial sniffing         374.900   4.333333e+01
# 122  RI2_2_3       RI2        body sniffing         377.153  -1.919192e+01
# 123  RI2_2_3       RI2        body sniffing         410.153  -6.896552e+00
# 124  RI2_2_3       RI2        body sniffing         414.902   3.333333e+00
# 125  RI2_2_3       RI2  anogenital sniffing         418.153  -5.649718e-01
# 126  RI2_2_3       RI2        body sniffing         427.653  -3.815789e+01
# 127  RI2_2_3       RI2        body sniffing         435.653   2.613636e+01
# 128  RI2_2_3       RI2        body sniffing         438.153  -2.676056e+01
# 129  RI2_2_3       RI2  anogenital sniffing         461.653  -2.615385e+01
# 130  RI2_2_3       RI2        body sniffing         497.152   1.724138e+00
# 131  RI2_2_3       RI2      facial sniffing         497.903  -2.420091e+01
# 132  RI2_2_3       RI2        body sniffing         524.087   1.282051e+00
# 133  RI2_2_3       RI2        body sniffing         528.086  -1.034483e+01
# 134  RI2_2_3       RI2        body sniffing         529.586  -1.666667e+01
# 135  RI2_2_3       RI2        body sniffing         534.336  -1.814346e+01
# 136  RI2_2_3       RI2  anogenital sniffing         541.933  -1.789474e+01
# 137  RI2_2_3       RI2      facial sniffing         591.087   1.190476e+00
# 138  RI2_2_3       RI2        body sniffing         596.167  -4.083333e+01
# 139  RI2_2_3       RI2        body sniffing         598.800  -2.449799e+01
# 140  RI2_4_8       RI2      facial sniffing           3.333  -2.314815e+01
# 141  RI2_4_8       RI2        body sniffing          16.833  -3.611111e+01
# 142  RI2_4_8       RI2      facial sniffing          18.200  -2.112676e+01
# 143  RI2_4_8       RI2  anogenital sniffing          19.100  -1.034483e+01
# 144  RI2_4_8       RI2  anogenital sniffing          19.900   6.363636e+01
# 145  RI2_4_8       RI2      facial sniffing          27.200   1.388889e+01
# 146  RI2_4_8       RI2        body sniffing          28.900   4.457831e+01
# 147  RI2_4_8       RI2        body sniffing          31.000   0.000000e+00
# 148  RI2_4_8       RI2      facial sniffing          40.967   1.358025e+01
# 149  RI2_4_8       RI2      facial sniffing          59.333  -7.894737e+00
# 150  RI2_4_8       RI2      facial sniffing          61.933   1.234568e+00
# 151  RI2_4_8       RI2  anogenital sniffing          66.033   5.000000e+01
# 152  RI2_4_8       RI2  anogenital sniffing          73.467  -2.314815e+01
# 153  RI2_4_8       RI2  anogenital sniffing          76.033  -3.947368e+00
# 154  RI2_4_8       RI2        body sniffing         100.733   1.764706e+01
# 155  RI2_4_8       RI2      facial sniffing         101.133   8.771930e+00
# 156  RI2_4_8       RI2  anogenital sniffing         111.300  -2.247191e+00
# 157  RI2_4_8       RI2      facial sniffing         113.167  -2.435897e+01
# 158  RI2_4_8       RI2        body sniffing         113.767   3.554217e+01
# 159  RI2_4_8       RI2        body sniffing         131.500   2.857143e+01
# 160  RI2_4_8       RI2  anogenital sniffing         158.733   0.000000e+00
# 161  RI2_4_8       RI2      facial sniffing         165.300   1.264368e+01
# 162  RI2_4_8       RI2  anogenital sniffing         184.100  -3.574297e+01
# 163  RI2_4_8       RI2      facial sniffing         193.100   4.797297e+01
# 164  RI2_4_8       RI2        body sniffing         204.600  -2.857143e+01
# 165  RI2_4_8       RI2      facial sniffing         206.933  -4.758065e+01
# 166  RI2_4_8       RI2  anogenital sniffing         210.100  -1.717172e+01
# 167  RI2_4_8       RI2      facial sniffing         221.000  -2.027027e+01
# 168  RI2_4_8       RI2      facial sniffing         224.267   8.983051e+01
# 169  RI2_4_8       RI2      facial sniffing         235.333  -4.285714e+00
# 170  RI2_4_8       RI2        body sniffing         244.000   3.103448e+01
# 171  RI2_4_8       RI2      facial sniffing         244.300   1.304348e+01
# 172  RI2_4_8       RI2      facial sniffing         250.467   2.026144e+01
# 173  RI2_4_8       RI2      facial sniffing         263.933   1.176471e+01
# 174  RI2_4_8       RI2      facial sniffing         269.000   3.396226e+01
# 175  RI2_4_8       RI2      facial sniffing         274.733   3.333333e+00
# 176  RI2_4_8       RI2        body sniffing         294.433  -1.315789e+01
# 177  RI2_4_8       RI2  anogenital sniffing         295.533  -2.391304e+01
# 178  RI2_4_8       RI2        body sniffing         296.233  -1.159420e+01
# 179  RI2_4_8       RI2      facial sniffing         297.100  -1.587302e+00
# 180  RI2_4_8       RI2  anogenital sniffing         298.000  -1.265823e+00
# 181  RI2_4_8       RI2        body sniffing         314.900  -1.333333e+01
# 182  RI2_4_8       RI2        body sniffing         328.167  -4.761905e+00
# 183  RI2_4_8       RI2      facial sniffing         336.333   2.469136e+00
# 184  RI2_4_8       RI2      facial sniffing         356.167   9.213483e+01
# 185  RI2_4_8       RI2        body sniffing         378.733  -5.954545e+01
# 186  RI2_4_8       RI2      facial sniffing         378.933  -4.276316e+01
# 187  RI2_4_8       RI2        body sniffing         401.533  -1.702128e+01
# 188  RI2_4_8       RI2      facial sniffing         422.433  -8.219178e+00
# 189  RI2_4_8       RI2        body sniffing         423.167  -4.298246e+01
# 190  RI2_4_8       RI2  anogenital sniffing         426.333   7.109375e+01
# 191  RI2_4_8       RI2      facial sniffing         431.767   3.518519e+01
# 192  RI2_4_8       RI2      facial sniffing         452.167  -2.168675e+01
# 193  RI2_4_8       RI2      facial sniffing         457.933   5.263158e+00
# 194  RI2_4_8       RI2  anogenital sniffing         459.400   1.408451e+01
# 195  RI2_4_8       RI2      facial sniffing         477.533  -8.333333e+00
# 196  RI2_4_8       RI2      facial sniffing         488.333   3.186813e+01
# 197  RI2_4_8       RI2        body sniffing         494.167  -3.125000e+00
# 198  RI2_4_8       RI2      facial sniffing         496.633   5.333333e+01
# 199  RI2_4_8       RI2      facial sniffing         498.700   1.190476e+00
# 200  RI2_4_8       RI2      facial sniffing         500.800   3.333333e+01
# 201  RI2_4_8       RI2  anogenital sniffing         523.433   5.633803e+00
# 202  RI2_4_8       RI2      facial sniffing         526.067  -6.493506e-01
# 203  RI2_4_8       RI2      facial sniffing         530.500  -3.412698e+01
# 204  RI2_4_8       RI2      facial sniffing         532.167   8.474576e+00
# 205  RI2_4_8       RI2      facial sniffing         547.367  -3.797468e+00
# 206  RI2_4_8       RI2      facial sniffing         557.367  -2.747253e+01
# 207  RI2_4_8       RI2        body sniffing         557.600  -1.397849e+01
# 208  RI2_4_8       RI2      facial sniffing         558.167   2.307692e+01
# 209  RI2_1_1       RI2        body sniffing          11.533   1.126761e+01
# 210  RI2_1_1       RI2        body sniffing          38.467   0.000000e+00
# 211  RI2_1_1       RI2        body sniffing          83.933  -1.809524e+01
# 212  RI2_1_1       RI2      facial sniffing         126.933  -2.790698e+01
# 213  RI2_1_1       RI2        body sniffing         130.000   1.746988e+01
# 214  RI2_1_1       RI2        body sniffing         132.133  -2.888889e+01
# 215  RI2_1_1       RI2        body sniffing         228.400  -2.612613e+01
# 216  RI2_1_1       RI2        body sniffing         241.467  -2.807018e+01
# 217  RI2_1_1       RI2      facial sniffing         341.571  -5.952381e+00
# 218  RI2_1_1       RI2        body sniffing         349.071   2.142857e+01
# 219  RI2_1_1       RI2      facial sniffing         358.570  -1.111111e+01
# 220  RI2_1_1       RI2        body sniffing         420.069   2.542373e+01
# 221  RI2_1_1       RI2        body sniffing         427.071  -4.705882e+00
# 222  RI2_1_1       RI2        body sniffing         472.322   1.739130e+01
# 223  RI2_1_1       RI2        body sniffing         475.821  -1.500000e+01
# 224  RI2_1_1       RI2        body sniffing         528.822  -3.833333e+01
# 225  RI2_1_1       RI2      facial sniffing         582.324   3.312500e+01
# 226  RI2_1_1       RI2        body sniffing         582.818  -4.918033e+00
# 227  RI2_1_2       RI2      facial sniffing           8.067  -1.720430e+01
# 228  RI2_1_2       RI2      facial sniffing          99.933  -3.846154e+01
# 229  RI2_1_2       RI2        body sniffing         149.133  -5.194805e+00
# 230  RI2_1_2       RI2      facial sniffing         158.433  -1.666667e+01
# 231  RI2_1_2       RI2        body sniffing         160.167  -2.272727e+00
# 232  RI2_1_2       RI2      facial sniffing         163.700  -3.833333e+01
# 233  RI2_1_2       RI2      facial sniffing         164.200  -1.428571e+00
# 234  RI2_1_2       RI2        body sniffing         164.833  -1.372549e+01
# 235  RI2_1_2       RI2  anogenital sniffing         199.155   1.551724e+01
# 236  RI2_1_2       RI2  anogenital sniffing         202.155   2.027027e+01
# 237  RI2_1_2       RI2        body sniffing         203.667   1.633987e+01
# 238  RI2_1_2       RI2      facial sniffing         204.200  -1.333333e+00
# 239  RI2_1_2       RI2      facial sniffing         208.133   2.531646e+00
# 240  RI2_1_2       RI2        body sniffing         243.155  -2.021858e+01
# 241  RI2_1_2       RI2      facial sniffing         245.154  -8.955224e+00
# 242  RI2_1_2       RI2      facial sniffing         250.655   1.071429e+01
# 243  RI2_1_2       RI2        body sniffing         284.306  -2.000000e+01
# 244  RI2_1_2       RI2      facial sniffing         287.055   1.208333e+02
# 245  RI2_1_2       RI2        body sniffing         308.033   3.636364e+01
# 246  RI2_1_2       RI2  anogenital sniffing         310.467   7.801418e+00
# 247  RI2_1_2       RI2        body sniffing         310.867   2.340426e+01
# 248  RI2_1_2       RI2        body sniffing         314.933   4.615385e+00
# 249  RI2_1_2       RI2      facial sniffing         316.767   2.214286e+01
# 250  RI2_1_2       RI2        body sniffing         319.033   1.351351e+00
# 251  RI2_1_2       RI2      facial sniffing         319.867  -1.014493e+01
# 252  RI2_1_2       RI2        body sniffing         321.800   1.470588e+00
# 253  RI2_1_2       RI2        body sniffing         323.000   3.561644e+01
# 254  RI2_1_2       RI2  anogenital sniffing         324.600  -1.965812e+01
# 255  RI2_1_2       RI2        body sniffing         325.400  -8.653846e+00
# 256  RI2_1_2       RI2        body sniffing         327.733   2.777778e+00
# 257  RI2_1_2       RI2  anogenital sniffing         330.100  -1.970588e+01
# 258  RI2_1_2       RI2        body sniffing         332.000  -4.054054e+00
# 259  RI2_1_2       RI2  anogenital sniffing         333.233  -2.272727e+00
# 260  RI2_1_2       RI2      facial sniffing         395.057   1.117647e+01
# 261  RI2_1_2       RI2      facial sniffing         403.804   6.626506e+00
# 262  RI2_1_2       RI2        body sniffing         452.556   1.166667e+01
# 263  RI2_1_2       RI2        body sniffing         460.804  -1.111111e+01
# 264  RI2_1_2       RI2        body sniffing         495.805  -1.402439e+01
# 265  RI2_1_2       RI2        body sniffing         498.055  -1.718750e+01
# 266  RI2_1_2       RI2      facial sniffing         499.301  -1.333333e+00
# 267  RI2_1_2       RI2        body sniffing         511.307   7.692308e+00
# 268  RI2_1_2       RI2  anogenital sniffing         518.302  -1.643836e+01
# 269  RI2_1_2       RI2        body sniffing         523.056   5.063291e+00
# 270  RI2_1_2       RI2      facial sniffing         558.304  -3.529412e+00
# 271  RI2_1_2       RI2        body sniffing         560.550  -8.457711e+00
# 272  RI2_1_2       RI2      facial sniffing         565.052   2.328767e+01
# 273  RI2_1_2       RI2        body sniffing         581.000  -2.626263e+01
# 274  RI2_2_4       RI2        body sniffing           5.933  -2.134831e+01
# 275  RI2_2_4       RI2  anogenital sniffing           7.333  -2.602740e+01
# 276  RI2_2_4       RI2        body sniffing           7.867   3.653846e+01
# 277  RI2_2_4       RI2      facial sniffing           9.200  -2.511416e+01
# 278  RI2_2_4       RI2      facial sniffing          10.133  -1.219512e+01
# 279  RI2_2_4       RI2        body sniffing          12.667  -9.677419e+00
# 280  RI2_2_4       RI2  anogenital sniffing          13.333  -3.846154e+00
# 281  RI2_2_4       RI2        body sniffing          14.267   1.190476e+00
# 282  RI2_2_4       RI2        body sniffing          14.733   1.746988e+01
# 283  RI2_2_4       RI2        body sniffing          17.467   1.250000e+01
# 284  RI2_2_4       RI2        body sniffing          26.867   8.333333e+00
# 285  RI2_2_4       RI2  anogenital sniffing          30.400   1.186441e+01
# 286  RI2_2_4       RI2        body sniffing          30.867  -1.812865e+01
# 287  RI2_2_4       RI2      facial sniffing          64.400  -7.500000e+00
# 288  RI2_2_4       RI2  anogenital sniffing          68.600   7.462687e+00
# 289  RI2_2_4       RI2      facial sniffing          77.267   5.000000e+00
# 290  RI2_2_4       RI2        body sniffing          79.933  -1.666667e+01
# 291  RI2_2_4       RI2      facial sniffing         122.467   1.694915e+00
# 292  RI2_2_4       RI2        body sniffing         141.667   5.362319e+01
# 293  RI2_2_4       RI2      facial sniffing         142.933   4.705882e+00
# 294  RI2_2_4       RI2      facial sniffing         146.733   1.686047e+01
# 295  RI2_2_4       RI2      facial sniffing         149.733   5.128205e+00
# 296  RI2_2_4       RI2        body sniffing         177.867   1.129032e+01
# 297  RI2_2_4       RI2        body sniffing         183.533  -3.000000e+01
# 298  RI2_2_4       RI2        body sniffing         211.800  -2.894737e+01
# 299  RI2_2_4       RI2        body sniffing         217.067   4.308554e-12
# 300  RI2_2_4       RI2        body sniffing         220.000   1.690141e+01
# 301  RI2_2_4       RI2  anogenital sniffing         235.267  -3.950617e+01
# 302  RI2_2_4       RI2        body sniffing         236.067   9.259259e+00
# 303  RI2_2_4       RI2        body sniffing         239.933   3.392857e+01
# 304  RI2_2_4       RI2  anogenital sniffing         242.333   5.692308e+01
# 305  RI2_2_4       RI2        body sniffing         260.667  -4.807692e+01
# 306  RI2_2_4       RI2        body sniffing         269.067   4.651163e+00
# 307  RI2_2_4       RI2        body sniffing         272.933   1.016949e+01
# 308  RI2_2_4       RI2        body sniffing         287.267  -2.898551e+00
# 309  RI2_2_4       RI2        body sniffing         296.400   3.015873e+01
# 310  RI2_2_4       RI2  anogenital sniffing         301.867  -2.409639e+00
# 311  RI2_2_4       RI2      facial sniffing         302.467   2.446809e+01
# 312  RI2_2_4       RI2        body sniffing         329.400   1.406250e+01
# 313  RI2_2_4       RI2        body sniffing         344.400   3.125000e+00
# 314  RI2_2_4       RI2      facial sniffing         345.800   1.451613e+01
# 315  RI2_2_4       RI2        body sniffing         346.800  -1.527778e+01
# 316  RI2_2_4       RI2        body sniffing         350.800   9.090909e+00
# 317  RI2_2_4       RI2        body sniffing         368.800  -2.649573e+01
# 318  RI2_2_4       RI2        body sniffing         376.133   4.451220e+01
# 319  RI2_2_4       RI2      facial sniffing         513.867   2.033898e+01
# 320  RI2_2_4       RI2        body sniffing         544.933  -9.195402e+00
# 321  RI2_2_4       RI2      facial sniffing         565.067  -4.597701e+00
# 322  RI2_2_4       RI2      facial sniffing         580.933  -6.557377e+00
# 323  RI2_2_4       RI2        body sniffing         601.333   2.108434e+01
# 324  RI2_3_5       RI2      facial sniffing           4.067   2.034884e+01
# 325  RI2_3_5       RI2        body sniffing           4.467  -1.075269e+01
# 326  RI2_3_5       RI2      facial sniffing          12.033  -1.549296e+01
# 327  RI2_3_5       RI2      facial sniffing          32.900   1.639344e+01
# 328  RI2_3_5       RI2      facial sniffing          55.800   1.022727e+01
# 329  RI2_3_5       RI2        body sniffing          80.733   5.479452e+00
# 330  RI2_3_5       RI2        body sniffing         170.900  -5.952381e+00
# 331  RI2_3_5       RI2      facial sniffing         203.600  -2.478632e+01
# 332  RI2_3_5       RI2      facial sniffing         207.433   4.687500e+00

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.boxplot(
    data=ri2_df, 
    x='Behavior', 
    y='% Change Rate', 
    hue='Condition'
)
plt.title('Respiratory Rate % Change by Behavior and Condition')
plt.xticks(rotation=30)
plt.ylabel('Percent Change in Respiration Rate')
plt.xlabel('Behavior Type')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.stripplot(
    data=ri2_df,
    x='Behavior',
    y='% Change Rate',
    hue='Condition',
    jitter=True,
    dodge=True
)
plt.title('Individual Respiratory Rate Changes per Event')
plt.xticks(rotation=30)
plt.ylabel('Percent Change in Respiration Rate')
plt.xlabel('Behavior Type')
plt.tight_layout()
plt.show()

# %%
ri1_results = []

for label in ["RI1_3_6", "RI1_4_7", "RI1_2_3", "RI1_4_8"]:
    boris_df = globals()[label + "_boris"]  # grab the BORIS dataframe by variable name
    resp_entry = resp_data.get(label)

    if resp_entry is None:
        print(f"Skipping {label}: no respiration data.")
        continue

    agent_events = extract_agent_sniff_events(boris_df)
    signal = resp_entry["signal"]
    time = resp_entry["time"]
    sr = resp_entry["sampling_rate"]

    for _, row in agent_events.iterrows():
        behavior = row["Behavior"]
        sniff_start = row["Start (s)"]

        rate_change = percent_change_resp_rate(signal, time, sniff_start, sr)
        if rate_change is None:
            continue

        ri1_results.append({
            "Trial": label,
            "Condition": "RI1",
            "Behavior": behavior,
            "Sniff Time (s)": sniff_start,
            "% Change Rate": rate_change
        })

ri1_df = pd.DataFrame(ri1_results)
print(ri1_df.head())
# Out:
#      Trial Condition             Behavior  Sniff Time (s)  % Change Rate
# 0  RI1_3_6       RI1  anogenital sniffing           8.862     -15.789474
# 1  RI1_3_6       RI1      facial sniffing          12.069       0.000000
# 2  RI1_3_6       RI1  anogenital sniffing          80.310      -8.474576
# 3  RI1_3_6       RI1      facial sniffing          86.207       1.388889
# 4  RI1_3_6       RI1      facial sniffing          88.034     -16.666667

# %%
ri1_df
# Out:
#       Trial Condition             Behavior  Sniff Time (s)  % Change Rate
# 0   RI1_3_6       RI1  anogenital sniffing           8.862  -1.578947e+01
# 1   RI1_3_6       RI1      facial sniffing          12.069   0.000000e+00
# 2   RI1_3_6       RI1  anogenital sniffing          80.310  -8.474576e+00
# 3   RI1_3_6       RI1      facial sniffing          86.207   1.388889e+00
# 4   RI1_3_6       RI1      facial sniffing          88.034  -1.666667e+01
# 5   RI1_3_6       RI1  anogenital sniffing          90.690  -2.156863e+01
# 6   RI1_3_6       RI1      facial sniffing         107.724  -3.059361e+01
# 7   RI1_3_6       RI1      facial sniffing         183.724  -1.250000e+01
# 8   RI1_3_6       RI1      facial sniffing         200.517   4.805195e+01
# 9   RI1_3_6       RI1      facial sniffing         217.172   1.733333e+01
# 10  RI1_3_6       RI1      facial sniffing         229.897   2.800000e+01
# 11  RI1_3_6       RI1      facial sniffing         243.793   5.172414e+00
# 12  RI1_3_6       RI1  anogenital sniffing         260.862   5.205479e+01
# 13  RI1_3_6       RI1      facial sniffing         337.172  -2.207792e+01
# 14  RI1_3_6       RI1      facial sniffing         367.345  -5.813953e+00
# 15  RI1_3_6       RI1      facial sniffing         368.483   3.986486e+01
# 16  RI1_3_6       RI1        body sniffing         404.310   6.250000e+00
# 17  RI1_3_6       RI1      facial sniffing         416.414  -3.466667e+01
# 18  RI1_3_6       RI1        body sniffing         596.931   1.481481e+01
# 19  RI1_3_6       RI1  anogenital sniffing         597.517  -1.136364e+01
# 20  RI1_3_6       RI1      facial sniffing         598.034  -2.872340e+01
# 21  RI1_4_7       RI1      facial sniffing           8.167   1.678657e-13
# 22  RI1_4_7       RI1      facial sniffing          24.467  -9.302326e+00
# 23  RI1_4_7       RI1  anogenital sniffing         346.067   6.976744e+00
# 24  RI1_4_7       RI1      facial sniffing         365.033   1.954023e+01
# 25  RI1_4_7       RI1      facial sniffing         452.867  -7.058824e+00
# 26  RI1_4_7       RI1      facial sniffing         480.500   7.602339e+00
# 27  RI1_4_7       RI1      facial sniffing         483.067   1.576087e+01
# 28  RI1_2_3       RI1      facial sniffing          72.223  -1.351351e+00
# 29  RI1_2_3       RI1        body sniffing          75.723   1.481481e+01
# 30  RI1_2_3       RI1        body sniffing          80.222   5.361446e+01
# 31  RI1_2_3       RI1  anogenital sniffing          85.222  -3.571429e-01
# 32  RI1_2_3       RI1        body sniffing         145.222  -1.298701e+01
# 33  RI1_2_3       RI1        body sniffing         249.222   2.197802e+01
# 34  RI1_4_8       RI1      facial sniffing           5.733   7.792208e+00
# 35  RI1_4_8       RI1      facial sniffing          17.167  -2.112676e+01
# 36  RI1_4_8       RI1  anogenital sniffing          18.700   2.313433e+01
# 37  RI1_4_8       RI1        body sniffing          35.133  -2.747253e+00
# 38  RI1_4_8       RI1  anogenital sniffing          35.600   4.451220e+01
# 39  RI1_4_8       RI1      facial sniffing          37.400  -1.392405e+01
# 40  RI1_4_8       RI1  anogenital sniffing          44.800   1.137757e-12
# 41  RI1_4_8       RI1      facial sniffing          52.733  -1.149425e+01
# 42  RI1_4_8       RI1      facial sniffing          56.400   2.321429e+01
# 43  RI1_4_8       RI1      facial sniffing          62.700   3.392857e+01
# 44  RI1_4_8       RI1      facial sniffing          77.267  -1.785714e+01
# 45  RI1_4_8       RI1      facial sniffing          85.367   7.792208e+00
# 46  RI1_4_8       RI1      facial sniffing         138.200   1.292517e+01
# 47  RI1_4_8       RI1        body sniffing         174.400  -1.219512e+00
# 48  RI1_4_8       RI1  anogenital sniffing         176.133   0.000000e+00
# 49  RI1_4_8       RI1        body sniffing         176.200   0.000000e+00
# 50  RI1_4_8       RI1  anogenital sniffing         185.467   7.792208e+00
# 51  RI1_4_8       RI1  anogenital sniffing         203.733  -8.433735e+00
# 52  RI1_4_8       RI1        body sniffing         234.067  -4.649123e+01
# 53  RI1_4_8       RI1      facial sniffing         324.800  -1.555556e+01
# 54  RI1_4_8       RI1        body sniffing         344.567  -1.746032e+01
# 55  RI1_4_8       RI1      facial sniffing         363.500  -4.597701e+00
# 56  RI1_4_8       RI1      facial sniffing         390.367  -3.148148e+01
# 57  RI1_4_8       RI1      facial sniffing         455.933   3.012048e+01
# 58  RI1_4_8       RI1        body sniffing         463.733   2.325581e+00
# 59  RI1_4_8       RI1      facial sniffing         531.600   3.098592e+01

# %%
combined_df = pd.concat([ri1_df, ri2_df], ignore_index=True)
print(combined_df.head())
# Out:
#      Trial Condition             Behavior  Sniff Time (s)  % Change Rate
# 0  RI1_3_6       RI1  anogenital sniffing           8.862     -15.789474
# 1  RI1_3_6       RI1      facial sniffing          12.069       0.000000
# 2  RI1_3_6       RI1  anogenital sniffing          80.310      -8.474576
# 3  RI1_3_6       RI1      facial sniffing          86.207       1.388889
# 4  RI1_3_6       RI1      facial sniffing          88.034     -16.666667

# %%
combined_df
# Out:
#        Trial Condition             Behavior  Sniff Time (s)  % Change Rate
# 0    RI1_3_6       RI1  anogenital sniffing           8.862  -1.578947e+01
# 1    RI1_3_6       RI1      facial sniffing          12.069   0.000000e+00
# 2    RI1_3_6       RI1  anogenital sniffing          80.310  -8.474576e+00
# 3    RI1_3_6       RI1      facial sniffing          86.207   1.388889e+00
# 4    RI1_3_6       RI1      facial sniffing          88.034  -1.666667e+01
# 5    RI1_3_6       RI1  anogenital sniffing          90.690  -2.156863e+01
# 6    RI1_3_6       RI1      facial sniffing         107.724  -3.059361e+01
# 7    RI1_3_6       RI1      facial sniffing         183.724  -1.250000e+01
# 8    RI1_3_6       RI1      facial sniffing         200.517   4.805195e+01
# 9    RI1_3_6       RI1      facial sniffing         217.172   1.733333e+01
# 10   RI1_3_6       RI1      facial sniffing         229.897   2.800000e+01
# 11   RI1_3_6       RI1      facial sniffing         243.793   5.172414e+00
# 12   RI1_3_6       RI1  anogenital sniffing         260.862   5.205479e+01
# 13   RI1_3_6       RI1      facial sniffing         337.172  -2.207792e+01
# 14   RI1_3_6       RI1      facial sniffing         367.345  -5.813953e+00
# 15   RI1_3_6       RI1      facial sniffing         368.483   3.986486e+01
# 16   RI1_3_6       RI1        body sniffing         404.310   6.250000e+00
# 17   RI1_3_6       RI1      facial sniffing         416.414  -3.466667e+01
# 18   RI1_3_6       RI1        body sniffing         596.931   1.481481e+01
# 19   RI1_3_6       RI1  anogenital sniffing         597.517  -1.136364e+01
# 20   RI1_3_6       RI1      facial sniffing         598.034  -2.872340e+01
# 21   RI1_4_7       RI1      facial sniffing           8.167   1.678657e-13
# 22   RI1_4_7       RI1      facial sniffing          24.467  -9.302326e+00
# 23   RI1_4_7       RI1  anogenital sniffing         346.067   6.976744e+00
# 24   RI1_4_7       RI1      facial sniffing         365.033   1.954023e+01
# 25   RI1_4_7       RI1      facial sniffing         452.867  -7.058824e+00
# 26   RI1_4_7       RI1      facial sniffing         480.500   7.602339e+00
# 27   RI1_4_7       RI1      facial sniffing         483.067   1.576087e+01
# 28   RI1_2_3       RI1      facial sniffing          72.223  -1.351351e+00
# 29   RI1_2_3       RI1        body sniffing          75.723   1.481481e+01
# 30   RI1_2_3       RI1        body sniffing          80.222   5.361446e+01
# 31   RI1_2_3       RI1  anogenital sniffing          85.222  -3.571429e-01
# 32   RI1_2_3       RI1        body sniffing         145.222  -1.298701e+01
# 33   RI1_2_3       RI1        body sniffing         249.222   2.197802e+01
# 34   RI1_4_8       RI1      facial sniffing           5.733   7.792208e+00
# 35   RI1_4_8       RI1      facial sniffing          17.167  -2.112676e+01
# 36   RI1_4_8       RI1  anogenital sniffing          18.700   2.313433e+01
# 37   RI1_4_8       RI1        body sniffing          35.133  -2.747253e+00
# 38   RI1_4_8       RI1  anogenital sniffing          35.600   4.451220e+01
# 39   RI1_4_8       RI1      facial sniffing          37.400  -1.392405e+01
# 40   RI1_4_8       RI1  anogenital sniffing          44.800   1.137757e-12
# 41   RI1_4_8       RI1      facial sniffing          52.733  -1.149425e+01
# 42   RI1_4_8       RI1      facial sniffing          56.400   2.321429e+01
# 43   RI1_4_8       RI1      facial sniffing          62.700   3.392857e+01
# 44   RI1_4_8       RI1      facial sniffing          77.267  -1.785714e+01
# 45   RI1_4_8       RI1      facial sniffing          85.367   7.792208e+00
# 46   RI1_4_8       RI1      facial sniffing         138.200   1.292517e+01
# 47   RI1_4_8       RI1        body sniffing         174.400  -1.219512e+00
# 48   RI1_4_8       RI1  anogenital sniffing         176.133   0.000000e+00
# 49   RI1_4_8       RI1        body sniffing         176.200   0.000000e+00
# 50   RI1_4_8       RI1  anogenital sniffing         185.467   7.792208e+00
# 51   RI1_4_8       RI1  anogenital sniffing         203.733  -8.433735e+00
# 52   RI1_4_8       RI1        body sniffing         234.067  -4.649123e+01
# 53   RI1_4_8       RI1      facial sniffing         324.800  -1.555556e+01
# 54   RI1_4_8       RI1        body sniffing         344.567  -1.746032e+01
# 55   RI1_4_8       RI1      facial sniffing         363.500  -4.597701e+00
# 56   RI1_4_8       RI1      facial sniffing         390.367  -3.148148e+01
# 57   RI1_4_8       RI1      facial sniffing         455.933   3.012048e+01
# 58   RI1_4_8       RI1        body sniffing         463.733   2.325581e+00
# 59   RI1_4_8       RI1      facial sniffing         531.600   3.098592e+01
# 60   RI2_3_6       RI2      facial sniffing          25.600  -1.182432e+01
# 61   RI2_3_6       RI2        body sniffing          26.167  -7.602339e+00
# 62   RI2_3_6       RI2  anogenital sniffing          26.600   6.578947e+00
# 63   RI2_3_6       RI2      facial sniffing          68.767  -4.000000e+00
# 64   RI2_3_6       RI2      facial sniffing          91.900   2.740741e+01
# 65   RI2_3_6       RI2      facial sniffing         153.900   3.000000e+01
# 66   RI2_3_6       RI2      facial sniffing         156.233  -2.840909e+01
# 67   RI2_3_6       RI2      facial sniffing         195.433  -2.266667e+01
# 68   RI2_3_6       RI2        body sniffing         195.767  -1.919192e+01
# 69   RI2_3_6       RI2      facial sniffing         196.167   0.000000e+00
# 70   RI2_3_6       RI2        body sniffing         198.333  -1.534392e+01
# 71   RI2_3_6       RI2      facial sniffing         218.300   1.612903e+00
# 72   RI2_3_6       RI2        body sniffing         219.433  -2.394366e+01
# 73   RI2_3_6       RI2      facial sniffing         226.433  -3.493976e+01
# 74   RI2_3_6       RI2        body sniffing         228.433   3.833333e+01
# 75   RI2_3_6       RI2  anogenital sniffing         234.167   1.712329e+01
# 76   RI2_3_6       RI2      facial sniffing         234.867   3.536585e+01
# 77   RI2_3_6       RI2  anogenital sniffing         235.567  -3.257576e+01
# 78   RI2_3_6       RI2      facial sniffing         249.733  -7.894737e+00
# 79   RI2_3_6       RI2      facial sniffing         257.833   7.042254e+00
# 80   RI2_3_6       RI2      facial sniffing         267.400  -4.225352e+00
# 81   RI2_3_6       RI2      facial sniffing         269.767  -5.632184e+01
# 82   RI2_3_6       RI2      facial sniffing         273.367  -4.716981e+01
# 83   RI2_3_6       RI2      facial sniffing         282.033  -4.230769e+01
# 84   RI2_3_6       RI2      facial sniffing         288.200  -2.125000e+01
# 85   RI2_3_6       RI2      facial sniffing         290.133   3.793103e+01
# 86   RI2_3_6       RI2      facial sniffing         318.700  -1.176471e+01
# 87   RI2_3_6       RI2      facial sniffing         343.133  -9.628964e-12
# 88   RI2_3_6       RI2  anogenital sniffing         430.167   6.764706e+01
# 89   RI2_3_6       RI2  anogenital sniffing         449.800  -1.272727e+01
# 90   RI2_3_6       RI2        body sniffing         455.067   1.007752e+01
# 91   RI2_3_6       RI2        body sniffing         502.667   2.613636e+01
# 92   RI2_3_6       RI2      facial sniffing         503.133   4.625000e+01
# 93   RI2_3_6       RI2  anogenital sniffing         524.333  -7.526882e+00
# 94   RI2_3_6       RI2      facial sniffing         537.000  -3.278689e+00
# 95   RI2_3_6       RI2      facial sniffing         548.033  -1.549296e+01
# 96   RI2_3_6       RI2        body sniffing         550.833  -2.921348e+01
# 97   RI2_3_6       RI2      facial sniffing         554.333  -5.747126e+00
# 98   RI2_3_6       RI2      facial sniffing         559.000  -1.518987e+01
# 99   RI2_3_6       RI2      facial sniffing         596.333   2.222222e+01
# 100  RI2_4_7       RI2      facial sniffing           6.767   5.063291e+00
# 101  RI2_4_7       RI2      facial sniffing          13.767  -1.250000e+01
# 102  RI2_4_7       RI2      facial sniffing          29.633   3.846154e+00
# 103  RI2_4_7       RI2        body sniffing          30.767  -6.896552e+00
# 104  RI2_4_7       RI2  anogenital sniffing          31.767  -3.046875e+01
# 105  RI2_4_7       RI2        body sniffing          35.133  -1.250000e+00
# 106  RI2_4_7       RI2  anogenital sniffing          36.600  -1.265823e+00
# 107  RI2_4_7       RI2      facial sniffing          37.567   2.162162e+01
# 108  RI2_4_7       RI2      facial sniffing          66.300   2.000000e+01
# 109  RI2_4_7       RI2  anogenital sniffing          69.900  -1.123596e+01
# 110  RI2_4_7       RI2  anogenital sniffing          73.600   4.444444e+01
# 111  RI2_4_7       RI2        body sniffing          75.633  -1.195652e+01
# 112  RI2_4_7       RI2  anogenital sniffing          77.133  -6.024096e-01
# 113  RI2_4_7       RI2      facial sniffing          99.333  -4.814815e+01
# 114  RI2_4_7       RI2        body sniffing         100.100   3.965517e+01
# 115  RI2_4_7       RI2  anogenital sniffing         100.467   1.506849e+01
# 116  RI2_4_7       RI2      facial sniffing         104.067   5.161290e+01
# 117  RI2_4_7       RI2        body sniffing         166.967  -3.703704e+01
# 118  RI2_4_7       RI2  anogenital sniffing         168.900  -1.142857e+01
# 119  RI2_4_7       RI2  anogenital sniffing         171.967   4.285714e+01
# 120  RI2_4_7       RI2  anogenital sniffing         190.433  -6.818182e+00
# 121  RI2_4_7       RI2  anogenital sniffing         214.033   1.750000e+01
# 122  RI2_4_7       RI2        body sniffing         226.633  -1.256831e+01
# 123  RI2_4_7       RI2  anogenital sniffing         227.133   2.564103e+00
# 124  RI2_4_7       RI2  anogenital sniffing         228.533  -6.250000e+00
# 125  RI2_4_7       RI2      facial sniffing         298.300  -6.601562e+01
# 126  RI2_4_7       RI2  anogenital sniffing         305.100  -2.205882e+01
# 127  RI2_4_7       RI2        body sniffing         334.600  -2.150538e+01
# 128  RI2_4_7       RI2      facial sniffing         334.867  -1.363636e+01
# 129  RI2_4_7       RI2        body sniffing         335.600  -5.617978e+00
# 130  RI2_4_7       RI2        body sniffing         367.700  -3.125000e+01
# 131  RI2_4_7       RI2  anogenital sniffing         380.300  -4.054054e+00
# 132  RI2_4_7       RI2  anogenital sniffing         381.732   3.687500e+01
# 133  RI2_4_7       RI2      facial sniffing         409.867  -5.154639e+00
# 134  RI2_4_7       RI2  anogenital sniffing         429.067   8.196721e+00
# 135  RI2_4_7       RI2  anogenital sniffing         446.667   2.368421e+01
# 136  RI2_4_7       RI2      facial sniffing         454.000   7.792208e+00
# 137  RI2_4_7       RI2        body sniffing         462.933   3.103448e+01
# 138  RI2_4_7       RI2        body sniffing         465.967   0.000000e+00
# 139  RI2_4_7       RI2  anogenital sniffing         467.333  -2.900433e+01
# 140  RI2_4_7       RI2        body sniffing         470.533   2.500000e+01
# 141  RI2_4_7       RI2      facial sniffing         471.633  -1.734694e+01
# 142  RI2_4_7       RI2      facial sniffing         472.367   4.347826e+00
# 143  RI2_4_7       RI2      facial sniffing         495.733   1.746032e+01
# 144  RI2_4_7       RI2      facial sniffing         518.200   2.222222e+01
# 145  RI2_4_7       RI2      facial sniffing         535.867   1.960121e-11
# 146  RI2_4_7       RI2      facial sniffing         549.467   1.079545e+01
# 147  RI2_4_7       RI2  anogenital sniffing         556.833  -1.562500e+01
# 148  RI2_4_7       RI2      facial sniffing         561.567   1.355932e+01
# 149  RI2_4_7       RI2        body sniffing         582.600   5.000000e+00
# 150  RI2_4_7       RI2  anogenital sniffing         583.367  -4.400000e+01
# 151  RI2_4_7       RI2      facial sniffing         586.333   1.935484e+01
# 152  RI2_4_7       RI2        body sniffing         586.667   1.694915e+01
# 153  RI2_4_7       RI2      facial sniffing         587.433  -2.972973e+01
# 154  RI2_4_7       RI2        body sniffing         602.500  -1.410256e+01
# 155  RI2_4_7       RI2      facial sniffing         603.533   2.108434e+01
# 156  RI2_4_7       RI2        body sniffing         605.033  -3.333333e+01
# 157  RI2_2_3       RI2        body sniffing           7.655  -2.456140e+01
# 158  RI2_2_3       RI2  anogenital sniffing           9.905   2.289157e+01
# 159  RI2_2_3       RI2        body sniffing          29.155  -1.414474e+01
# 160  RI2_2_3       RI2        body sniffing          33.654   1.803279e+01
# 161  RI2_2_3       RI2  anogenital sniffing         102.655   1.492537e+01
# 162  RI2_2_3       RI2        body sniffing         104.901   4.423077e+01
# 163  RI2_2_3       RI2      facial sniffing         182.405   3.670886e+01
# 164  RI2_2_3       RI2        body sniffing         190.655  -4.583333e+01
# 165  RI2_2_3       RI2      facial sniffing         192.901   2.343750e+01
# 166  RI2_2_3       RI2      facial sniffing         198.155  -5.333333e+00
# 167  RI2_2_3       RI2      facial sniffing         229.533  -4.819277e+00
# 168  RI2_2_3       RI2        body sniffing         230.400   4.615385e+01
# 169  RI2_2_3       RI2        body sniffing         232.700  -1.547619e+01
# 170  RI2_2_3       RI2        body sniffing         238.533  -2.439024e+00
# 171  RI2_2_3       RI2      facial sniffing         239.033   3.947368e+00
# 172  RI2_2_3       RI2      facial sniffing         241.433  -2.469136e+00
# 173  RI2_2_3       RI2        body sniffing         268.157  -3.586498e+01
# 174  RI2_2_3       RI2      facial sniffing         272.656   2.580645e+01
# 175  RI2_2_3       RI2      facial sniffing         281.656   1.111111e+01
# 176  RI2_2_3       RI2        body sniffing         282.155   7.017544e+00
# 177  RI2_2_3       RI2      facial sniffing         282.901   1.600000e+01
# 178  RI2_2_3       RI2        body sniffing         312.154  -5.769231e+00
# 179  RI2_2_3       RI2        body sniffing         343.500  -1.639344e+00
# 180  RI2_2_3       RI2        body sniffing         345.033  -6.250000e+00
# 181  RI2_2_3       RI2      facial sniffing         374.900   4.333333e+01
# 182  RI2_2_3       RI2        body sniffing         377.153  -1.919192e+01
# 183  RI2_2_3       RI2        body sniffing         410.153  -6.896552e+00
# 184  RI2_2_3       RI2        body sniffing         414.902   3.333333e+00
# 185  RI2_2_3       RI2  anogenital sniffing         418.153  -5.649718e-01
# 186  RI2_2_3       RI2        body sniffing         427.653  -3.815789e+01
# 187  RI2_2_3       RI2        body sniffing         435.653   2.613636e+01
# 188  RI2_2_3       RI2        body sniffing         438.153  -2.676056e+01
# 189  RI2_2_3       RI2  anogenital sniffing         461.653  -2.615385e+01
# 190  RI2_2_3       RI2        body sniffing         497.152   1.724138e+00
# 191  RI2_2_3       RI2      facial sniffing         497.903  -2.420091e+01
# 192  RI2_2_3       RI2        body sniffing         524.087   1.282051e+00
# 193  RI2_2_3       RI2        body sniffing         528.086  -1.034483e+01
# 194  RI2_2_3       RI2        body sniffing         529.586  -1.666667e+01
# 195  RI2_2_3       RI2        body sniffing         534.336  -1.814346e+01
# 196  RI2_2_3       RI2  anogenital sniffing         541.933  -1.789474e+01
# 197  RI2_2_3       RI2      facial sniffing         591.087   1.190476e+00
# 198  RI2_2_3       RI2        body sniffing         596.167  -4.083333e+01
# 199  RI2_2_3       RI2        body sniffing         598.800  -2.449799e+01
# 200  RI2_4_8       RI2      facial sniffing           3.333  -2.314815e+01
# 201  RI2_4_8       RI2        body sniffing          16.833  -3.611111e+01
# 202  RI2_4_8       RI2      facial sniffing          18.200  -2.112676e+01
# 203  RI2_4_8       RI2  anogenital sniffing          19.100  -1.034483e+01
# 204  RI2_4_8       RI2  anogenital sniffing          19.900   6.363636e+01
# 205  RI2_4_8       RI2      facial sniffing          27.200   1.388889e+01
# 206  RI2_4_8       RI2        body sniffing          28.900   4.457831e+01
# 207  RI2_4_8       RI2        body sniffing          31.000   0.000000e+00
# 208  RI2_4_8       RI2      facial sniffing          40.967   1.358025e+01
# 209  RI2_4_8       RI2      facial sniffing          59.333  -7.894737e+00
# 210  RI2_4_8       RI2      facial sniffing          61.933   1.234568e+00
# 211  RI2_4_8       RI2  anogenital sniffing          66.033   5.000000e+01
# 212  RI2_4_8       RI2  anogenital sniffing          73.467  -2.314815e+01
# 213  RI2_4_8       RI2  anogenital sniffing          76.033  -3.947368e+00
# 214  RI2_4_8       RI2        body sniffing         100.733   1.764706e+01
# 215  RI2_4_8       RI2      facial sniffing         101.133   8.771930e+00
# 216  RI2_4_8       RI2  anogenital sniffing         111.300  -2.247191e+00
# 217  RI2_4_8       RI2      facial sniffing         113.167  -2.435897e+01
# 218  RI2_4_8       RI2        body sniffing         113.767   3.554217e+01
# 219  RI2_4_8       RI2        body sniffing         131.500   2.857143e+01
# 220  RI2_4_8       RI2  anogenital sniffing         158.733   0.000000e+00
# 221  RI2_4_8       RI2      facial sniffing         165.300   1.264368e+01
# 222  RI2_4_8       RI2  anogenital sniffing         184.100  -3.574297e+01
# 223  RI2_4_8       RI2      facial sniffing         193.100   4.797297e+01
# 224  RI2_4_8       RI2        body sniffing         204.600  -2.857143e+01
# 225  RI2_4_8       RI2      facial sniffing         206.933  -4.758065e+01
# 226  RI2_4_8       RI2  anogenital sniffing         210.100  -1.717172e+01
# 227  RI2_4_8       RI2      facial sniffing         221.000  -2.027027e+01
# 228  RI2_4_8       RI2      facial sniffing         224.267   8.983051e+01
# 229  RI2_4_8       RI2      facial sniffing         235.333  -4.285714e+00
# 230  RI2_4_8       RI2        body sniffing         244.000   3.103448e+01
# 231  RI2_4_8       RI2      facial sniffing         244.300   1.304348e+01
# 232  RI2_4_8       RI2      facial sniffing         250.467   2.026144e+01
# 233  RI2_4_8       RI2      facial sniffing         263.933   1.176471e+01
# 234  RI2_4_8       RI2      facial sniffing         269.000   3.396226e+01
# 235  RI2_4_8       RI2      facial sniffing         274.733   3.333333e+00
# 236  RI2_4_8       RI2        body sniffing         294.433  -1.315789e+01
# 237  RI2_4_8       RI2  anogenital sniffing         295.533  -2.391304e+01
# 238  RI2_4_8       RI2        body sniffing         296.233  -1.159420e+01
# 239  RI2_4_8       RI2      facial sniffing         297.100  -1.587302e+00
# 240  RI2_4_8       RI2  anogenital sniffing         298.000  -1.265823e+00
# 241  RI2_4_8       RI2        body sniffing         314.900  -1.333333e+01
# 242  RI2_4_8       RI2        body sniffing         328.167  -4.761905e+00
# 243  RI2_4_8       RI2      facial sniffing         336.333   2.469136e+00
# 244  RI2_4_8       RI2      facial sniffing         356.167   9.213483e+01
# 245  RI2_4_8       RI2        body sniffing         378.733  -5.954545e+01
# 246  RI2_4_8       RI2      facial sniffing         378.933  -4.276316e+01
# 247  RI2_4_8       RI2        body sniffing         401.533  -1.702128e+01
# 248  RI2_4_8       RI2      facial sniffing         422.433  -8.219178e+00
# 249  RI2_4_8       RI2        body sniffing         423.167  -4.298246e+01
# 250  RI2_4_8       RI2  anogenital sniffing         426.333   7.109375e+01
# 251  RI2_4_8       RI2      facial sniffing         431.767   3.518519e+01
# 252  RI2_4_8       RI2      facial sniffing         452.167  -2.168675e+01
# 253  RI2_4_8       RI2      facial sniffing         457.933   5.263158e+00
# 254  RI2_4_8       RI2  anogenital sniffing         459.400   1.408451e+01
# 255  RI2_4_8       RI2      facial sniffing         477.533  -8.333333e+00
# 256  RI2_4_8       RI2      facial sniffing         488.333   3.186813e+01
# 257  RI2_4_8       RI2        body sniffing         494.167  -3.125000e+00
# 258  RI2_4_8       RI2      facial sniffing         496.633   5.333333e+01
# 259  RI2_4_8       RI2      facial sniffing         498.700   1.190476e+00
# 260  RI2_4_8       RI2      facial sniffing         500.800   3.333333e+01
# 261  RI2_4_8       RI2  anogenital sniffing         523.433   5.633803e+00
# 262  RI2_4_8       RI2      facial sniffing         526.067  -6.493506e-01
# 263  RI2_4_8       RI2      facial sniffing         530.500  -3.412698e+01
# 264  RI2_4_8       RI2      facial sniffing         532.167   8.474576e+00
# 265  RI2_4_8       RI2      facial sniffing         547.367  -3.797468e+00
# 266  RI2_4_8       RI2      facial sniffing         557.367  -2.747253e+01
# 267  RI2_4_8       RI2        body sniffing         557.600  -1.397849e+01
# 268  RI2_4_8       RI2      facial sniffing         558.167   2.307692e+01
# 269  RI2_1_1       RI2        body sniffing          11.533   1.126761e+01
# 270  RI2_1_1       RI2        body sniffing          38.467   0.000000e+00
# 271  RI2_1_1       RI2        body sniffing          83.933  -1.809524e+01
# 272  RI2_1_1       RI2      facial sniffing         126.933  -2.790698e+01
# 273  RI2_1_1       RI2        body sniffing         130.000   1.746988e+01
# 274  RI2_1_1       RI2        body sniffing         132.133  -2.888889e+01
# 275  RI2_1_1       RI2        body sniffing         228.400  -2.612613e+01
# 276  RI2_1_1       RI2        body sniffing         241.467  -2.807018e+01
# 277  RI2_1_1       RI2      facial sniffing         341.571  -5.952381e+00
# 278  RI2_1_1       RI2        body sniffing         349.071   2.142857e+01
# 279  RI2_1_1       RI2      facial sniffing         358.570  -1.111111e+01
# 280  RI2_1_1       RI2        body sniffing         420.069   2.542373e+01
# 281  RI2_1_1       RI2        body sniffing         427.071  -4.705882e+00
# 282  RI2_1_1       RI2        body sniffing         472.322   1.739130e+01
# 283  RI2_1_1       RI2        body sniffing         475.821  -1.500000e+01
# 284  RI2_1_1       RI2        body sniffing         528.822  -3.833333e+01
# 285  RI2_1_1       RI2      facial sniffing         582.324   3.312500e+01
# 286  RI2_1_1       RI2        body sniffing         582.818  -4.918033e+00
# 287  RI2_1_2       RI2      facial sniffing           8.067  -1.720430e+01
# 288  RI2_1_2       RI2      facial sniffing          99.933  -3.846154e+01
# 289  RI2_1_2       RI2        body sniffing         149.133  -5.194805e+00
# 290  RI2_1_2       RI2      facial sniffing         158.433  -1.666667e+01
# 291  RI2_1_2       RI2        body sniffing         160.167  -2.272727e+00
# 292  RI2_1_2       RI2      facial sniffing         163.700  -3.833333e+01
# 293  RI2_1_2       RI2      facial sniffing         164.200  -1.428571e+00
# 294  RI2_1_2       RI2        body sniffing         164.833  -1.372549e+01
# 295  RI2_1_2       RI2  anogenital sniffing         199.155   1.551724e+01
# 296  RI2_1_2       RI2  anogenital sniffing         202.155   2.027027e+01
# 297  RI2_1_2       RI2        body sniffing         203.667   1.633987e+01
# 298  RI2_1_2       RI2      facial sniffing         204.200  -1.333333e+00
# 299  RI2_1_2       RI2      facial sniffing         208.133   2.531646e+00
# 300  RI2_1_2       RI2        body sniffing         243.155  -2.021858e+01
# 301  RI2_1_2       RI2      facial sniffing         245.154  -8.955224e+00
# 302  RI2_1_2       RI2      facial sniffing         250.655   1.071429e+01
# 303  RI2_1_2       RI2        body sniffing         284.306  -2.000000e+01
# 304  RI2_1_2       RI2      facial sniffing         287.055   1.208333e+02
# 305  RI2_1_2       RI2        body sniffing         308.033   3.636364e+01
# 306  RI2_1_2       RI2  anogenital sniffing         310.467   7.801418e+00
# 307  RI2_1_2       RI2        body sniffing         310.867   2.340426e+01
# 308  RI2_1_2       RI2        body sniffing         314.933   4.615385e+00
# 309  RI2_1_2       RI2      facial sniffing         316.767   2.214286e+01
# 310  RI2_1_2       RI2        body sniffing         319.033   1.351351e+00
# 311  RI2_1_2       RI2      facial sniffing         319.867  -1.014493e+01
# 312  RI2_1_2       RI2        body sniffing         321.800   1.470588e+00
# 313  RI2_1_2       RI2        body sniffing         323.000   3.561644e+01
# 314  RI2_1_2       RI2  anogenital sniffing         324.600  -1.965812e+01
# 315  RI2_1_2       RI2        body sniffing         325.400  -8.653846e+00
# 316  RI2_1_2       RI2        body sniffing         327.733   2.777778e+00
# 317  RI2_1_2       RI2  anogenital sniffing         330.100  -1.970588e+01
# 318  RI2_1_2       RI2        body sniffing         332.000  -4.054054e+00
# 319  RI2_1_2       RI2  anogenital sniffing         333.233  -2.272727e+00
# 320  RI2_1_2       RI2      facial sniffing         395.057   1.117647e+01
# 321  RI2_1_2       RI2      facial sniffing         403.804   6.626506e+00
# 322  RI2_1_2       RI2        body sniffing         452.556   1.166667e+01
# 323  RI2_1_2       RI2        body sniffing         460.804  -1.111111e+01
# 324  RI2_1_2       RI2        body sniffing         495.805  -1.402439e+01
# 325  RI2_1_2       RI2        body sniffing         498.055  -1.718750e+01
# 326  RI2_1_2       RI2      facial sniffing         499.301  -1.333333e+00
# 327  RI2_1_2       RI2        body sniffing         511.307   7.692308e+00
# 328  RI2_1_2       RI2  anogenital sniffing         518.302  -1.643836e+01
# 329  RI2_1_2       RI2        body sniffing         523.056   5.063291e+00
# 330  RI2_1_2       RI2      facial sniffing         558.304  -3.529412e+00
# 331  RI2_1_2       RI2        body sniffing         560.550  -8.457711e+00
# 332  RI2_1_2       RI2      facial sniffing         565.052   2.328767e+01
# 333  RI2_1_2       RI2        body sniffing         581.000  -2.626263e+01
# 334  RI2_2_4       RI2        body sniffing           5.933  -2.134831e+01
# 335  RI2_2_4       RI2  anogenital sniffing           7.333  -2.602740e+01
# 336  RI2_2_4       RI2        body sniffing           7.867   3.653846e+01
# 337  RI2_2_4       RI2      facial sniffing           9.200  -2.511416e+01
# 338  RI2_2_4       RI2      facial sniffing          10.133  -1.219512e+01
# 339  RI2_2_4       RI2        body sniffing          12.667  -9.677419e+00
# 340  RI2_2_4       RI2  anogenital sniffing          13.333  -3.846154e+00
# 341  RI2_2_4       RI2        body sniffing          14.267   1.190476e+00
# 342  RI2_2_4       RI2        body sniffing          14.733   1.746988e+01
# 343  RI2_2_4       RI2        body sniffing          17.467   1.250000e+01
# 344  RI2_2_4       RI2        body sniffing          26.867   8.333333e+00
# 345  RI2_2_4       RI2  anogenital sniffing          30.400   1.186441e+01
# 346  RI2_2_4       RI2        body sniffing          30.867  -1.812865e+01
# 347  RI2_2_4       RI2      facial sniffing          64.400  -7.500000e+00
# 348  RI2_2_4       RI2  anogenital sniffing          68.600   7.462687e+00
# 349  RI2_2_4       RI2      facial sniffing          77.267   5.000000e+00
# 350  RI2_2_4       RI2        body sniffing          79.933  -1.666667e+01
# 351  RI2_2_4       RI2      facial sniffing         122.467   1.694915e+00
# 352  RI2_2_4       RI2        body sniffing         141.667   5.362319e+01
# 353  RI2_2_4       RI2      facial sniffing         142.933   4.705882e+00
# 354  RI2_2_4       RI2      facial sniffing         146.733   1.686047e+01
# 355  RI2_2_4       RI2      facial sniffing         149.733   5.128205e+00
# 356  RI2_2_4       RI2        body sniffing         177.867   1.129032e+01
# 357  RI2_2_4       RI2        body sniffing         183.533  -3.000000e+01
# 358  RI2_2_4       RI2        body sniffing         211.800  -2.894737e+01
# 359  RI2_2_4       RI2        body sniffing         217.067   4.308554e-12
# 360  RI2_2_4       RI2        body sniffing         220.000   1.690141e+01
# 361  RI2_2_4       RI2  anogenital sniffing         235.267  -3.950617e+01
# 362  RI2_2_4       RI2        body sniffing         236.067   9.259259e+00
# 363  RI2_2_4       RI2        body sniffing         239.933   3.392857e+01
# 364  RI2_2_4       RI2  anogenital sniffing         242.333   5.692308e+01
# 365  RI2_2_4       RI2        body sniffing         260.667  -4.807692e+01
# 366  RI2_2_4       RI2        body sniffing         269.067   4.651163e+00
# 367  RI2_2_4       RI2        body sniffing         272.933   1.016949e+01
# 368  RI2_2_4       RI2        body sniffing         287.267  -2.898551e+00
# 369  RI2_2_4       RI2        body sniffing         296.400   3.015873e+01
# 370  RI2_2_4       RI2  anogenital sniffing         301.867  -2.409639e+00
# 371  RI2_2_4       RI2      facial sniffing         302.467   2.446809e+01
# 372  RI2_2_4       RI2        body sniffing         329.400   1.406250e+01
# 373  RI2_2_4       RI2        body sniffing         344.400   3.125000e+00
# 374  RI2_2_4       RI2      facial sniffing         345.800   1.451613e+01
# 375  RI2_2_4       RI2        body sniffing         346.800  -1.527778e+01
# 376  RI2_2_4       RI2        body sniffing         350.800   9.090909e+00
# 377  RI2_2_4       RI2        body sniffing         368.800  -2.649573e+01
# 378  RI2_2_4       RI2        body sniffing         376.133   4.451220e+01
# 379  RI2_2_4       RI2      facial sniffing         513.867   2.033898e+01
# 380  RI2_2_4       RI2        body sniffing         544.933  -9.195402e+00
# 381  RI2_2_4       RI2      facial sniffing         565.067  -4.597701e+00
# 382  RI2_2_4       RI2      facial sniffing         580.933  -6.557377e+00
# 383  RI2_2_4       RI2        body sniffing         601.333   2.108434e+01
# 384  RI2_3_5       RI2      facial sniffing           4.067   2.034884e+01
# 385  RI2_3_5       RI2        body sniffing           4.467  -1.075269e+01
# 386  RI2_3_5       RI2      facial sniffing          12.033  -1.549296e+01
# 387  RI2_3_5       RI2      facial sniffing          32.900   1.639344e+01
# 388  RI2_3_5       RI2      facial sniffing          55.800   1.022727e+01
# 389  RI2_3_5       RI2        body sniffing          80.733   5.479452e+00
# 390  RI2_3_5       RI2        body sniffing         170.900  -5.952381e+00
# 391  RI2_3_5       RI2      facial sniffing         203.600  -2.478632e+01
# 392  RI2_3_5       RI2      facial sniffing         207.433   4.687500e+00

# %%
combined_df['Condition Label'] = combined_df['Condition'].map({
    'RI1': 'Positive Social Interaction',
    'RI2': 'Negative Social Interaction'
})

# %%
colors = {
    'Positive Social Interaction': (83/255, 161/255, 169/255),  # teal-ish
    'Negative Social Interaction': (169/255, 83/255, 118/255)   # purplish
}

# %%
colors = {
    'Positive Social Interaction': (83/255, 161/255, 169/255),  # teal-ish
    'Negative Social Interaction': (169/255, 83/255, 118/255)   # purplish
}

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
sns.boxplot(
    data=combined_df,
    x='Behavior',
    y='% Change Rate',
    hue='Condition Label',
    palette=colors
)
plt.title('Respiratory Rate % Change by Behavior and Social Valence')
plt.xticks(rotation=30)
plt.ylabel('Percent Change in Respiration Rate')
plt.xlabel('Behavior Type')
plt.legend(title='Condition')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))

# Boxplot (summary)
sns.boxplot(
    data=combined_df,
    x='Behavior',
    y='% Change Rate',
    hue='Condition Label',
    palette=colors,
    showcaps=False,
    boxprops={'facecolor':'None'},
    whiskerprops={'linewidth':0}
)

# Stripplot (individual points)
sns.stripplot(
    data=combined_df,
    x='Behavior',
    y='% Change Rate',
    hue='Condition Label',
    dodge=True,
    palette=colors,
    alpha=0.6,
    jitter=True,
    marker='o'
)

plt.title('Respiratory Rate % Change by Behavior and Social Valence')
plt.xticks(rotation=30)
plt.ylabel('Percent Change in Respiration Rate')
plt.xlabel('Behavior Type')
plt.legend(title='Condition', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
combined_df
# Out:
#        Trial Condition             Behavior  Sniff Time (s)  % Change Rate  \
# 0    RI1_3_6       RI1  anogenital sniffing           8.862  -1.578947e+01
# 1    RI1_3_6       RI1      facial sniffing          12.069   0.000000e+00
# 2    RI1_3_6       RI1  anogenital sniffing          80.310  -8.474576e+00
# 3    RI1_3_6       RI1      facial sniffing          86.207   1.388889e+00
# 4    RI1_3_6       RI1      facial sniffing          88.034  -1.666667e+01
# 5    RI1_3_6       RI1  anogenital sniffing          90.690  -2.156863e+01
# 6    RI1_3_6       RI1      facial sniffing         107.724  -3.059361e+01
# 7    RI1_3_6       RI1      facial sniffing         183.724  -1.250000e+01
# 8    RI1_3_6       RI1      facial sniffing         200.517   4.805195e+01
# 9    RI1_3_6       RI1      facial sniffing         217.172   1.733333e+01
# 10   RI1_3_6       RI1      facial sniffing         229.897   2.800000e+01
# 11   RI1_3_6       RI1      facial sniffing         243.793   5.172414e+00
# 12   RI1_3_6       RI1  anogenital sniffing         260.862   5.205479e+01
# 13   RI1_3_6       RI1      facial sniffing         337.172  -2.207792e+01
# 14   RI1_3_6       RI1      facial sniffing         367.345  -5.813953e+00
# 15   RI1_3_6       RI1      facial sniffing         368.483   3.986486e+01
# 16   RI1_3_6       RI1        body sniffing         404.310   6.250000e+00
# 17   RI1_3_6       RI1      facial sniffing         416.414  -3.466667e+01
# 18   RI1_3_6       RI1        body sniffing         596.931   1.481481e+01
# 19   RI1_3_6       RI1  anogenital sniffing         597.517  -1.136364e+01
# 20   RI1_3_6       RI1      facial sniffing         598.034  -2.872340e+01
# 21   RI1_4_7       RI1      facial sniffing           8.167   1.678657e-13
# 22   RI1_4_7       RI1      facial sniffing          24.467  -9.302326e+00
# 23   RI1_4_7       RI1  anogenital sniffing         346.067   6.976744e+00
# 24   RI1_4_7       RI1      facial sniffing         365.033   1.954023e+01
# 25   RI1_4_7       RI1      facial sniffing         452.867  -7.058824e+00
# 26   RI1_4_7       RI1      facial sniffing         480.500   7.602339e+00
# 27   RI1_4_7       RI1      facial sniffing         483.067   1.576087e+01
# 28   RI1_2_3       RI1      facial sniffing          72.223  -1.351351e+00
# 29   RI1_2_3       RI1        body sniffing          75.723   1.481481e+01
# 30   RI1_2_3       RI1        body sniffing          80.222   5.361446e+01
# 31   RI1_2_3       RI1  anogenital sniffing          85.222  -3.571429e-01
# 32   RI1_2_3       RI1        body sniffing         145.222  -1.298701e+01
# 33   RI1_2_3       RI1        body sniffing         249.222   2.197802e+01
# 34   RI1_4_8       RI1      facial sniffing           5.733   7.792208e+00
# 35   RI1_4_8       RI1      facial sniffing          17.167  -2.112676e+01
# 36   RI1_4_8       RI1  anogenital sniffing          18.700   2.313433e+01
# 37   RI1_4_8       RI1        body sniffing          35.133  -2.747253e+00
# 38   RI1_4_8       RI1  anogenital sniffing          35.600   4.451220e+01
# 39   RI1_4_8       RI1      facial sniffing          37.400  -1.392405e+01
# 40   RI1_4_8       RI1  anogenital sniffing          44.800   1.137757e-12
# 41   RI1_4_8       RI1      facial sniffing          52.733  -1.149425e+01
# 42   RI1_4_8       RI1      facial sniffing          56.400   2.321429e+01
# 43   RI1_4_8       RI1      facial sniffing          62.700   3.392857e+01
# 44   RI1_4_8       RI1      facial sniffing          77.267  -1.785714e+01
# 45   RI1_4_8       RI1      facial sniffing          85.367   7.792208e+00
# 46   RI1_4_8       RI1      facial sniffing         138.200   1.292517e+01
# 47   RI1_4_8       RI1        body sniffing         174.400  -1.219512e+00
# 48   RI1_4_8       RI1  anogenital sniffing         176.133   0.000000e+00
# 49   RI1_4_8       RI1        body sniffing         176.200   0.000000e+00
# 50   RI1_4_8       RI1  anogenital sniffing         185.467   7.792208e+00
# 51   RI1_4_8       RI1  anogenital sniffing         203.733  -8.433735e+00
# 52   RI1_4_8       RI1        body sniffing         234.067  -4.649123e+01
# 53   RI1_4_8       RI1      facial sniffing         324.800  -1.555556e+01
# 54   RI1_4_8       RI1        body sniffing         344.567  -1.746032e+01
# 55   RI1_4_8       RI1      facial sniffing         363.500  -4.597701e+00
# 56   RI1_4_8       RI1      facial sniffing         390.367  -3.148148e+01
# 57   RI1_4_8       RI1      facial sniffing         455.933   3.012048e+01
# 58   RI1_4_8       RI1        body sniffing         463.733   2.325581e+00
# 59   RI1_4_8       RI1      facial sniffing         531.600   3.098592e+01
# 60   RI2_3_6       RI2      facial sniffing          25.600  -1.182432e+01
# 61   RI2_3_6       RI2        body sniffing          26.167  -7.602339e+00
# 62   RI2_3_6       RI2  anogenital sniffing          26.600   6.578947e+00
# 63   RI2_3_6       RI2      facial sniffing          68.767  -4.000000e+00
# 64   RI2_3_6       RI2      facial sniffing          91.900   2.740741e+01
# 65   RI2_3_6       RI2      facial sniffing         153.900   3.000000e+01
# 66   RI2_3_6       RI2      facial sniffing         156.233  -2.840909e+01
# 67   RI2_3_6       RI2      facial sniffing         195.433  -2.266667e+01
# 68   RI2_3_6       RI2        body sniffing         195.767  -1.919192e+01
# 69   RI2_3_6       RI2      facial sniffing         196.167   0.000000e+00
# 70   RI2_3_6       RI2        body sniffing         198.333  -1.534392e+01
# 71   RI2_3_6       RI2      facial sniffing         218.300   1.612903e+00
# 72   RI2_3_6       RI2        body sniffing         219.433  -2.394366e+01
# 73   RI2_3_6       RI2      facial sniffing         226.433  -3.493976e+01
# 74   RI2_3_6       RI2        body sniffing         228.433   3.833333e+01
# 75   RI2_3_6       RI2  anogenital sniffing         234.167   1.712329e+01
# 76   RI2_3_6       RI2      facial sniffing         234.867   3.536585e+01
# 77   RI2_3_6       RI2  anogenital sniffing         235.567  -3.257576e+01
# 78   RI2_3_6       RI2      facial sniffing         249.733  -7.894737e+00
# 79   RI2_3_6       RI2      facial sniffing         257.833   7.042254e+00
# 80   RI2_3_6       RI2      facial sniffing         267.400  -4.225352e+00
# 81   RI2_3_6       RI2      facial sniffing         269.767  -5.632184e+01
# 82   RI2_3_6       RI2      facial sniffing         273.367  -4.716981e+01
# 83   RI2_3_6       RI2      facial sniffing         282.033  -4.230769e+01
# 84   RI2_3_6       RI2      facial sniffing         288.200  -2.125000e+01
# 85   RI2_3_6       RI2      facial sniffing         290.133   3.793103e+01
# 86   RI2_3_6       RI2      facial sniffing         318.700  -1.176471e+01
# 87   RI2_3_6       RI2      facial sniffing         343.133  -9.628964e-12
# 88   RI2_3_6       RI2  anogenital sniffing         430.167   6.764706e+01
# 89   RI2_3_6       RI2  anogenital sniffing         449.800  -1.272727e+01
# 90   RI2_3_6       RI2        body sniffing         455.067   1.007752e+01
# 91   RI2_3_6       RI2        body sniffing         502.667   2.613636e+01
# 92   RI2_3_6       RI2      facial sniffing         503.133   4.625000e+01
# 93   RI2_3_6       RI2  anogenital sniffing         524.333  -7.526882e+00
# 94   RI2_3_6       RI2      facial sniffing         537.000  -3.278689e+00
# 95   RI2_3_6       RI2      facial sniffing         548.033  -1.549296e+01
# 96   RI2_3_6       RI2        body sniffing         550.833  -2.921348e+01
# 97   RI2_3_6       RI2      facial sniffing         554.333  -5.747126e+00
# 98   RI2_3_6       RI2      facial sniffing         559.000  -1.518987e+01
# 99   RI2_3_6       RI2      facial sniffing         596.333   2.222222e+01
# 100  RI2_4_7       RI2      facial sniffing           6.767   5.063291e+00
# 101  RI2_4_7       RI2      facial sniffing          13.767  -1.250000e+01
# 102  RI2_4_7       RI2      facial sniffing          29.633   3.846154e+00
# 103  RI2_4_7       RI2        body sniffing          30.767  -6.896552e+00
# 104  RI2_4_7       RI2  anogenital sniffing          31.767  -3.046875e+01
# 105  RI2_4_7       RI2        body sniffing          35.133  -1.250000e+00
# 106  RI2_4_7       RI2  anogenital sniffing          36.600  -1.265823e+00
# 107  RI2_4_7       RI2      facial sniffing          37.567   2.162162e+01
# 108  RI2_4_7       RI2      facial sniffing          66.300   2.000000e+01
# 109  RI2_4_7       RI2  anogenital sniffing          69.900  -1.123596e+01
# 110  RI2_4_7       RI2  anogenital sniffing          73.600   4.444444e+01
# 111  RI2_4_7       RI2        body sniffing          75.633  -1.195652e+01
# 112  RI2_4_7       RI2  anogenital sniffing          77.133  -6.024096e-01
# 113  RI2_4_7       RI2      facial sniffing          99.333  -4.814815e+01
# 114  RI2_4_7       RI2        body sniffing         100.100   3.965517e+01
# 115  RI2_4_7       RI2  anogenital sniffing         100.467   1.506849e+01
# 116  RI2_4_7       RI2      facial sniffing         104.067   5.161290e+01
# 117  RI2_4_7       RI2        body sniffing         166.967  -3.703704e+01
# 118  RI2_4_7       RI2  anogenital sniffing         168.900  -1.142857e+01
# 119  RI2_4_7       RI2  anogenital sniffing         171.967   4.285714e+01
# 120  RI2_4_7       RI2  anogenital sniffing         190.433  -6.818182e+00
# 121  RI2_4_7       RI2  anogenital sniffing         214.033   1.750000e+01
# 122  RI2_4_7       RI2        body sniffing         226.633  -1.256831e+01
# 123  RI2_4_7       RI2  anogenital sniffing         227.133   2.564103e+00
# 124  RI2_4_7       RI2  anogenital sniffing         228.533  -6.250000e+00
# 125  RI2_4_7       RI2      facial sniffing         298.300  -6.601562e+01
# 126  RI2_4_7       RI2  anogenital sniffing         305.100  -2.205882e+01
# 127  RI2_4_7       RI2        body sniffing         334.600  -2.150538e+01
# 128  RI2_4_7       RI2      facial sniffing         334.867  -1.363636e+01
# 129  RI2_4_7       RI2        body sniffing         335.600  -5.617978e+00
# 130  RI2_4_7       RI2        body sniffing         367.700  -3.125000e+01
# 131  RI2_4_7       RI2  anogenital sniffing         380.300  -4.054054e+00
# 132  RI2_4_7       RI2  anogenital sniffing         381.732   3.687500e+01
# 133  RI2_4_7       RI2      facial sniffing         409.867  -5.154639e+00
# 134  RI2_4_7       RI2  anogenital sniffing         429.067   8.196721e+00
# 135  RI2_4_7       RI2  anogenital sniffing         446.667   2.368421e+01
# 136  RI2_4_7       RI2      facial sniffing         454.000   7.792208e+00
# 137  RI2_4_7       RI2        body sniffing         462.933   3.103448e+01
# 138  RI2_4_7       RI2        body sniffing         465.967   0.000000e+00
# 139  RI2_4_7       RI2  anogenital sniffing         467.333  -2.900433e+01
# 140  RI2_4_7       RI2        body sniffing         470.533   2.500000e+01
# 141  RI2_4_7       RI2      facial sniffing         471.633  -1.734694e+01
# 142  RI2_4_7       RI2      facial sniffing         472.367   4.347826e+00
# 143  RI2_4_7       RI2      facial sniffing         495.733   1.746032e+01
# 144  RI2_4_7       RI2      facial sniffing         518.200   2.222222e+01
# 145  RI2_4_7       RI2      facial sniffing         535.867   1.960121e-11
# 146  RI2_4_7       RI2      facial sniffing         549.467   1.079545e+01
# 147  RI2_4_7       RI2  anogenital sniffing         556.833  -1.562500e+01
# 148  RI2_4_7       RI2      facial sniffing         561.567   1.355932e+01
# 149  RI2_4_7       RI2        body sniffing         582.600   5.000000e+00
# 150  RI2_4_7       RI2  anogenital sniffing         583.367  -4.400000e+01
# 151  RI2_4_7       RI2      facial sniffing         586.333   1.935484e+01
# 152  RI2_4_7       RI2        body sniffing         586.667   1.694915e+01
# 153  RI2_4_7       RI2      facial sniffing         587.433  -2.972973e+01
# 154  RI2_4_7       RI2        body sniffing         602.500  -1.410256e+01
# 155  RI2_4_7       RI2      facial sniffing         603.533   2.108434e+01
# 156  RI2_4_7       RI2        body sniffing         605.033  -3.333333e+01
# 157  RI2_2_3       RI2        body sniffing           7.655  -2.456140e+01
# 158  RI2_2_3       RI2  anogenital sniffing           9.905   2.289157e+01
# 159  RI2_2_3       RI2        body sniffing          29.155  -1.414474e+01
# 160  RI2_2_3       RI2        body sniffing          33.654   1.803279e+01
# 161  RI2_2_3       RI2  anogenital sniffing         102.655   1.492537e+01
# 162  RI2_2_3       RI2        body sniffing         104.901   4.423077e+01
# 163  RI2_2_3       RI2      facial sniffing         182.405   3.670886e+01
# 164  RI2_2_3       RI2        body sniffing         190.655  -4.583333e+01
# 165  RI2_2_3       RI2      facial sniffing         192.901   2.343750e+01
# 166  RI2_2_3       RI2      facial sniffing         198.155  -5.333333e+00
# 167  RI2_2_3       RI2      facial sniffing         229.533  -4.819277e+00
# 168  RI2_2_3       RI2        body sniffing         230.400   4.615385e+01
# 169  RI2_2_3       RI2        body sniffing         232.700  -1.547619e+01
# 170  RI2_2_3       RI2        body sniffing         238.533  -2.439024e+00
# 171  RI2_2_3       RI2      facial sniffing         239.033   3.947368e+00
# 172  RI2_2_3       RI2      facial sniffing         241.433  -2.469136e+00
# 173  RI2_2_3       RI2        body sniffing         268.157  -3.586498e+01
# 174  RI2_2_3       RI2      facial sniffing         272.656   2.580645e+01
# 175  RI2_2_3       RI2      facial sniffing         281.656   1.111111e+01
# 176  RI2_2_3       RI2        body sniffing         282.155   7.017544e+00
# 177  RI2_2_3       RI2      facial sniffing         282.901   1.600000e+01
# 178  RI2_2_3       RI2        body sniffing         312.154  -5.769231e+00
# 179  RI2_2_3       RI2        body sniffing         343.500  -1.639344e+00
# 180  RI2_2_3       RI2        body sniffing         345.033  -6.250000e+00
# 181  RI2_2_3       RI2      facial sniffing         374.900   4.333333e+01
# 182  RI2_2_3       RI2        body sniffing         377.153  -1.919192e+01
# 183  RI2_2_3       RI2        body sniffing         410.153  -6.896552e+00
# 184  RI2_2_3       RI2        body sniffing         414.902   3.333333e+00
# 185  RI2_2_3       RI2  anogenital sniffing         418.153  -5.649718e-01
# 186  RI2_2_3       RI2        body sniffing         427.653  -3.815789e+01
# 187  RI2_2_3       RI2        body sniffing         435.653   2.613636e+01
# 188  RI2_2_3       RI2        body sniffing         438.153  -2.676056e+01
# 189  RI2_2_3       RI2  anogenital sniffing         461.653  -2.615385e+01
# 190  RI2_2_3       RI2        body sniffing         497.152   1.724138e+00
# 191  RI2_2_3       RI2      facial sniffing         497.903  -2.420091e+01
# 192  RI2_2_3       RI2        body sniffing         524.087   1.282051e+00
# 193  RI2_2_3       RI2        body sniffing         528.086  -1.034483e+01
# 194  RI2_2_3       RI2        body sniffing         529.586  -1.666667e+01
# 195  RI2_2_3       RI2        body sniffing         534.336  -1.814346e+01
# 196  RI2_2_3       RI2  anogenital sniffing         541.933  -1.789474e+01
# 197  RI2_2_3       RI2      facial sniffing         591.087   1.190476e+00
# 198  RI2_2_3       RI2        body sniffing         596.167  -4.083333e+01
# 199  RI2_2_3       RI2        body sniffing         598.800  -2.449799e+01
# 200  RI2_4_8       RI2      facial sniffing           3.333  -2.314815e+01
# 201  RI2_4_8       RI2        body sniffing          16.833  -3.611111e+01
# 202  RI2_4_8       RI2      facial sniffing          18.200  -2.112676e+01
# 203  RI2_4_8       RI2  anogenital sniffing          19.100  -1.034483e+01
# 204  RI2_4_8       RI2  anogenital sniffing          19.900   6.363636e+01
# 205  RI2_4_8       RI2      facial sniffing          27.200   1.388889e+01
# 206  RI2_4_8       RI2        body sniffing          28.900   4.457831e+01
# 207  RI2_4_8       RI2        body sniffing          31.000   0.000000e+00
# 208  RI2_4_8       RI2      facial sniffing          40.967   1.358025e+01
# 209  RI2_4_8       RI2      facial sniffing          59.333  -7.894737e+00
# 210  RI2_4_8       RI2      facial sniffing          61.933   1.234568e+00
# 211  RI2_4_8       RI2  anogenital sniffing          66.033   5.000000e+01
# 212  RI2_4_8       RI2  anogenital sniffing          73.467  -2.314815e+01
# 213  RI2_4_8       RI2  anogenital sniffing          76.033  -3.947368e+00
# 214  RI2_4_8       RI2        body sniffing         100.733   1.764706e+01
# 215  RI2_4_8       RI2      facial sniffing         101.133   8.771930e+00
# 216  RI2_4_8       RI2  anogenital sniffing         111.300  -2.247191e+00
# 217  RI2_4_8       RI2      facial sniffing         113.167  -2.435897e+01
# 218  RI2_4_8       RI2        body sniffing         113.767   3.554217e+01
# 219  RI2_4_8       RI2        body sniffing         131.500   2.857143e+01
# 220  RI2_4_8       RI2  anogenital sniffing         158.733   0.000000e+00
# 221  RI2_4_8       RI2      facial sniffing         165.300   1.264368e+01
# 222  RI2_4_8       RI2  anogenital sniffing         184.100  -3.574297e+01
# 223  RI2_4_8       RI2      facial sniffing         193.100   4.797297e+01
# 224  RI2_4_8       RI2        body sniffing         204.600  -2.857143e+01
# 225  RI2_4_8       RI2      facial sniffing         206.933  -4.758065e+01
# 226  RI2_4_8       RI2  anogenital sniffing         210.100  -1.717172e+01
# 227  RI2_4_8       RI2      facial sniffing         221.000  -2.027027e+01
# 228  RI2_4_8       RI2      facial sniffing         224.267   8.983051e+01
# 229  RI2_4_8       RI2      facial sniffing         235.333  -4.285714e+00
# 230  RI2_4_8       RI2        body sniffing         244.000   3.103448e+01
# 231  RI2_4_8       RI2      facial sniffing         244.300   1.304348e+01
# 232  RI2_4_8       RI2      facial sniffing         250.467   2.026144e+01
# 233  RI2_4_8       RI2      facial sniffing         263.933   1.176471e+01
# 234  RI2_4_8       RI2      facial sniffing         269.000   3.396226e+01
# 235  RI2_4_8       RI2      facial sniffing         274.733   3.333333e+00
# 236  RI2_4_8       RI2        body sniffing         294.433  -1.315789e+01
# 237  RI2_4_8       RI2  anogenital sniffing         295.533  -2.391304e+01
# 238  RI2_4_8       RI2        body sniffing         296.233  -1.159420e+01
# 239  RI2_4_8       RI2      facial sniffing         297.100  -1.587302e+00
# 240  RI2_4_8       RI2  anogenital sniffing         298.000  -1.265823e+00
# 241  RI2_4_8       RI2        body sniffing         314.900  -1.333333e+01
# 242  RI2_4_8       RI2        body sniffing         328.167  -4.761905e+00
# 243  RI2_4_8       RI2      facial sniffing         336.333   2.469136e+00
# 244  RI2_4_8       RI2      facial sniffing         356.167   9.213483e+01
# 245  RI2_4_8       RI2        body sniffing         378.733  -5.954545e+01
# 246  RI2_4_8       RI2      facial sniffing         378.933  -4.276316e+01
# 247  RI2_4_8       RI2        body sniffing         401.533  -1.702128e+01
# 248  RI2_4_8       RI2      facial sniffing         422.433  -8.219178e+00
# 249  RI2_4_8       RI2        body sniffing         423.167  -4.298246e+01
# 250  RI2_4_8       RI2  anogenital sniffing         426.333   7.109375e+01
# 251  RI2_4_8       RI2      facial sniffing         431.767   3.518519e+01
# 252  RI2_4_8       RI2      facial sniffing         452.167  -2.168675e+01
# 253  RI2_4_8       RI2      facial sniffing         457.933   5.263158e+00
# 254  RI2_4_8       RI2  anogenital sniffing         459.400   1.408451e+01
# 255  RI2_4_8       RI2      facial sniffing         477.533  -8.333333e+00
# 256  RI2_4_8       RI2      facial sniffing         488.333   3.186813e+01
# 257  RI2_4_8       RI2        body sniffing         494.167  -3.125000e+00
# 258  RI2_4_8       RI2      facial sniffing         496.633   5.333333e+01
# 259  RI2_4_8       RI2      facial sniffing         498.700   1.190476e+00
# 260  RI2_4_8       RI2      facial sniffing         500.800   3.333333e+01
# 261  RI2_4_8       RI2  anogenital sniffing         523.433   5.633803e+00
# 262  RI2_4_8       RI2      facial sniffing         526.067  -6.493506e-01
# 263  RI2_4_8       RI2      facial sniffing         530.500  -3.412698e+01
# 264  RI2_4_8       RI2      facial sniffing         532.167   8.474576e+00
# 265  RI2_4_8       RI2      facial sniffing         547.367  -3.797468e+00
# 266  RI2_4_8       RI2      facial sniffing         557.367  -2.747253e+01
# 267  RI2_4_8       RI2        body sniffing         557.600  -1.397849e+01
# 268  RI2_4_8       RI2      facial sniffing         558.167   2.307692e+01
# 269  RI2_1_1       RI2        body sniffing          11.533   1.126761e+01
# 270  RI2_1_1       RI2        body sniffing          38.467   0.000000e+00
# 271  RI2_1_1       RI2        body sniffing          83.933  -1.809524e+01
# 272  RI2_1_1       RI2      facial sniffing         126.933  -2.790698e+01
# 273  RI2_1_1       RI2        body sniffing         130.000   1.746988e+01
# 274  RI2_1_1       RI2        body sniffing         132.133  -2.888889e+01
# 275  RI2_1_1       RI2        body sniffing         228.400  -2.612613e+01
# 276  RI2_1_1       RI2        body sniffing         241.467  -2.807018e+01
# 277  RI2_1_1       RI2      facial sniffing         341.571  -5.952381e+00
# 278  RI2_1_1       RI2        body sniffing         349.071   2.142857e+01
# 279  RI2_1_1       RI2      facial sniffing         358.570  -1.111111e+01
# 280  RI2_1_1       RI2        body sniffing         420.069   2.542373e+01
# 281  RI2_1_1       RI2        body sniffing         427.071  -4.705882e+00
# 282  RI2_1_1       RI2        body sniffing         472.322   1.739130e+01
# 283  RI2_1_1       RI2        body sniffing         475.821  -1.500000e+01
# 284  RI2_1_1       RI2        body sniffing         528.822  -3.833333e+01
# 285  RI2_1_1       RI2      facial sniffing         582.324   3.312500e+01
# 286  RI2_1_1       RI2        body sniffing         582.818  -4.918033e+00
# 287  RI2_1_2       RI2      facial sniffing           8.067  -1.720430e+01
# 288  RI2_1_2       RI2      facial sniffing          99.933  -3.846154e+01
# 289  RI2_1_2       RI2        body sniffing         149.133  -5.194805e+00
# 290  RI2_1_2       RI2      facial sniffing         158.433  -1.666667e+01
# 291  RI2_1_2       RI2        body sniffing         160.167  -2.272727e+00
# 292  RI2_1_2       RI2      facial sniffing         163.700  -3.833333e+01
# 293  RI2_1_2       RI2      facial sniffing         164.200  -1.428571e+00
# 294  RI2_1_2       RI2        body sniffing         164.833  -1.372549e+01
# 295  RI2_1_2       RI2  anogenital sniffing         199.155   1.551724e+01
# 296  RI2_1_2       RI2  anogenital sniffing         202.155   2.027027e+01
# 297  RI2_1_2       RI2        body sniffing         203.667   1.633987e+01
# 298  RI2_1_2       RI2      facial sniffing         204.200  -1.333333e+00
# 299  RI2_1_2       RI2      facial sniffing         208.133   2.531646e+00
# 300  RI2_1_2       RI2        body sniffing         243.155  -2.021858e+01
# 301  RI2_1_2       RI2      facial sniffing         245.154  -8.955224e+00
# 302  RI2_1_2       RI2      facial sniffing         250.655   1.071429e+01
# 303  RI2_1_2       RI2        body sniffing         284.306  -2.000000e+01
# 304  RI2_1_2       RI2      facial sniffing         287.055   1.208333e+02
# 305  RI2_1_2       RI2        body sniffing         308.033   3.636364e+01
# 306  RI2_1_2       RI2  anogenital sniffing         310.467   7.801418e+00
# 307  RI2_1_2       RI2        body sniffing         310.867   2.340426e+01
# 308  RI2_1_2       RI2        body sniffing         314.933   4.615385e+00
# 309  RI2_1_2       RI2      facial sniffing         316.767   2.214286e+01
# 310  RI2_1_2       RI2        body sniffing         319.033   1.351351e+00
# 311  RI2_1_2       RI2      facial sniffing         319.867  -1.014493e+01
# 312  RI2_1_2       RI2        body sniffing         321.800   1.470588e+00
# 313  RI2_1_2       RI2        body sniffing         323.000   3.561644e+01
# 314  RI2_1_2       RI2  anogenital sniffing         324.600  -1.965812e+01
# 315  RI2_1_2       RI2        body sniffing         325.400  -8.653846e+00
# 316  RI2_1_2       RI2        body sniffing         327.733   2.777778e+00
# 317  RI2_1_2       RI2  anogenital sniffing         330.100  -1.970588e+01
# 318  RI2_1_2       RI2        body sniffing         332.000  -4.054054e+00
# 319  RI2_1_2       RI2  anogenital sniffing         333.233  -2.272727e+00
# 320  RI2_1_2       RI2      facial sniffing         395.057   1.117647e+01
# 321  RI2_1_2       RI2      facial sniffing         403.804   6.626506e+00
# 322  RI2_1_2       RI2        body sniffing         452.556   1.166667e+01
# 323  RI2_1_2       RI2        body sniffing         460.804  -1.111111e+01
# 324  RI2_1_2       RI2        body sniffing         495.805  -1.402439e+01
# 325  RI2_1_2       RI2        body sniffing         498.055  -1.718750e+01
# 326  RI2_1_2       RI2      facial sniffing         499.301  -1.333333e+00
# 327  RI2_1_2       RI2        body sniffing         511.307   7.692308e+00
# 328  RI2_1_2       RI2  anogenital sniffing         518.302  -1.643836e+01
# 329  RI2_1_2       RI2        body sniffing         523.056   5.063291e+00
# 330  RI2_1_2       RI2      facial sniffing         558.304  -3.529412e+00
# 331  RI2_1_2       RI2        body sniffing         560.550  -8.457711e+00
# 332  RI2_1_2       RI2      facial sniffing         565.052   2.328767e+01
# 333  RI2_1_2       RI2        body sniffing         581.000  -2.626263e+01
# 334  RI2_2_4       RI2        body sniffing           5.933  -2.134831e+01
# 335  RI2_2_4       RI2  anogenital sniffing           7.333  -2.602740e+01
# 336  RI2_2_4       RI2        body sniffing           7.867   3.653846e+01
# 337  RI2_2_4       RI2      facial sniffing           9.200  -2.511416e+01
# 338  RI2_2_4       RI2      facial sniffing          10.133  -1.219512e+01
# 339  RI2_2_4       RI2        body sniffing          12.667  -9.677419e+00
# 340  RI2_2_4       RI2  anogenital sniffing          13.333  -3.846154e+00
# 341  RI2_2_4       RI2        body sniffing          14.267   1.190476e+00
# 342  RI2_2_4       RI2        body sniffing          14.733   1.746988e+01
# 343  RI2_2_4       RI2        body sniffing          17.467   1.250000e+01
# 344  RI2_2_4       RI2        body sniffing          26.867   8.333333e+00
# 345  RI2_2_4       RI2  anogenital sniffing          30.400   1.186441e+01
# 346  RI2_2_4       RI2        body sniffing          30.867  -1.812865e+01
# 347  RI2_2_4       RI2      facial sniffing          64.400  -7.500000e+00
# 348  RI2_2_4       RI2  anogenital sniffing          68.600   7.462687e+00
# 349  RI2_2_4       RI2      facial sniffing          77.267   5.000000e+00
# 350  RI2_2_4       RI2        body sniffing          79.933  -1.666667e+01
# 351  RI2_2_4       RI2      facial sniffing         122.467   1.694915e+00
# 352  RI2_2_4       RI2        body sniffing         141.667   5.362319e+01
# 353  RI2_2_4       RI2      facial sniffing         142.933   4.705882e+00
# 354  RI2_2_4       RI2      facial sniffing         146.733   1.686047e+01
# 355  RI2_2_4       RI2      facial sniffing         149.733   5.128205e+00
# 356  RI2_2_4       RI2        body sniffing         177.867   1.129032e+01
# 357  RI2_2_4       RI2        body sniffing         183.533  -3.000000e+01
# 358  RI2_2_4       RI2        body sniffing         211.800  -2.894737e+01
# 359  RI2_2_4       RI2        body sniffing         217.067   4.308554e-12
# 360  RI2_2_4       RI2        body sniffing         220.000   1.690141e+01
# 361  RI2_2_4       RI2  anogenital sniffing         235.267  -3.950617e+01
# 362  RI2_2_4       RI2        body sniffing         236.067   9.259259e+00
# 363  RI2_2_4       RI2        body sniffing         239.933   3.392857e+01
# 364  RI2_2_4       RI2  anogenital sniffing         242.333   5.692308e+01
# 365  RI2_2_4       RI2        body sniffing         260.667  -4.807692e+01
# 366  RI2_2_4       RI2        body sniffing         269.067   4.651163e+00
# 367  RI2_2_4       RI2        body sniffing         272.933   1.016949e+01
# 368  RI2_2_4       RI2        body sniffing         287.267  -2.898551e+00
# 369  RI2_2_4       RI2        body sniffing         296.400   3.015873e+01
# 370  RI2_2_4       RI2  anogenital sniffing         301.867  -2.409639e+00
# 371  RI2_2_4       RI2      facial sniffing         302.467   2.446809e+01
# 372  RI2_2_4       RI2        body sniffing         329.400   1.406250e+01
# 373  RI2_2_4       RI2        body sniffing         344.400   3.125000e+00
# 374  RI2_2_4       RI2      facial sniffing         345.800   1.451613e+01
# 375  RI2_2_4       RI2        body sniffing         346.800  -1.527778e+01
# 376  RI2_2_4       RI2        body sniffing         350.800   9.090909e+00
# 377  RI2_2_4       RI2        body sniffing         368.800  -2.649573e+01
# 378  RI2_2_4       RI2        body sniffing         376.133   4.451220e+01
# 379  RI2_2_4       RI2      facial sniffing         513.867   2.033898e+01
# 380  RI2_2_4       RI2        body sniffing         544.933  -9.195402e+00
# 381  RI2_2_4       RI2      facial sniffing         565.067  -4.597701e+00
# 382  RI2_2_4       RI2      facial sniffing         580.933  -6.557377e+00
# 383  RI2_2_4       RI2        body sniffing         601.333   2.108434e+01
# 384  RI2_3_5       RI2      facial sniffing           4.067   2.034884e+01
# 385  RI2_3_5       RI2        body sniffing           4.467  -1.075269e+01
# 386  RI2_3_5       RI2      facial sniffing          12.033  -1.549296e+01
# 387  RI2_3_5       RI2      facial sniffing          32.900   1.639344e+01
# 388  RI2_3_5       RI2      facial sniffing          55.800   1.022727e+01
# 389  RI2_3_5       RI2        body sniffing          80.733   5.479452e+00
# 390  RI2_3_5       RI2        body sniffing         170.900  -5.952381e+00
# 391  RI2_3_5       RI2      facial sniffing         203.600  -2.478632e+01
# 392  RI2_3_5       RI2      facial sniffing         207.433   4.687500e+00
#
#                  Condition Label
# 0    Positive Social Interaction
# 1    Positive Social Interaction
# 2    Positive Social Interaction
# 3    Positive Social Interaction
# 4    Positive Social Interaction
# 5    Positive Social Interaction
# 6    Positive Social Interaction
# 7    Positive Social Interaction
# 8    Positive Social Interaction
# 9    Positive Social Interaction
# 10   Positive Social Interaction
# 11   Positive Social Interaction
# 12   Positive Social Interaction
# 13   Positive Social Interaction
# 14   Positive Social Interaction
# 15   Positive Social Interaction
# 16   Positive Social Interaction
# 17   Positive Social Interaction
# 18   Positive Social Interaction
# 19   Positive Social Interaction
# 20   Positive Social Interaction
# 21   Positive Social Interaction
# 22   Positive Social Interaction
# 23   Positive Social Interaction
# 24   Positive Social Interaction
# 25   Positive Social Interaction
# 26   Positive Social Interaction
# 27   Positive Social Interaction
# 28   Positive Social Interaction
# 29   Positive Social Interaction
# 30   Positive Social Interaction
# 31   Positive Social Interaction
# 32   Positive Social Interaction
# 33   Positive Social Interaction
# 34   Positive Social Interaction
# 35   Positive Social Interaction
# 36   Positive Social Interaction
# 37   Positive Social Interaction
# 38   Positive Social Interaction
# 39   Positive Social Interaction
# 40   Positive Social Interaction
# 41   Positive Social Interaction
# 42   Positive Social Interaction
# 43   Positive Social Interaction
# 44   Positive Social Interaction
# 45   Positive Social Interaction
# 46   Positive Social Interaction
# 47   Positive Social Interaction
# 48   Positive Social Interaction
# 49   Positive Social Interaction
# 50   Positive Social Interaction
# 51   Positive Social Interaction
# 52   Positive Social Interaction
# 53   Positive Social Interaction
# 54   Positive Social Interaction
# 55   Positive Social Interaction
# 56   Positive Social Interaction
# 57   Positive Social Interaction
# 58   Positive Social Interaction
# 59   Positive Social Interaction
# 60   Negative Social Interaction
# 61   Negative Social Interaction
# 62   Negative Social Interaction
# 63   Negative Social Interaction
# 64   Negative Social Interaction
# 65   Negative Social Interaction
# 66   Negative Social Interaction
# 67   Negative Social Interaction
# 68   Negative Social Interaction
# 69   Negative Social Interaction
# 70   Negative Social Interaction
# 71   Negative Social Interaction
# 72   Negative Social Interaction
# 73   Negative Social Interaction
# 74   Negative Social Interaction
# 75   Negative Social Interaction
# 76   Negative Social Interaction
# 77   Negative Social Interaction
# 78   Negative Social Interaction
# 79   Negative Social Interaction
# 80   Negative Social Interaction
# 81   Negative Social Interaction
# 82   Negative Social Interaction
# 83   Negative Social Interaction
# 84   Negative Social Interaction
# 85   Negative Social Interaction
# 86   Negative Social Interaction
# 87   Negative Social Interaction
# 88   Negative Social Interaction
# 89   Negative Social Interaction
# 90   Negative Social Interaction
# 91   Negative Social Interaction
# 92   Negative Social Interaction
# 93   Negative Social Interaction
# 94   Negative Social Interaction
# 95   Negative Social Interaction
# 96   Negative Social Interaction
# 97   Negative Social Interaction
# 98   Negative Social Interaction
# 99   Negative Social Interaction
# 100  Negative Social Interaction
# 101  Negative Social Interaction
# 102  Negative Social Interaction
# 103  Negative Social Interaction
# 104  Negative Social Interaction
# 105  Negative Social Interaction
# 106  Negative Social Interaction
# 107  Negative Social Interaction
# 108  Negative Social Interaction
# 109  Negative Social Interaction
# 110  Negative Social Interaction
# 111  Negative Social Interaction
# 112  Negative Social Interaction
# 113  Negative Social Interaction
# 114  Negative Social Interaction
# 115  Negative Social Interaction
# 116  Negative Social Interaction
# 117  Negative Social Interaction
# 118  Negative Social Interaction
# 119  Negative Social Interaction
# 120  Negative Social Interaction
# 121  Negative Social Interaction
# 122  Negative Social Interaction
# 123  Negative Social Interaction
# 124  Negative Social Interaction
# 125  Negative Social Interaction
# 126  Negative Social Interaction
# 127  Negative Social Interaction
# 128  Negative Social Interaction
# 129  Negative Social Interaction
# 130  Negative Social Interaction
# 131  Negative Social Interaction
# 132  Negative Social Interaction
# 133  Negative Social Interaction
# 134  Negative Social Interaction
# 135  Negative Social Interaction
# 136  Negative Social Interaction
# 137  Negative Social Interaction
# 138  Negative Social Interaction
# 139  Negative Social Interaction
# 140  Negative Social Interaction
# 141  Negative Social Interaction
# 142  Negative Social Interaction
# 143  Negative Social Interaction
# 144  Negative Social Interaction
# 145  Negative Social Interaction
# 146  Negative Social Interaction
# 147  Negative Social Interaction
# 148  Negative Social Interaction
# 149  Negative Social Interaction
# 150  Negative Social Interaction
# 151  Negative Social Interaction
# 152  Negative Social Interaction
# 153  Negative Social Interaction
# 154  Negative Social Interaction
# 155  Negative Social Interaction
# 156  Negative Social Interaction
# 157  Negative Social Interaction
# 158  Negative Social Interaction
# 159  Negative Social Interaction
# 160  Negative Social Interaction
# 161  Negative Social Interaction
# 162  Negative Social Interaction
# 163  Negative Social Interaction
# 164  Negative Social Interaction
# 165  Negative Social Interaction
# 166  Negative Social Interaction
# 167  Negative Social Interaction
# 168  Negative Social Interaction
# 169  Negative Social Interaction
# 170  Negative Social Interaction
# 171  Negative Social Interaction
# 172  Negative Social Interaction
# 173  Negative Social Interaction
# 174  Negative Social Interaction
# 175  Negative Social Interaction
# 176  Negative Social Interaction
# 177  Negative Social Interaction
# 178  Negative Social Interaction
# 179  Negative Social Interaction
# 180  Negative Social Interaction
# 181  Negative Social Interaction
# 182  Negative Social Interaction
# 183  Negative Social Interaction
# 184  Negative Social Interaction
# 185  Negative Social Interaction
# 186  Negative Social Interaction
# 187  Negative Social Interaction
# 188  Negative Social Interaction
# 189  Negative Social Interaction
# 190  Negative Social Interaction
# 191  Negative Social Interaction
# 192  Negative Social Interaction
# 193  Negative Social Interaction
# 194  Negative Social Interaction
# 195  Negative Social Interaction
# 196  Negative Social Interaction
# 197  Negative Social Interaction
# 198  Negative Social Interaction
# 199  Negative Social Interaction
# 200  Negative Social Interaction
# 201  Negative Social Interaction
# 202  Negative Social Interaction
# 203  Negative Social Interaction
# 204  Negative Social Interaction
# 205  Negative Social Interaction
# 206  Negative Social Interaction
# 207  Negative Social Interaction
# 208  Negative Social Interaction
# 209  Negative Social Interaction
# 210  Negative Social Interaction
# 211  Negative Social Interaction
# 212  Negative Social Interaction
# 213  Negative Social Interaction
# 214  Negative Social Interaction
# 215  Negative Social Interaction
# 216  Negative Social Interaction
# 217  Negative Social Interaction
# 218  Negative Social Interaction
# 219  Negative Social Interaction
# 220  Negative Social Interaction
# 221  Negative Social Interaction
# 222  Negative Social Interaction
# 223  Negative Social Interaction
# 224  Negative Social Interaction
# 225  Negative Social Interaction
# 226  Negative Social Interaction
# 227  Negative Social Interaction
# 228  Negative Social Interaction
# 229  Negative Social Interaction
# 230  Negative Social Interaction
# 231  Negative Social Interaction
# 232  Negative Social Interaction
# 233  Negative Social Interaction
# 234  Negative Social Interaction
# 235  Negative Social Interaction
# 236  Negative Social Interaction
# 237  Negative Social Interaction
# 238  Negative Social Interaction
# 239  Negative Social Interaction
# 240  Negative Social Interaction
# 241  Negative Social Interaction
# 242  Negative Social Interaction
# 243  Negative Social Interaction
# 244  Negative Social Interaction
# 245  Negative Social Interaction
# 246  Negative Social Interaction
# 247  Negative Social Interaction
# 248  Negative Social Interaction
# 249  Negative Social Interaction
# 250  Negative Social Interaction
# 251  Negative Social Interaction
# 252  Negative Social Interaction
# 253  Negative Social Interaction
# 254  Negative Social Interaction
# 255  Negative Social Interaction
# 256  Negative Social Interaction
# 257  Negative Social Interaction
# 258  Negative Social Interaction
# 259  Negative Social Interaction
# 260  Negative Social Interaction
# 261  Negative Social Interaction
# 262  Negative Social Interaction
# 263  Negative Social Interaction
# 264  Negative Social Interaction
# 265  Negative Social Interaction
# 266  Negative Social Interaction
# 267  Negative Social Interaction
# 268  Negative Social Interaction
# 269  Negative Social Interaction
# 270  Negative Social Interaction
# 271  Negative Social Interaction
# 272  Negative Social Interaction
# 273  Negative Social Interaction
# 274  Negative Social Interaction
# 275  Negative Social Interaction
# 276  Negative Social Interaction
# 277  Negative Social Interaction
# 278  Negative Social Interaction
# 279  Negative Social Interaction
# 280  Negative Social Interaction
# 281  Negative Social Interaction
# 282  Negative Social Interaction
# 283  Negative Social Interaction
# 284  Negative Social Interaction
# 285  Negative Social Interaction
# 286  Negative Social Interaction
# 287  Negative Social Interaction
# 288  Negative Social Interaction
# 289  Negative Social Interaction
# 290  Negative Social Interaction
# 291  Negative Social Interaction
# 292  Negative Social Interaction
# 293  Negative Social Interaction
# 294  Negative Social Interaction
# 295  Negative Social Interaction
# 296  Negative Social Interaction
# 297  Negative Social Interaction
# 298  Negative Social Interaction
# 299  Negative Social Interaction
# 300  Negative Social Interaction
# 301  Negative Social Interaction
# 302  Negative Social Interaction
# 303  Negative Social Interaction
# 304  Negative Social Interaction
# 305  Negative Social Interaction
# 306  Negative Social Interaction
# 307  Negative Social Interaction
# 308  Negative Social Interaction
# 309  Negative Social Interaction
# 310  Negative Social Interaction
# 311  Negative Social Interaction
# 312  Negative Social Interaction
# 313  Negative Social Interaction
# 314  Negative Social Interaction
# 315  Negative Social Interaction
# 316  Negative Social Interaction
# 317  Negative Social Interaction
# 318  Negative Social Interaction
# 319  Negative Social Interaction
# 320  Negative Social Interaction
# 321  Negative Social Interaction
# 322  Negative Social Interaction
# 323  Negative Social Interaction
# 324  Negative Social Interaction
# 325  Negative Social Interaction
# 326  Negative Social Interaction
# 327  Negative Social Interaction
# 328  Negative Social Interaction
# 329  Negative Social Interaction
# 330  Negative Social Interaction
# 331  Negative Social Interaction
# 332  Negative Social Interaction
# 333  Negative Social Interaction
# 334  Negative Social Interaction
# 335  Negative Social Interaction
# 336  Negative Social Interaction
# 337  Negative Social Interaction
# 338  Negative Social Interaction
# 339  Negative Social Interaction
# 340  Negative Social Interaction
# 341  Negative Social Interaction
# 342  Negative Social Interaction
# 343  Negative Social Interaction
# 344  Negative Social Interaction
# 345  Negative Social Interaction
# 346  Negative Social Interaction
# 347  Negative Social Interaction
# 348  Negative Social Interaction
# 349  Negative Social Interaction
# 350  Negative Social Interaction
# 351  Negative Social Interaction
# 352  Negative Social Interaction
# 353  Negative Social Interaction
# 354  Negative Social Interaction
# 355  Negative Social Interaction
# 356  Negative Social Interaction
# 357  Negative Social Interaction
# 358  Negative Social Interaction
# 359  Negative Social Interaction
# 360  Negative Social Interaction
# 361  Negative Social Interaction
# 362  Negative Social Interaction
# 363  Negative Social Interaction
# 364  Negative Social Interaction
# 365  Negative Social Interaction
# 366  Negative Social Interaction
# 367  Negative Social Interaction
# 368  Negative Social Interaction
# 369  Negative Social Interaction
# 370  Negative Social Interaction
# 371  Negative Social Interaction
# 372  Negative Social Interaction
# 373  Negative Social Interaction
# 374  Negative Social Interaction
# 375  Negative Social Interaction
# 376  Negative Social Interaction
# 377  Negative Social Interaction
# 378  Negative Social Interaction
# 379  Negative Social Interaction
# 380  Negative Social Interaction
# 381  Negative Social Interaction
# 382  Negative Social Interaction
# 383  Negative Social Interaction
# 384  Negative Social Interaction
# 385  Negative Social Interaction
# 386  Negative Social Interaction
# 387  Negative Social Interaction
# 388  Negative Social Interaction
# 389  Negative Social Interaction
# 390  Negative Social Interaction
# 391  Negative Social Interaction
# 392  Negative Social Interaction

# %%
from scipy.stats import ttest_ind

behaviors = combined_df['Behavior'].unique()

for behavior in behaviors:
    pos_vals = combined_df.loc[
        (combined_df['Behavior'] == behavior) & 
        (combined_df['Condition'] == 'RI1'), '% Change Rate'
    ].dropna()
    neg_vals = combined_df.loc[
        (combined_df['Behavior'] == behavior) & 
        (combined_df['Condition'] == 'RI2'), '% Change Rate'
    ].dropna()
    
    if len(pos_vals) > 1 and len(neg_vals) > 1:
        stat, pval = ttest_ind(pos_vals, neg_vals, equal_var=False)
        print(f"Behavior: {behavior:20} | p-value = {pval:.4f}")
    else:
        print(f"Behavior: {behavior:20} | Not enough data for test")
# Out:
# Behavior: anogenital sniffing  | p-value = 0.6474
# Behavior: facial sniffing      | p-value = 0.7278
# Behavior: body sniffing        | p-value = 0.4785

# %%
def percent_change_resp_rate(signal, time, sniff_start, sampling_rate=100,
                             baseline_start_offset=-1.5, baseline_end_offset=-0.5,
                             post_start_offset=0.5, post_end_offset=1.5):
    baseline_mask = (time >= sniff_start + baseline_start_offset) & (time < sniff_start + baseline_end_offset)
    post_mask = (time >= sniff_start + post_start_offset) & (time < sniff_start + post_end_offset)

    baseline_peaks, _ = find_peaks(signal[baseline_mask], distance=0.2 * sampling_rate)
    post_peaks, _ = find_peaks(signal[post_mask], distance=0.2 * sampling_rate)

    baseline_times = time[baseline_mask][baseline_peaks]
    post_times = time[post_mask][post_peaks]

    baseline_ibis = np.diff(baseline_times)
    post_ibis = np.diff(post_times)

    if len(baseline_ibis) == 0 or len(post_ibis) == 0:
        return None

    baseline_rate = 1 / np.mean(baseline_ibis)
    post_rate = 1 / np.mean(post_ibis)

    rate_change = (post_rate - baseline_rate) / baseline_rate * 100
    return rate_change

# %%
# Define baseline and post-sniff windows to test (start and end offsets in seconds)
window_sets = [
    (-2.0, -1.0, 0.5, 1.5),
    (-1.5, -0.5, 0.5, 1.5),
    (-1.0, 0.0, 0.5, 1.5),
    (-1.5, -0.5, 0.0, 1.0),
    (-1.0, 0.0, 0.0, 1.0),
]

results = []

for (b_start, b_end, p_start, p_end) in window_sets:
    for label in ["RI1_3_6", "RI2_3_6"]:  # example labels, add yours
        boris_df = ri1_boris_data[label] if "RI1" in label else ri2_boris_data[label]
        resp_entry = resp_data.get(label)
        if resp_entry is None:
            print(f"Skipping {label}: no respiration data.")
            continue
        agent_events = extract_agent_sniff_events(boris_df)
        signal = resp_entry["signal"]
        time = resp_entry["time"]
        sr = resp_entry["sampling_rate"]

        for _, row in agent_events.iterrows():
            behavior = row["Behavior"]
            sniff_start = row["Start (s)"]

            rate_change = percent_change_resp_rate(
                signal, time, sniff_start, sr,
                baseline_start_offset=b_start,
                baseline_end_offset=b_end,
                post_start_offset=p_start,
                post_end_offset=p_end,
            )
            if rate_change is None:
                continue

            results.append({
                "Trial": label,
                "Condition": "RI1" if "RI1" in label else "RI2",
                "Behavior": behavior,
                "Sniff Time (s)": sniff_start,
                "% Change Rate": rate_change,
                "Baseline Window": f"{b_start} to {b_end}",
                "Post Window": f"{p_start} to {p_end}"
            })

# Create a DataFrame for analysis
window_compare_df = pd.DataFrame(results)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 8))

# Define your color palette with labels for legend
palette = {
    'RI1': (83/255, 161/255, 169/255),  # Positive Social Interaction color
    'RI2': (169/255, 83/255, 118/255)   # Negative Social Interaction color
}

# Plot the boxplot
box = sns.boxplot(
    data=window_compare_df,
    x='Baseline Window',
    y='% Change Rate',
    hue='Condition',
    palette=palette
)

# Plot the swarmplot without adding a new legend
sns.swarmplot(
    data=window_compare_df,
    x='Baseline Window',
    y='% Change Rate',
    hue='Condition',
    dodge=True,
    color='k',
    alpha=0.6,
    size=3,
    legend=False  # THIS PREVENTS adding a second legend
)

plt.title('Respiratory Rate % Change by Condition and Baseline Window')
plt.ylabel('Percent Change in Respiration Rate')
plt.xlabel('Baseline Window (seconds relative to sniff start)')
plt.xticks(rotation=45)

# Customize legend labels manually
handles, labels = box.get_legend_handles_labels()
new_labels = ['Positive Social Interaction', 'Negative Social Interaction']
plt.legend(handles=handles, labels=new_labels, title='Condition', loc='upper right')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\sjs93\AppData\Local\Temp\ipykernel_50964\1632807842.py:22: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:k'` for the same effect.
#
#   sns.swarmplot(

# %%
from scipy.stats import ttest_ind

behaviors = window_compare_df['Behavior'].unique()
baseline_windows = window_compare_df['Baseline Window'].unique()

for window in baseline_windows:
    print(f"\n=== Baseline window: {window} ===")
    for behavior in behaviors:
        pos_vals = window_compare_df.loc[
            (window_compare_df['Baseline Window'] == window) &
            (window_compare_df['Behavior'] == behavior) &
            (window_compare_df['Condition'] == 'RI1'), '% Change Rate'
        ].dropna()
        neg_vals = window_compare_df.loc[
            (window_compare_df['Baseline Window'] == window) &
            (window_compare_df['Behavior'] == behavior) &
            (window_compare_df['Condition'] == 'RI2'), '% Change Rate'
        ].dropna()

        if len(pos_vals) > 1 and len(neg_vals) > 1:
            stat, pval = ttest_ind(pos_vals, neg_vals, equal_var=False)
            print(f"Behavior: {behavior:20} | p-value = {pval:.4f}")
        else:
            print(f"Behavior: {behavior:20} | Not enough data")
# Out:
# === Baseline window: -2.0 to -1.0 ===
# Behavior: anogenital sniffing  | p-value = 0.9609
# Behavior: facial sniffing      | p-value = 0.8797
# Behavior: body sniffing        | p-value = 0.0926
#
# === Baseline window: -1.5 to -0.5 ===
# Behavior: anogenital sniffing  | p-value = 0.5769
# Behavior: facial sniffing      | p-value = 0.7809
# Behavior: body sniffing        | p-value = 0.2326
#
# === Baseline window: -1.0 to 0.0 ===
# Behavior: anogenital sniffing  | p-value = 0.6982
# Behavior: facial sniffing      | p-value = 0.9317
# Behavior: body sniffing        | p-value = 0.1071

# %%
# Only RI2 trials and fighting behavior
ri2_fight_df = combined_df[
    (combined_df["Condition"] == "RI2") &
    (combined_df["Behavior"].str.lower() == "fighting")  # Make sure this matches exactly
]

print(f"Found {len(ri2_fight_df)} fight events in RI2")
# Out:
# Found 0 fight events in RI2

# %%
print(combined_df.loc[combined_df["Condition"] == "RI2", "Behavior"].unique())
# Out:
# ['facial sniffing' 'body sniffing' 'anogenital sniffing']

# %%
print(combined_df.columns)
# Out:
# Index(['Trial', 'Condition', 'Behavior', 'Sniff Time (s)', '% Change Rate',
#        'Condition Label'],
#       dtype='object')

# %%
combined_df
# Out:
#        Trial Condition             Behavior  Sniff Time (s)  % Change Rate  \
# 0    RI1_3_6       RI1  anogenital sniffing           8.862  -1.578947e+01
# 1    RI1_3_6       RI1      facial sniffing          12.069   0.000000e+00
# 2    RI1_3_6       RI1  anogenital sniffing          80.310  -8.474576e+00
# 3    RI1_3_6       RI1      facial sniffing          86.207   1.388889e+00
# 4    RI1_3_6       RI1      facial sniffing          88.034  -1.666667e+01
# 5    RI1_3_6       RI1  anogenital sniffing          90.690  -2.156863e+01
# 6    RI1_3_6       RI1      facial sniffing         107.724  -3.059361e+01
# 7    RI1_3_6       RI1      facial sniffing         183.724  -1.250000e+01
# 8    RI1_3_6       RI1      facial sniffing         200.517   4.805195e+01
# 9    RI1_3_6       RI1      facial sniffing         217.172   1.733333e+01
# 10   RI1_3_6       RI1      facial sniffing         229.897   2.800000e+01
# 11   RI1_3_6       RI1      facial sniffing         243.793   5.172414e+00
# 12   RI1_3_6       RI1  anogenital sniffing         260.862   5.205479e+01
# 13   RI1_3_6       RI1      facial sniffing         337.172  -2.207792e+01
# 14   RI1_3_6       RI1      facial sniffing         367.345  -5.813953e+00
# 15   RI1_3_6       RI1      facial sniffing         368.483   3.986486e+01
# 16   RI1_3_6       RI1        body sniffing         404.310   6.250000e+00
# 17   RI1_3_6       RI1      facial sniffing         416.414  -3.466667e+01
# 18   RI1_3_6       RI1        body sniffing         596.931   1.481481e+01
# 19   RI1_3_6       RI1  anogenital sniffing         597.517  -1.136364e+01
# 20   RI1_3_6       RI1      facial sniffing         598.034  -2.872340e+01
# 21   RI1_4_7       RI1      facial sniffing           8.167   1.678657e-13
# 22   RI1_4_7       RI1      facial sniffing          24.467  -9.302326e+00
# 23   RI1_4_7       RI1  anogenital sniffing         346.067   6.976744e+00
# 24   RI1_4_7       RI1      facial sniffing         365.033   1.954023e+01
# 25   RI1_4_7       RI1      facial sniffing         452.867  -7.058824e+00
# 26   RI1_4_7       RI1      facial sniffing         480.500   7.602339e+00
# 27   RI1_4_7       RI1      facial sniffing         483.067   1.576087e+01
# 28   RI1_2_3       RI1      facial sniffing          72.223  -1.351351e+00
# 29   RI1_2_3       RI1        body sniffing          75.723   1.481481e+01
# 30   RI1_2_3       RI1        body sniffing          80.222   5.361446e+01
# 31   RI1_2_3       RI1  anogenital sniffing          85.222  -3.571429e-01
# 32   RI1_2_3       RI1        body sniffing         145.222  -1.298701e+01
# 33   RI1_2_3       RI1        body sniffing         249.222   2.197802e+01
# 34   RI1_4_8       RI1      facial sniffing           5.733   7.792208e+00
# 35   RI1_4_8       RI1      facial sniffing          17.167  -2.112676e+01
# 36   RI1_4_8       RI1  anogenital sniffing          18.700   2.313433e+01
# 37   RI1_4_8       RI1        body sniffing          35.133  -2.747253e+00
# 38   RI1_4_8       RI1  anogenital sniffing          35.600   4.451220e+01
# 39   RI1_4_8       RI1      facial sniffing          37.400  -1.392405e+01
# 40   RI1_4_8       RI1  anogenital sniffing          44.800   1.137757e-12
# 41   RI1_4_8       RI1      facial sniffing          52.733  -1.149425e+01
# 42   RI1_4_8       RI1      facial sniffing          56.400   2.321429e+01
# 43   RI1_4_8       RI1      facial sniffing          62.700   3.392857e+01
# 44   RI1_4_8       RI1      facial sniffing          77.267  -1.785714e+01
# 45   RI1_4_8       RI1      facial sniffing          85.367   7.792208e+00
# 46   RI1_4_8       RI1      facial sniffing         138.200   1.292517e+01
# 47   RI1_4_8       RI1        body sniffing         174.400  -1.219512e+00
# 48   RI1_4_8       RI1  anogenital sniffing         176.133   0.000000e+00
# 49   RI1_4_8       RI1        body sniffing         176.200   0.000000e+00
# 50   RI1_4_8       RI1  anogenital sniffing         185.467   7.792208e+00
# 51   RI1_4_8       RI1  anogenital sniffing         203.733  -8.433735e+00
# 52   RI1_4_8       RI1        body sniffing         234.067  -4.649123e+01
# 53   RI1_4_8       RI1      facial sniffing         324.800  -1.555556e+01
# 54   RI1_4_8       RI1        body sniffing         344.567  -1.746032e+01
# 55   RI1_4_8       RI1      facial sniffing         363.500  -4.597701e+00
# 56   RI1_4_8       RI1      facial sniffing         390.367  -3.148148e+01
# 57   RI1_4_8       RI1      facial sniffing         455.933   3.012048e+01
# 58   RI1_4_8       RI1        body sniffing         463.733   2.325581e+00
# 59   RI1_4_8       RI1      facial sniffing         531.600   3.098592e+01
# 60   RI2_3_6       RI2      facial sniffing          25.600  -1.182432e+01
# 61   RI2_3_6       RI2        body sniffing          26.167  -7.602339e+00
# 62   RI2_3_6       RI2  anogenital sniffing          26.600   6.578947e+00
# 63   RI2_3_6       RI2      facial sniffing          68.767  -4.000000e+00
# 64   RI2_3_6       RI2      facial sniffing          91.900   2.740741e+01
# 65   RI2_3_6       RI2      facial sniffing         153.900   3.000000e+01
# 66   RI2_3_6       RI2      facial sniffing         156.233  -2.840909e+01
# 67   RI2_3_6       RI2      facial sniffing         195.433  -2.266667e+01
# 68   RI2_3_6       RI2        body sniffing         195.767  -1.919192e+01
# 69   RI2_3_6       RI2      facial sniffing         196.167   0.000000e+00
# 70   RI2_3_6       RI2        body sniffing         198.333  -1.534392e+01
# 71   RI2_3_6       RI2      facial sniffing         218.300   1.612903e+00
# 72   RI2_3_6       RI2        body sniffing         219.433  -2.394366e+01
# 73   RI2_3_6       RI2      facial sniffing         226.433  -3.493976e+01
# 74   RI2_3_6       RI2        body sniffing         228.433   3.833333e+01
# 75   RI2_3_6       RI2  anogenital sniffing         234.167   1.712329e+01
# 76   RI2_3_6       RI2      facial sniffing         234.867   3.536585e+01
# 77   RI2_3_6       RI2  anogenital sniffing         235.567  -3.257576e+01
# 78   RI2_3_6       RI2      facial sniffing         249.733  -7.894737e+00
# 79   RI2_3_6       RI2      facial sniffing         257.833   7.042254e+00
# 80   RI2_3_6       RI2      facial sniffing         267.400  -4.225352e+00
# 81   RI2_3_6       RI2      facial sniffing         269.767  -5.632184e+01
# 82   RI2_3_6       RI2      facial sniffing         273.367  -4.716981e+01
# 83   RI2_3_6       RI2      facial sniffing         282.033  -4.230769e+01
# 84   RI2_3_6       RI2      facial sniffing         288.200  -2.125000e+01
# 85   RI2_3_6       RI2      facial sniffing         290.133   3.793103e+01
# 86   RI2_3_6       RI2      facial sniffing         318.700  -1.176471e+01
# 87   RI2_3_6       RI2      facial sniffing         343.133  -9.628964e-12
# 88   RI2_3_6       RI2  anogenital sniffing         430.167   6.764706e+01
# 89   RI2_3_6       RI2  anogenital sniffing         449.800  -1.272727e+01
# 90   RI2_3_6       RI2        body sniffing         455.067   1.007752e+01
# 91   RI2_3_6       RI2        body sniffing         502.667   2.613636e+01
# 92   RI2_3_6       RI2      facial sniffing         503.133   4.625000e+01
# 93   RI2_3_6       RI2  anogenital sniffing         524.333  -7.526882e+00
# 94   RI2_3_6       RI2      facial sniffing         537.000  -3.278689e+00
# 95   RI2_3_6       RI2      facial sniffing         548.033  -1.549296e+01
# 96   RI2_3_6       RI2        body sniffing         550.833  -2.921348e+01
# 97   RI2_3_6       RI2      facial sniffing         554.333  -5.747126e+00
# 98   RI2_3_6       RI2      facial sniffing         559.000  -1.518987e+01
# 99   RI2_3_6       RI2      facial sniffing         596.333   2.222222e+01
# 100  RI2_4_7       RI2      facial sniffing           6.767   5.063291e+00
# 101  RI2_4_7       RI2      facial sniffing          13.767  -1.250000e+01
# 102  RI2_4_7       RI2      facial sniffing          29.633   3.846154e+00
# 103  RI2_4_7       RI2        body sniffing          30.767  -6.896552e+00
# 104  RI2_4_7       RI2  anogenital sniffing          31.767  -3.046875e+01
# 105  RI2_4_7       RI2        body sniffing          35.133  -1.250000e+00
# 106  RI2_4_7       RI2  anogenital sniffing          36.600  -1.265823e+00
# 107  RI2_4_7       RI2      facial sniffing          37.567   2.162162e+01
# 108  RI2_4_7       RI2      facial sniffing          66.300   2.000000e+01
# 109  RI2_4_7       RI2  anogenital sniffing          69.900  -1.123596e+01
# 110  RI2_4_7       RI2  anogenital sniffing          73.600   4.444444e+01
# 111  RI2_4_7       RI2        body sniffing          75.633  -1.195652e+01
# 112  RI2_4_7       RI2  anogenital sniffing          77.133  -6.024096e-01
# 113  RI2_4_7       RI2      facial sniffing          99.333  -4.814815e+01
# 114  RI2_4_7       RI2        body sniffing         100.100   3.965517e+01
# 115  RI2_4_7       RI2  anogenital sniffing         100.467   1.506849e+01
# 116  RI2_4_7       RI2      facial sniffing         104.067   5.161290e+01
# 117  RI2_4_7       RI2        body sniffing         166.967  -3.703704e+01
# 118  RI2_4_7       RI2  anogenital sniffing         168.900  -1.142857e+01
# 119  RI2_4_7       RI2  anogenital sniffing         171.967   4.285714e+01
# 120  RI2_4_7       RI2  anogenital sniffing         190.433  -6.818182e+00
# 121  RI2_4_7       RI2  anogenital sniffing         214.033   1.750000e+01
# 122  RI2_4_7       RI2        body sniffing         226.633  -1.256831e+01
# 123  RI2_4_7       RI2  anogenital sniffing         227.133   2.564103e+00
# 124  RI2_4_7       RI2  anogenital sniffing         228.533  -6.250000e+00
# 125  RI2_4_7       RI2      facial sniffing         298.300  -6.601562e+01
# 126  RI2_4_7       RI2  anogenital sniffing         305.100  -2.205882e+01
# 127  RI2_4_7       RI2        body sniffing         334.600  -2.150538e+01
# 128  RI2_4_7       RI2      facial sniffing         334.867  -1.363636e+01
# 129  RI2_4_7       RI2        body sniffing         335.600  -5.617978e+00
# 130  RI2_4_7       RI2        body sniffing         367.700  -3.125000e+01
# 131  RI2_4_7       RI2  anogenital sniffing         380.300  -4.054054e+00
# 132  RI2_4_7       RI2  anogenital sniffing         381.732   3.687500e+01
# 133  RI2_4_7       RI2      facial sniffing         409.867  -5.154639e+00
# 134  RI2_4_7       RI2  anogenital sniffing         429.067   8.196721e+00
# 135  RI2_4_7       RI2  anogenital sniffing         446.667   2.368421e+01
# 136  RI2_4_7       RI2      facial sniffing         454.000   7.792208e+00
# 137  RI2_4_7       RI2        body sniffing         462.933   3.103448e+01
# 138  RI2_4_7       RI2        body sniffing         465.967   0.000000e+00
# 139  RI2_4_7       RI2  anogenital sniffing         467.333  -2.900433e+01
# 140  RI2_4_7       RI2        body sniffing         470.533   2.500000e+01
# 141  RI2_4_7       RI2      facial sniffing         471.633  -1.734694e+01
# 142  RI2_4_7       RI2      facial sniffing         472.367   4.347826e+00
# 143  RI2_4_7       RI2      facial sniffing         495.733   1.746032e+01
# 144  RI2_4_7       RI2      facial sniffing         518.200   2.222222e+01
# 145  RI2_4_7       RI2      facial sniffing         535.867   1.960121e-11
# 146  RI2_4_7       RI2      facial sniffing         549.467   1.079545e+01
# 147  RI2_4_7       RI2  anogenital sniffing         556.833  -1.562500e+01
# 148  RI2_4_7       RI2      facial sniffing         561.567   1.355932e+01
# 149  RI2_4_7       RI2        body sniffing         582.600   5.000000e+00
# 150  RI2_4_7       RI2  anogenital sniffing         583.367  -4.400000e+01
# 151  RI2_4_7       RI2      facial sniffing         586.333   1.935484e+01
# 152  RI2_4_7       RI2        body sniffing         586.667   1.694915e+01
# 153  RI2_4_7       RI2      facial sniffing         587.433  -2.972973e+01
# 154  RI2_4_7       RI2        body sniffing         602.500  -1.410256e+01
# 155  RI2_4_7       RI2      facial sniffing         603.533   2.108434e+01
# 156  RI2_4_7       RI2        body sniffing         605.033  -3.333333e+01
# 157  RI2_2_3       RI2        body sniffing           7.655  -2.456140e+01
# 158  RI2_2_3       RI2  anogenital sniffing           9.905   2.289157e+01
# 159  RI2_2_3       RI2        body sniffing          29.155  -1.414474e+01
# 160  RI2_2_3       RI2        body sniffing          33.654   1.803279e+01
# 161  RI2_2_3       RI2  anogenital sniffing         102.655   1.492537e+01
# 162  RI2_2_3       RI2        body sniffing         104.901   4.423077e+01
# 163  RI2_2_3       RI2      facial sniffing         182.405   3.670886e+01
# 164  RI2_2_3       RI2        body sniffing         190.655  -4.583333e+01
# 165  RI2_2_3       RI2      facial sniffing         192.901   2.343750e+01
# 166  RI2_2_3       RI2      facial sniffing         198.155  -5.333333e+00
# 167  RI2_2_3       RI2      facial sniffing         229.533  -4.819277e+00
# 168  RI2_2_3       RI2        body sniffing         230.400   4.615385e+01
# 169  RI2_2_3       RI2        body sniffing         232.700  -1.547619e+01
# 170  RI2_2_3       RI2        body sniffing         238.533  -2.439024e+00
# 171  RI2_2_3       RI2      facial sniffing         239.033   3.947368e+00
# 172  RI2_2_3       RI2      facial sniffing         241.433  -2.469136e+00
# 173  RI2_2_3       RI2        body sniffing         268.157  -3.586498e+01
# 174  RI2_2_3       RI2      facial sniffing         272.656   2.580645e+01
# 175  RI2_2_3       RI2      facial sniffing         281.656   1.111111e+01
# 176  RI2_2_3       RI2        body sniffing         282.155   7.017544e+00
# 177  RI2_2_3       RI2      facial sniffing         282.901   1.600000e+01
# 178  RI2_2_3       RI2        body sniffing         312.154  -5.769231e+00
# 179  RI2_2_3       RI2        body sniffing         343.500  -1.639344e+00
# 180  RI2_2_3       RI2        body sniffing         345.033  -6.250000e+00
# 181  RI2_2_3       RI2      facial sniffing         374.900   4.333333e+01
# 182  RI2_2_3       RI2        body sniffing         377.153  -1.919192e+01
# 183  RI2_2_3       RI2        body sniffing         410.153  -6.896552e+00
# 184  RI2_2_3       RI2        body sniffing         414.902   3.333333e+00
# 185  RI2_2_3       RI2  anogenital sniffing         418.153  -5.649718e-01
# 186  RI2_2_3       RI2        body sniffing         427.653  -3.815789e+01
# 187  RI2_2_3       RI2        body sniffing         435.653   2.613636e+01
# 188  RI2_2_3       RI2        body sniffing         438.153  -2.676056e+01
# 189  RI2_2_3       RI2  anogenital sniffing         461.653  -2.615385e+01
# 190  RI2_2_3       RI2        body sniffing         497.152   1.724138e+00
# 191  RI2_2_3       RI2      facial sniffing         497.903  -2.420091e+01
# 192  RI2_2_3       RI2        body sniffing         524.087   1.282051e+00
# 193  RI2_2_3       RI2        body sniffing         528.086  -1.034483e+01
# 194  RI2_2_3       RI2        body sniffing         529.586  -1.666667e+01
# 195  RI2_2_3       RI2        body sniffing         534.336  -1.814346e+01
# 196  RI2_2_3       RI2  anogenital sniffing         541.933  -1.789474e+01
# 197  RI2_2_3       RI2      facial sniffing         591.087   1.190476e+00
# 198  RI2_2_3       RI2        body sniffing         596.167  -4.083333e+01
# 199  RI2_2_3       RI2        body sniffing         598.800  -2.449799e+01
# 200  RI2_4_8       RI2      facial sniffing           3.333  -2.314815e+01
# 201  RI2_4_8       RI2        body sniffing          16.833  -3.611111e+01
# 202  RI2_4_8       RI2      facial sniffing          18.200  -2.112676e+01
# 203  RI2_4_8       RI2  anogenital sniffing          19.100  -1.034483e+01
# 204  RI2_4_8       RI2  anogenital sniffing          19.900   6.363636e+01
# 205  RI2_4_8       RI2      facial sniffing          27.200   1.388889e+01
# 206  RI2_4_8       RI2        body sniffing          28.900   4.457831e+01
# 207  RI2_4_8       RI2        body sniffing          31.000   0.000000e+00
# 208  RI2_4_8       RI2      facial sniffing          40.967   1.358025e+01
# 209  RI2_4_8       RI2      facial sniffing          59.333  -7.894737e+00
# 210  RI2_4_8       RI2      facial sniffing          61.933   1.234568e+00
# 211  RI2_4_8       RI2  anogenital sniffing          66.033   5.000000e+01
# 212  RI2_4_8       RI2  anogenital sniffing          73.467  -2.314815e+01
# 213  RI2_4_8       RI2  anogenital sniffing          76.033  -3.947368e+00
# 214  RI2_4_8       RI2        body sniffing         100.733   1.764706e+01
# 215  RI2_4_8       RI2      facial sniffing         101.133   8.771930e+00
# 216  RI2_4_8       RI2  anogenital sniffing         111.300  -2.247191e+00
# 217  RI2_4_8       RI2      facial sniffing         113.167  -2.435897e+01
# 218  RI2_4_8       RI2        body sniffing         113.767   3.554217e+01
# 219  RI2_4_8       RI2        body sniffing         131.500   2.857143e+01
# 220  RI2_4_8       RI2  anogenital sniffing         158.733   0.000000e+00
# 221  RI2_4_8       RI2      facial sniffing         165.300   1.264368e+01
# 222  RI2_4_8       RI2  anogenital sniffing         184.100  -3.574297e+01
# 223  RI2_4_8       RI2      facial sniffing         193.100   4.797297e+01
# 224  RI2_4_8       RI2        body sniffing         204.600  -2.857143e+01
# 225  RI2_4_8       RI2      facial sniffing         206.933  -4.758065e+01
# 226  RI2_4_8       RI2  anogenital sniffing         210.100  -1.717172e+01
# 227  RI2_4_8       RI2      facial sniffing         221.000  -2.027027e+01
# 228  RI2_4_8       RI2      facial sniffing         224.267   8.983051e+01
# 229  RI2_4_8       RI2      facial sniffing         235.333  -4.285714e+00
# 230  RI2_4_8       RI2        body sniffing         244.000   3.103448e+01
# 231  RI2_4_8       RI2      facial sniffing         244.300   1.304348e+01
# 232  RI2_4_8       RI2      facial sniffing         250.467   2.026144e+01
# 233  RI2_4_8       RI2      facial sniffing         263.933   1.176471e+01
# 234  RI2_4_8       RI2      facial sniffing         269.000   3.396226e+01
# 235  RI2_4_8       RI2      facial sniffing         274.733   3.333333e+00
# 236  RI2_4_8       RI2        body sniffing         294.433  -1.315789e+01
# 237  RI2_4_8       RI2  anogenital sniffing         295.533  -2.391304e+01
# 238  RI2_4_8       RI2        body sniffing         296.233  -1.159420e+01
# 239  RI2_4_8       RI2      facial sniffing         297.100  -1.587302e+00
# 240  RI2_4_8       RI2  anogenital sniffing         298.000  -1.265823e+00
# 241  RI2_4_8       RI2        body sniffing         314.900  -1.333333e+01
# 242  RI2_4_8       RI2        body sniffing         328.167  -4.761905e+00
# 243  RI2_4_8       RI2      facial sniffing         336.333   2.469136e+00
# 244  RI2_4_8       RI2      facial sniffing         356.167   9.213483e+01
# 245  RI2_4_8       RI2        body sniffing         378.733  -5.954545e+01
# 246  RI2_4_8       RI2      facial sniffing         378.933  -4.276316e+01
# 247  RI2_4_8       RI2        body sniffing         401.533  -1.702128e+01
# 248  RI2_4_8       RI2      facial sniffing         422.433  -8.219178e+00
# 249  RI2_4_8       RI2        body sniffing         423.167  -4.298246e+01
# 250  RI2_4_8       RI2  anogenital sniffing         426.333   7.109375e+01
# 251  RI2_4_8       RI2      facial sniffing         431.767   3.518519e+01
# 252  RI2_4_8       RI2      facial sniffing         452.167  -2.168675e+01
# 253  RI2_4_8       RI2      facial sniffing         457.933   5.263158e+00
# 254  RI2_4_8       RI2  anogenital sniffing         459.400   1.408451e+01
# 255  RI2_4_8       RI2      facial sniffing         477.533  -8.333333e+00
# 256  RI2_4_8       RI2      facial sniffing         488.333   3.186813e+01
# 257  RI2_4_8       RI2        body sniffing         494.167  -3.125000e+00
# 258  RI2_4_8       RI2      facial sniffing         496.633   5.333333e+01
# 259  RI2_4_8       RI2      facial sniffing         498.700   1.190476e+00
# 260  RI2_4_8       RI2      facial sniffing         500.800   3.333333e+01
# 261  RI2_4_8       RI2  anogenital sniffing         523.433   5.633803e+00
# 262  RI2_4_8       RI2      facial sniffing         526.067  -6.493506e-01
# 263  RI2_4_8       RI2      facial sniffing         530.500  -3.412698e+01
# 264  RI2_4_8       RI2      facial sniffing         532.167   8.474576e+00
# 265  RI2_4_8       RI2      facial sniffing         547.367  -3.797468e+00
# 266  RI2_4_8       RI2      facial sniffing         557.367  -2.747253e+01
# 267  RI2_4_8       RI2        body sniffing         557.600  -1.397849e+01
# 268  RI2_4_8       RI2      facial sniffing         558.167   2.307692e+01
# 269  RI2_1_1       RI2        body sniffing          11.533   1.126761e+01
# 270  RI2_1_1       RI2        body sniffing          38.467   0.000000e+00
# 271  RI2_1_1       RI2        body sniffing          83.933  -1.809524e+01
# 272  RI2_1_1       RI2      facial sniffing         126.933  -2.790698e+01
# 273  RI2_1_1       RI2        body sniffing         130.000   1.746988e+01
# 274  RI2_1_1       RI2        body sniffing         132.133  -2.888889e+01
# 275  RI2_1_1       RI2        body sniffing         228.400  -2.612613e+01
# 276  RI2_1_1       RI2        body sniffing         241.467  -2.807018e+01
# 277  RI2_1_1       RI2      facial sniffing         341.571  -5.952381e+00
# 278  RI2_1_1       RI2        body sniffing         349.071   2.142857e+01
# 279  RI2_1_1       RI2      facial sniffing         358.570  -1.111111e+01
# 280  RI2_1_1       RI2        body sniffing         420.069   2.542373e+01
# 281  RI2_1_1       RI2        body sniffing         427.071  -4.705882e+00
# 282  RI2_1_1       RI2        body sniffing         472.322   1.739130e+01
# 283  RI2_1_1       RI2        body sniffing         475.821  -1.500000e+01
# 284  RI2_1_1       RI2        body sniffing         528.822  -3.833333e+01
# 285  RI2_1_1       RI2      facial sniffing         582.324   3.312500e+01
# 286  RI2_1_1       RI2        body sniffing         582.818  -4.918033e+00
# 287  RI2_1_2       RI2      facial sniffing           8.067  -1.720430e+01
# 288  RI2_1_2       RI2      facial sniffing          99.933  -3.846154e+01
# 289  RI2_1_2       RI2        body sniffing         149.133  -5.194805e+00
# 290  RI2_1_2       RI2      facial sniffing         158.433  -1.666667e+01
# 291  RI2_1_2       RI2        body sniffing         160.167  -2.272727e+00
# 292  RI2_1_2       RI2      facial sniffing         163.700  -3.833333e+01
# 293  RI2_1_2       RI2      facial sniffing         164.200  -1.428571e+00
# 294  RI2_1_2       RI2        body sniffing         164.833  -1.372549e+01
# 295  RI2_1_2       RI2  anogenital sniffing         199.155   1.551724e+01
# 296  RI2_1_2       RI2  anogenital sniffing         202.155   2.027027e+01
# 297  RI2_1_2       RI2        body sniffing         203.667   1.633987e+01
# 298  RI2_1_2       RI2      facial sniffing         204.200  -1.333333e+00
# 299  RI2_1_2       RI2      facial sniffing         208.133   2.531646e+00
# 300  RI2_1_2       RI2        body sniffing         243.155  -2.021858e+01
# 301  RI2_1_2       RI2      facial sniffing         245.154  -8.955224e+00
# 302  RI2_1_2       RI2      facial sniffing         250.655   1.071429e+01
# 303  RI2_1_2       RI2        body sniffing         284.306  -2.000000e+01
# 304  RI2_1_2       RI2      facial sniffing         287.055   1.208333e+02
# 305  RI2_1_2       RI2        body sniffing         308.033   3.636364e+01
# 306  RI2_1_2       RI2  anogenital sniffing         310.467   7.801418e+00
# 307  RI2_1_2       RI2        body sniffing         310.867   2.340426e+01
# 308  RI2_1_2       RI2        body sniffing         314.933   4.615385e+00
# 309  RI2_1_2       RI2      facial sniffing         316.767   2.214286e+01
# 310  RI2_1_2       RI2        body sniffing         319.033   1.351351e+00
# 311  RI2_1_2       RI2      facial sniffing         319.867  -1.014493e+01
# 312  RI2_1_2       RI2        body sniffing         321.800   1.470588e+00
# 313  RI2_1_2       RI2        body sniffing         323.000   3.561644e+01
# 314  RI2_1_2       RI2  anogenital sniffing         324.600  -1.965812e+01
# 315  RI2_1_2       RI2        body sniffing         325.400  -8.653846e+00
# 316  RI2_1_2       RI2        body sniffing         327.733   2.777778e+00
# 317  RI2_1_2       RI2  anogenital sniffing         330.100  -1.970588e+01
# 318  RI2_1_2       RI2        body sniffing         332.000  -4.054054e+00
# 319  RI2_1_2       RI2  anogenital sniffing         333.233  -2.272727e+00
# 320  RI2_1_2       RI2      facial sniffing         395.057   1.117647e+01
# 321  RI2_1_2       RI2      facial sniffing         403.804   6.626506e+00
# 322  RI2_1_2       RI2        body sniffing         452.556   1.166667e+01
# 323  RI2_1_2       RI2        body sniffing         460.804  -1.111111e+01
# 324  RI2_1_2       RI2        body sniffing         495.805  -1.402439e+01
# 325  RI2_1_2       RI2        body sniffing         498.055  -1.718750e+01
# 326  RI2_1_2       RI2      facial sniffing         499.301  -1.333333e+00
# 327  RI2_1_2       RI2        body sniffing         511.307   7.692308e+00
# 328  RI2_1_2       RI2  anogenital sniffing         518.302  -1.643836e+01
# 329  RI2_1_2       RI2        body sniffing         523.056   5.063291e+00
# 330  RI2_1_2       RI2      facial sniffing         558.304  -3.529412e+00
# 331  RI2_1_2       RI2        body sniffing         560.550  -8.457711e+00
# 332  RI2_1_2       RI2      facial sniffing         565.052   2.328767e+01
# 333  RI2_1_2       RI2        body sniffing         581.000  -2.626263e+01
# 334  RI2_2_4       RI2        body sniffing           5.933  -2.134831e+01
# 335  RI2_2_4       RI2  anogenital sniffing           7.333  -2.602740e+01
# 336  RI2_2_4       RI2        body sniffing           7.867   3.653846e+01
# 337  RI2_2_4       RI2      facial sniffing           9.200  -2.511416e+01
# 338  RI2_2_4       RI2      facial sniffing          10.133  -1.219512e+01
# 339  RI2_2_4       RI2        body sniffing          12.667  -9.677419e+00
# 340  RI2_2_4       RI2  anogenital sniffing          13.333  -3.846154e+00
# 341  RI2_2_4       RI2        body sniffing          14.267   1.190476e+00
# 342  RI2_2_4       RI2        body sniffing          14.733   1.746988e+01
# 343  RI2_2_4       RI2        body sniffing          17.467   1.250000e+01
# 344  RI2_2_4       RI2        body sniffing          26.867   8.333333e+00
# 345  RI2_2_4       RI2  anogenital sniffing          30.400   1.186441e+01
# 346  RI2_2_4       RI2        body sniffing          30.867  -1.812865e+01
# 347  RI2_2_4       RI2      facial sniffing          64.400  -7.500000e+00
# 348  RI2_2_4       RI2  anogenital sniffing          68.600   7.462687e+00
# 349  RI2_2_4       RI2      facial sniffing          77.267   5.000000e+00
# 350  RI2_2_4       RI2        body sniffing          79.933  -1.666667e+01
# 351  RI2_2_4       RI2      facial sniffing         122.467   1.694915e+00
# 352  RI2_2_4       RI2        body sniffing         141.667   5.362319e+01
# 353  RI2_2_4       RI2      facial sniffing         142.933   4.705882e+00
# 354  RI2_2_4       RI2      facial sniffing         146.733   1.686047e+01
# 355  RI2_2_4       RI2      facial sniffing         149.733   5.128205e+00
# 356  RI2_2_4       RI2        body sniffing         177.867   1.129032e+01
# 357  RI2_2_4       RI2        body sniffing         183.533  -3.000000e+01
# 358  RI2_2_4       RI2        body sniffing         211.800  -2.894737e+01
# 359  RI2_2_4       RI2        body sniffing         217.067   4.308554e-12
# 360  RI2_2_4       RI2        body sniffing         220.000   1.690141e+01
# 361  RI2_2_4       RI2  anogenital sniffing         235.267  -3.950617e+01
# 362  RI2_2_4       RI2        body sniffing         236.067   9.259259e+00
# 363  RI2_2_4       RI2        body sniffing         239.933   3.392857e+01
# 364  RI2_2_4       RI2  anogenital sniffing         242.333   5.692308e+01
# 365  RI2_2_4       RI2        body sniffing         260.667  -4.807692e+01
# 366  RI2_2_4       RI2        body sniffing         269.067   4.651163e+00
# 367  RI2_2_4       RI2        body sniffing         272.933   1.016949e+01
# 368  RI2_2_4       RI2        body sniffing         287.267  -2.898551e+00
# 369  RI2_2_4       RI2        body sniffing         296.400   3.015873e+01
# 370  RI2_2_4       RI2  anogenital sniffing         301.867  -2.409639e+00
# 371  RI2_2_4       RI2      facial sniffing         302.467   2.446809e+01
# 372  RI2_2_4       RI2        body sniffing         329.400   1.406250e+01
# 373  RI2_2_4       RI2        body sniffing         344.400   3.125000e+00
# 374  RI2_2_4       RI2      facial sniffing         345.800   1.451613e+01
# 375  RI2_2_4       RI2        body sniffing         346.800  -1.527778e+01
# 376  RI2_2_4       RI2        body sniffing         350.800   9.090909e+00
# 377  RI2_2_4       RI2        body sniffing         368.800  -2.649573e+01
# 378  RI2_2_4       RI2        body sniffing         376.133   4.451220e+01
# 379  RI2_2_4       RI2      facial sniffing         513.867   2.033898e+01
# 380  RI2_2_4       RI2        body sniffing         544.933  -9.195402e+00
# 381  RI2_2_4       RI2      facial sniffing         565.067  -4.597701e+00
# 382  RI2_2_4       RI2      facial sniffing         580.933  -6.557377e+00
# 383  RI2_2_4       RI2        body sniffing         601.333   2.108434e+01
# 384  RI2_3_5       RI2      facial sniffing           4.067   2.034884e+01
# 385  RI2_3_5       RI2        body sniffing           4.467  -1.075269e+01
# 386  RI2_3_5       RI2      facial sniffing          12.033  -1.549296e+01
# 387  RI2_3_5       RI2      facial sniffing          32.900   1.639344e+01
# 388  RI2_3_5       RI2      facial sniffing          55.800   1.022727e+01
# 389  RI2_3_5       RI2        body sniffing          80.733   5.479452e+00
# 390  RI2_3_5       RI2        body sniffing         170.900  -5.952381e+00
# 391  RI2_3_5       RI2      facial sniffing         203.600  -2.478632e+01
# 392  RI2_3_5       RI2      facial sniffing         207.433   4.687500e+00
#
#                  Condition Label
# 0    Positive Social Interaction
# 1    Positive Social Interaction
# 2    Positive Social Interaction
# 3    Positive Social Interaction
# 4    Positive Social Interaction
# 5    Positive Social Interaction
# 6    Positive Social Interaction
# 7    Positive Social Interaction
# 8    Positive Social Interaction
# 9    Positive Social Interaction
# 10   Positive Social Interaction
# 11   Positive Social Interaction
# 12   Positive Social Interaction
# 13   Positive Social Interaction
# 14   Positive Social Interaction
# 15   Positive Social Interaction
# 16   Positive Social Interaction
# 17   Positive Social Interaction
# 18   Positive Social Interaction
# 19   Positive Social Interaction
# 20   Positive Social Interaction
# 21   Positive Social Interaction
# 22   Positive Social Interaction
# 23   Positive Social Interaction
# 24   Positive Social Interaction
# 25   Positive Social Interaction
# 26   Positive Social Interaction
# 27   Positive Social Interaction
# 28   Positive Social Interaction
# 29   Positive Social Interaction
# 30   Positive Social Interaction
# 31   Positive Social Interaction
# 32   Positive Social Interaction
# 33   Positive Social Interaction
# 34   Positive Social Interaction
# 35   Positive Social Interaction
# 36   Positive Social Interaction
# 37   Positive Social Interaction
# 38   Positive Social Interaction
# 39   Positive Social Interaction
# 40   Positive Social Interaction
# 41   Positive Social Interaction
# 42   Positive Social Interaction
# 43   Positive Social Interaction
# 44   Positive Social Interaction
# 45   Positive Social Interaction
# 46   Positive Social Interaction
# 47   Positive Social Interaction
# 48   Positive Social Interaction
# 49   Positive Social Interaction
# 50   Positive Social Interaction
# 51   Positive Social Interaction
# 52   Positive Social Interaction
# 53   Positive Social Interaction
# 54   Positive Social Interaction
# 55   Positive Social Interaction
# 56   Positive Social Interaction
# 57   Positive Social Interaction
# 58   Positive Social Interaction
# 59   Positive Social Interaction
# 60   Negative Social Interaction
# 61   Negative Social Interaction
# 62   Negative Social Interaction
# 63   Negative Social Interaction
# 64   Negative Social Interaction
# 65   Negative Social Interaction
# 66   Negative Social Interaction
# 67   Negative Social Interaction
# 68   Negative Social Interaction
# 69   Negative Social Interaction
# 70   Negative Social Interaction
# 71   Negative Social Interaction
# 72   Negative Social Interaction
# 73   Negative Social Interaction
# 74   Negative Social Interaction
# 75   Negative Social Interaction
# 76   Negative Social Interaction
# 77   Negative Social Interaction
# 78   Negative Social Interaction
# 79   Negative Social Interaction
# 80   Negative Social Interaction
# 81   Negative Social Interaction
# 82   Negative Social Interaction
# 83   Negative Social Interaction
# 84   Negative Social Interaction
# 85   Negative Social Interaction
# 86   Negative Social Interaction
# 87   Negative Social Interaction
# 88   Negative Social Interaction
# 89   Negative Social Interaction
# 90   Negative Social Interaction
# 91   Negative Social Interaction
# 92   Negative Social Interaction
# 93   Negative Social Interaction
# 94   Negative Social Interaction
# 95   Negative Social Interaction
# 96   Negative Social Interaction
# 97   Negative Social Interaction
# 98   Negative Social Interaction
# 99   Negative Social Interaction
# 100  Negative Social Interaction
# 101  Negative Social Interaction
# 102  Negative Social Interaction
# 103  Negative Social Interaction
# 104  Negative Social Interaction
# 105  Negative Social Interaction
# 106  Negative Social Interaction
# 107  Negative Social Interaction
# 108  Negative Social Interaction
# 109  Negative Social Interaction
# 110  Negative Social Interaction
# 111  Negative Social Interaction
# 112  Negative Social Interaction
# 113  Negative Social Interaction
# 114  Negative Social Interaction
# 115  Negative Social Interaction
# 116  Negative Social Interaction
# 117  Negative Social Interaction
# 118  Negative Social Interaction
# 119  Negative Social Interaction
# 120  Negative Social Interaction
# 121  Negative Social Interaction
# 122  Negative Social Interaction
# 123  Negative Social Interaction
# 124  Negative Social Interaction
# 125  Negative Social Interaction
# 126  Negative Social Interaction
# 127  Negative Social Interaction
# 128  Negative Social Interaction
# 129  Negative Social Interaction
# 130  Negative Social Interaction
# 131  Negative Social Interaction
# 132  Negative Social Interaction
# 133  Negative Social Interaction
# 134  Negative Social Interaction
# 135  Negative Social Interaction
# 136  Negative Social Interaction
# 137  Negative Social Interaction
# 138  Negative Social Interaction
# 139  Negative Social Interaction
# 140  Negative Social Interaction
# 141  Negative Social Interaction
# 142  Negative Social Interaction
# 143  Negative Social Interaction
# 144  Negative Social Interaction
# 145  Negative Social Interaction
# 146  Negative Social Interaction
# 147  Negative Social Interaction
# 148  Negative Social Interaction
# 149  Negative Social Interaction
# 150  Negative Social Interaction
# 151  Negative Social Interaction
# 152  Negative Social Interaction
# 153  Negative Social Interaction
# 154  Negative Social Interaction
# 155  Negative Social Interaction
# 156  Negative Social Interaction
# 157  Negative Social Interaction
# 158  Negative Social Interaction
# 159  Negative Social Interaction
# 160  Negative Social Interaction
# 161  Negative Social Interaction
# 162  Negative Social Interaction
# 163  Negative Social Interaction
# 164  Negative Social Interaction
# 165  Negative Social Interaction
# 166  Negative Social Interaction
# 167  Negative Social Interaction
# 168  Negative Social Interaction
# 169  Negative Social Interaction
# 170  Negative Social Interaction
# 171  Negative Social Interaction
# 172  Negative Social Interaction
# 173  Negative Social Interaction
# 174  Negative Social Interaction
# 175  Negative Social Interaction
# 176  Negative Social Interaction
# 177  Negative Social Interaction
# 178  Negative Social Interaction
# 179  Negative Social Interaction
# 180  Negative Social Interaction
# 181  Negative Social Interaction
# 182  Negative Social Interaction
# 183  Negative Social Interaction
# 184  Negative Social Interaction
# 185  Negative Social Interaction
# 186  Negative Social Interaction
# 187  Negative Social Interaction
# 188  Negative Social Interaction
# 189  Negative Social Interaction
# 190  Negative Social Interaction
# 191  Negative Social Interaction
# 192  Negative Social Interaction
# 193  Negative Social Interaction
# 194  Negative Social Interaction
# 195  Negative Social Interaction
# 196  Negative Social Interaction
# 197  Negative Social Interaction
# 198  Negative Social Interaction
# 199  Negative Social Interaction
# 200  Negative Social Interaction
# 201  Negative Social Interaction
# 202  Negative Social Interaction
# 203  Negative Social Interaction
# 204  Negative Social Interaction
# 205  Negative Social Interaction
# 206  Negative Social Interaction
# 207  Negative Social Interaction
# 208  Negative Social Interaction
# 209  Negative Social Interaction
# 210  Negative Social Interaction
# 211  Negative Social Interaction
# 212  Negative Social Interaction
# 213  Negative Social Interaction
# 214  Negative Social Interaction
# 215  Negative Social Interaction
# 216  Negative Social Interaction
# 217  Negative Social Interaction
# 218  Negative Social Interaction
# 219  Negative Social Interaction
# 220  Negative Social Interaction
# 221  Negative Social Interaction
# 222  Negative Social Interaction
# 223  Negative Social Interaction
# 224  Negative Social Interaction
# 225  Negative Social Interaction
# 226  Negative Social Interaction
# 227  Negative Social Interaction
# 228  Negative Social Interaction
# 229  Negative Social Interaction
# 230  Negative Social Interaction
# 231  Negative Social Interaction
# 232  Negative Social Interaction
# 233  Negative Social Interaction
# 234  Negative Social Interaction
# 235  Negative Social Interaction
# 236  Negative Social Interaction
# 237  Negative Social Interaction
# 238  Negative Social Interaction
# 239  Negative Social Interaction
# 240  Negative Social Interaction
# 241  Negative Social Interaction
# 242  Negative Social Interaction
# 243  Negative Social Interaction
# 244  Negative Social Interaction
# 245  Negative Social Interaction
# 246  Negative Social Interaction
# 247  Negative Social Interaction
# 248  Negative Social Interaction
# 249  Negative Social Interaction
# 250  Negative Social Interaction
# 251  Negative Social Interaction
# 252  Negative Social Interaction
# 253  Negative Social Interaction
# 254  Negative Social Interaction
# 255  Negative Social Interaction
# 256  Negative Social Interaction
# 257  Negative Social Interaction
# 258  Negative Social Interaction
# 259  Negative Social Interaction
# 260  Negative Social Interaction
# 261  Negative Social Interaction
# 262  Negative Social Interaction
# 263  Negative Social Interaction
# 264  Negative Social Interaction
# 265  Negative Social Interaction
# 266  Negative Social Interaction
# 267  Negative Social Interaction
# 268  Negative Social Interaction
# 269  Negative Social Interaction
# 270  Negative Social Interaction
# 271  Negative Social Interaction
# 272  Negative Social Interaction
# 273  Negative Social Interaction
# 274  Negative Social Interaction
# 275  Negative Social Interaction
# 276  Negative Social Interaction
# 277  Negative Social Interaction
# 278  Negative Social Interaction
# 279  Negative Social Interaction
# 280  Negative Social Interaction
# 281  Negative Social Interaction
# 282  Negative Social Interaction
# 283  Negative Social Interaction
# 284  Negative Social Interaction
# 285  Negative Social Interaction
# 286  Negative Social Interaction
# 287  Negative Social Interaction
# 288  Negative Social Interaction
# 289  Negative Social Interaction
# 290  Negative Social Interaction
# 291  Negative Social Interaction
# 292  Negative Social Interaction
# 293  Negative Social Interaction
# 294  Negative Social Interaction
# 295  Negative Social Interaction
# 296  Negative Social Interaction
# 297  Negative Social Interaction
# 298  Negative Social Interaction
# 299  Negative Social Interaction
# 300  Negative Social Interaction
# 301  Negative Social Interaction
# 302  Negative Social Interaction
# 303  Negative Social Interaction
# 304  Negative Social Interaction
# 305  Negative Social Interaction
# 306  Negative Social Interaction
# 307  Negative Social Interaction
# 308  Negative Social Interaction
# 309  Negative Social Interaction
# 310  Negative Social Interaction
# 311  Negative Social Interaction
# 312  Negative Social Interaction
# 313  Negative Social Interaction
# 314  Negative Social Interaction
# 315  Negative Social Interaction
# 316  Negative Social Interaction
# 317  Negative Social Interaction
# 318  Negative Social Interaction
# 319  Negative Social Interaction
# 320  Negative Social Interaction
# 321  Negative Social Interaction
# 322  Negative Social Interaction
# 323  Negative Social Interaction
# 324  Negative Social Interaction
# 325  Negative Social Interaction
# 326  Negative Social Interaction
# 327  Negative Social Interaction
# 328  Negative Social Interaction
# 329  Negative Social Interaction
# 330  Negative Social Interaction
# 331  Negative Social Interaction
# 332  Negative Social Interaction
# 333  Negative Social Interaction
# 334  Negative Social Interaction
# 335  Negative Social Interaction
# 336  Negative Social Interaction
# 337  Negative Social Interaction
# 338  Negative Social Interaction
# 339  Negative Social Interaction
# 340  Negative Social Interaction
# 341  Negative Social Interaction
# 342  Negative Social Interaction
# 343  Negative Social Interaction
# 344  Negative Social Interaction
# 345  Negative Social Interaction
# 346  Negative Social Interaction
# 347  Negative Social Interaction
# 348  Negative Social Interaction
# 349  Negative Social Interaction
# 350  Negative Social Interaction
# 351  Negative Social Interaction
# 352  Negative Social Interaction
# 353  Negative Social Interaction
# 354  Negative Social Interaction
# 355  Negative Social Interaction
# 356  Negative Social Interaction
# 357  Negative Social Interaction
# 358  Negative Social Interaction
# 359  Negative Social Interaction
# 360  Negative Social Interaction
# 361  Negative Social Interaction
# 362  Negative Social Interaction
# 363  Negative Social Interaction
# 364  Negative Social Interaction
# 365  Negative Social Interaction
# 366  Negative Social Interaction
# 367  Negative Social Interaction
# 368  Negative Social Interaction
# 369  Negative Social Interaction
# 370  Negative Social Interaction
# 371  Negative Social Interaction
# 372  Negative Social Interaction
# 373  Negative Social Interaction
# 374  Negative Social Interaction
# 375  Negative Social Interaction
# 376  Negative Social Interaction
# 377  Negative Social Interaction
# 378  Negative Social Interaction
# 379  Negative Social Interaction
# 380  Negative Social Interaction
# 381  Negative Social Interaction
# 382  Negative Social Interaction
# 383  Negative Social Interaction
# 384  Negative Social Interaction
# 385  Negative Social Interaction
# 386  Negative Social Interaction
# 387  Negative Social Interaction
# 388  Negative Social Interaction
# 389  Negative Social Interaction
# 390  Negative Social Interaction
# 391  Negative Social Interaction
# 392  Negative Social Interaction

# %%
combined_df['Subject'] = combined_df['Trial'].apply(lambda x: '_'.join(x.split('_')[1:]))

# %%
unique_mice = combined_df['Subject'].unique()
print(unique_mice)

# To look at data for one subject:
mouse_id = unique_mice[0]
mouse_data = combined_df[combined_df['Subject'] == mouse_id]
print(mouse_data)
# Out:
# ['3_6' '4_7' '2_3' '4_8' '1_1' '1_2' '2_4' '3_5']
#       Trial Condition             Behavior  Sniff Time (s)  % Change Rate  \
# 0   RI1_3_6       RI1  anogenital sniffing           8.862  -1.578947e+01
# 1   RI1_3_6       RI1      facial sniffing          12.069   0.000000e+00
# 2   RI1_3_6       RI1  anogenital sniffing          80.310  -8.474576e+00
# 3   RI1_3_6       RI1      facial sniffing          86.207   1.388889e+00
# 4   RI1_3_6       RI1      facial sniffing          88.034  -1.666667e+01
# 5   RI1_3_6       RI1  anogenital sniffing          90.690  -2.156863e+01
# 6   RI1_3_6       RI1      facial sniffing         107.724  -3.059361e+01
# 7   RI1_3_6       RI1      facial sniffing         183.724  -1.250000e+01
# 8   RI1_3_6       RI1      facial sniffing         200.517   4.805195e+01
# 9   RI1_3_6       RI1      facial sniffing         217.172   1.733333e+01
# 10  RI1_3_6       RI1      facial sniffing         229.897   2.800000e+01
# 11  RI1_3_6       RI1      facial sniffing         243.793   5.172414e+00
# 12  RI1_3_6       RI1  anogenital sniffing         260.862   5.205479e+01
# 13  RI1_3_6       RI1      facial sniffing         337.172  -2.207792e+01
# 14  RI1_3_6       RI1      facial sniffing         367.345  -5.813953e+00
# 15  RI1_3_6       RI1      facial sniffing         368.483   3.986486e+01
# 16  RI1_3_6       RI1        body sniffing         404.310   6.250000e+00
# 17  RI1_3_6       RI1      facial sniffing         416.414  -3.466667e+01
# 18  RI1_3_6       RI1        body sniffing         596.931   1.481481e+01
# 19  RI1_3_6       RI1  anogenital sniffing         597.517  -1.136364e+01
# 20  RI1_3_6       RI1      facial sniffing         598.034  -2.872340e+01
# 60  RI2_3_6       RI2      facial sniffing          25.600  -1.182432e+01
# 61  RI2_3_6       RI2        body sniffing          26.167  -7.602339e+00
# 62  RI2_3_6       RI2  anogenital sniffing          26.600   6.578947e+00
# 63  RI2_3_6       RI2      facial sniffing          68.767  -4.000000e+00
# 64  RI2_3_6       RI2      facial sniffing          91.900   2.740741e+01
# 65  RI2_3_6       RI2      facial sniffing         153.900   3.000000e+01
# 66  RI2_3_6       RI2      facial sniffing         156.233  -2.840909e+01
# 67  RI2_3_6       RI2      facial sniffing         195.433  -2.266667e+01
# 68  RI2_3_6       RI2        body sniffing         195.767  -1.919192e+01
# 69  RI2_3_6       RI2      facial sniffing         196.167   0.000000e+00
# 70  RI2_3_6       RI2        body sniffing         198.333  -1.534392e+01
# 71  RI2_3_6       RI2      facial sniffing         218.300   1.612903e+00
# 72  RI2_3_6       RI2        body sniffing         219.433  -2.394366e+01
# 73  RI2_3_6       RI2      facial sniffing         226.433  -3.493976e+01
# 74  RI2_3_6       RI2        body sniffing         228.433   3.833333e+01
# 75  RI2_3_6       RI2  anogenital sniffing         234.167   1.712329e+01
# 76  RI2_3_6       RI2      facial sniffing         234.867   3.536585e+01
# 77  RI2_3_6       RI2  anogenital sniffing         235.567  -3.257576e+01
# 78  RI2_3_6       RI2      facial sniffing         249.733  -7.894737e+00
# 79  RI2_3_6       RI2      facial sniffing         257.833   7.042254e+00
# 80  RI2_3_6       RI2      facial sniffing         267.400  -4.225352e+00
# 81  RI2_3_6       RI2      facial sniffing         269.767  -5.632184e+01
# 82  RI2_3_6       RI2      facial sniffing         273.367  -4.716981e+01
# 83  RI2_3_6       RI2      facial sniffing         282.033  -4.230769e+01
# 84  RI2_3_6       RI2      facial sniffing         288.200  -2.125000e+01
# 85  RI2_3_6       RI2      facial sniffing         290.133   3.793103e+01
# 86  RI2_3_6       RI2      facial sniffing         318.700  -1.176471e+01
# 87  RI2_3_6       RI2      facial sniffing         343.133  -9.628964e-12
# 88  RI2_3_6       RI2  anogenital sniffing         430.167   6.764706e+01
# 89  RI2_3_6       RI2  anogenital sniffing         449.800  -1.272727e+01
# 90  RI2_3_6       RI2        body sniffing         455.067   1.007752e+01
# 91  RI2_3_6       RI2        body sniffing         502.667   2.613636e+01
# 92  RI2_3_6       RI2      facial sniffing         503.133   4.625000e+01
# 93  RI2_3_6       RI2  anogenital sniffing         524.333  -7.526882e+00
# 94  RI2_3_6       RI2      facial sniffing         537.000  -3.278689e+00
# 95  RI2_3_6       RI2      facial sniffing         548.033  -1.549296e+01
# 96  RI2_3_6       RI2        body sniffing         550.833  -2.921348e+01
# 97  RI2_3_6       RI2      facial sniffing         554.333  -5.747126e+00
# 98  RI2_3_6       RI2      facial sniffing         559.000  -1.518987e+01
# 99  RI2_3_6       RI2      facial sniffing         596.333   2.222222e+01
#
#                 Condition Label Subject
# 0   Positive Social Interaction     3_6
# 1   Positive Social Interaction     3_6
# 2   Positive Social Interaction     3_6
# 3   Positive Social Interaction     3_6
# 4   Positive Social Interaction     3_6
# 5   Positive Social Interaction     3_6
# 6   Positive Social Interaction     3_6
# 7   Positive Social Interaction     3_6
# 8   Positive Social Interaction     3_6
# 9   Positive Social Interaction     3_6
# 10  Positive Social Interaction     3_6
# 11  Positive Social Interaction     3_6
# 12  Positive Social Interaction     3_6
# 13  Positive Social Interaction     3_6
# 14  Positive Social Interaction     3_6
# 15  Positive Social Interaction     3_6
# 16  Positive Social Interaction     3_6
# 17  Positive Social Interaction     3_6
# 18  Positive Social Interaction     3_6
# 19  Positive Social Interaction     3_6
# 20  Positive Social Interaction     3_6
# 60  Negative Social Interaction     3_6
# 61  Negative Social Interaction     3_6
# 62  Negative Social Interaction     3_6
# 63  Negative Social Interaction     3_6
# 64  Negative Social Interaction     3_6
# 65  Negative Social Interaction     3_6
# 66  Negative Social Interaction     3_6
# 67  Negative Social Interaction     3_6
# 68  Negative Social Interaction     3_6
# 69  Negative Social Interaction     3_6
# 70  Negative Social Interaction     3_6
# 71  Negative Social Interaction     3_6
# 72  Negative Social Interaction     3_6
# 73  Negative Social Interaction     3_6
# 74  Negative Social Interaction     3_6
# 75  Negative Social Interaction     3_6
# 76  Negative Social Interaction     3_6
# 77  Negative Social Interaction     3_6
# 78  Negative Social Interaction     3_6
# 79  Negative Social Interaction     3_6
# 80  Negative Social Interaction     3_6
# 81  Negative Social Interaction     3_6
# 82  Negative Social Interaction     3_6
# 83  Negative Social Interaction     3_6
# 84  Negative Social Interaction     3_6
# 85  Negative Social Interaction     3_6
# 86  Negative Social Interaction     3_6
# 87  Negative Social Interaction     3_6
# 88  Negative Social Interaction     3_6
# 89  Negative Social Interaction     3_6
# 90  Negative Social Interaction     3_6
# 91  Negative Social Interaction     3_6
# 92  Negative Social Interaction     3_6
# 93  Negative Social Interaction     3_6
# 94  Negative Social Interaction     3_6
# 95  Negative Social Interaction     3_6
# 96  Negative Social Interaction     3_6
# 97  Negative Social Interaction     3_6
# 98  Negative Social Interaction     3_6
# 99  Negative Social Interaction     3_6

# %%
def extract_subject(trial_name):
    parts = trial_name.split('_')
    if len(parts) >= 3:
        # Combine the 2nd and 3rd parts with underscore, e.g. "3_6"
        return f"{parts[1]}_{parts[2]}"
    else:
        return None

combined_df['Subject'] = combined_df['Trial'].apply(extract_subject)
print(combined_df[['Trial', 'Subject']].drop_duplicates())
# Out:
#        Trial Subject
# 0    RI1_3_6     3_6
# 21   RI1_4_7     4_7
# 28   RI1_2_3     2_3
# 34   RI1_4_8     4_8
# 60   RI2_3_6     3_6
# 100  RI2_4_7     4_7
# 157  RI2_2_3     2_3
# 200  RI2_4_8     4_8
# 269  RI2_1_1     1_1
# 287  RI2_1_2     1_2
# 334  RI2_2_4     2_4
# 384  RI2_3_5     3_5

# %%
combined_df = combined_df.sort_values(['Subject', 'Condition'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for mouse in unique_mice:
    mouse_data = combined_df[combined_df['Subject'] == mouse]
    plt.figure(figsize=(10, 5))
    sns.lineplot(data=mouse_data, x='Behavior', y='% Change Rate', hue='Condition', marker='o')
    plt.title(f'Respiration Rate Change for Subject {mouse}')
    plt.xticks(rotation=45)
    plt.show()

# %%
print(combined_df['Trial'].unique())
# Out:
# ['RI2_1_1' 'RI2_1_2' 'RI1_2_3' 'RI2_2_3' 'RI2_2_4' 'RI2_3_5' 'RI1_3_6'
#  'RI2_3_6' 'RI1_4_7' 'RI2_4_7' 'RI1_4_8' 'RI2_4_8']
