# %%
import os
import sys
import pandas as pd
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt

sys.path.append(r"C:\Users\thoma\Code\ResearchCode\respiratory_pilot\ephys_analysis")

from behavior.boris_extraction import get_behavior_bouts
import spike.spike_analysis.spike_collection as sc
import spike.spike_analysis.spike_recording as sr
import spike.spike_analysis.firing_rate_calculations as fr
import spike.spike_analysis.normalization as norm

# %%
boris_path = r"C:\Users\thoma\UFL Dropbox\Thomas Heeps\Padilla-Coreano Lab\2024\Cum_SocialMemEphys_pilot2\Rehouse (phase 6)\aggregated csvs\44_rehouse_d7_OM.csv"
phy_path = r"C:\Users\thoma\UFL Dropbox\Thomas Heeps\Padilla-Coreano Lab\2024\Cum_SocialMemEphys_pilot2\Rehouse (phase 6)\sorted\44_rehouse_d7_merged.rec"

# %% [markdown]
# ### Facial Sniffing Bouts

# %%
# Load BORIS CSV (change the path to your actual file)
df = pd.read_csv(boris_path)
fac_bouts = get_behavior_bouts(df, subject=['subject'], behavior = ['facial sniffing'], min_iti=1, min_bout = 0.5)
# Drop rows with missing start/stop if necessary
#df = df.dropna(subset=['Start (s)', 'Stop (s)'])

# # Initialize dictionary
# behavior_dict = defaultdict(list)

# # Loop through rows
# for _, row in df.iterrows():
#     behavior = row['Behavior']
#     start = float(row['Start (s)'])
#     stop = float(row['Stop (s)'])
#     duration = float(row['Duration (s)']) if pd.notna(row['Duration (s)']) else 0
#     behavior_dict[behavior].append((start, stop, duration))

# # Example: access all sniffing object entries
# print("facial sniffing :", behavior_dict['facial sniffing'])

df
# Out:
#                     Observation id     Observation date  Description  \
# 0   44_rehouse_d7_OM_merged(3).rec  2025-03-24 16:55:43          NaN
# 1   44_rehouse_d7_OM_merged(3).rec  2025-03-24 16:55:43          NaN
# 2   44_rehouse_d7_OM_merged(3).rec  2025-03-24 16:55:43          NaN
# 3   44_rehouse_d7_OM_merged(3).rec  2025-03-24 16:55:43          NaN
# 4   44_rehouse_d7_OM_merged(3).rec  2025-03-24 16:55:43          NaN
# ..                             ...                  ...          ...
# 89  44_rehouse_d7_OM_merged(3).rec  2025-03-24 16:55:43          NaN
# 90  44_rehouse_d7_OM_merged(3).rec  2025-03-24 16:55:43          NaN
# 91  44_rehouse_d7_OM_merged(3).rec  2025-03-24 16:55:43          NaN
# 92  44_rehouse_d7_OM_merged(3).rec  2025-03-24 16:55:43          NaN
# 93  44_rehouse_d7_OM_merged(3).rec  2025-03-24 16:55:43          NaN
#
#                                            Media file  Total length   FPS  \
# ...

# %%
bouts
# Out:
# array([[1230.267, 1259.533],
#        [1260.533, 1266.067],
#        [1273.467, 1276.733],
#        [1284.133, 1285.4  ],
#        [1290.067, 1291.067],
#        [1309.867, 1321.6  ],
#        [1325.6  , 1331.867],
#        [1332.933, 1343.6  ],
#        [1350.8  , 1352.267],
#        [1391.133, 1393.   ],
#        [1413.533, 1416.933],
#        [1422.6  , 1426.867],
#        [1605.333, 1608.133],
#        [1618.733, 1619.6  ],
#        [1645.933, 1649.267]])

# %% [markdown]
# ### Creating Spike Recording and Looking at different attributes/methods

# %%
sampling_rate = 20000

#This line initiates a spike recording object
subj_44 = sr.SpikeRecording(path = phy_path, sampling_rate = sampling_rate)

# %%
print(subj_44)
# Out:
# SpikeRecording Summary:
#   Recording: 44_rehouse_d7_merged.rec
#   Subject: None
#   Event Dict Assigned: False
#   Recording Length: 30.01 minutes
#
# Unit Overvew:
#   Number of Good Units: 7
#   Number of MUAs: 22

# %%
subj_44.analyze(timebin=100, ignore_freq=0.5, smoothing_window=None)
print(subj_44)
# Out:
# Cannot execute:44_rehouse_d7_merged.rec is missing the following attributes:
# ['subject', 'event_dict']
# SpikeRecording Summary:
#   Recording: 44_rehouse_d7_merged.rec
#   Subject: None
#   Event Dict Assigned: False
#   Recording Length: 30.01 minutes
#
# Unit Overvew:
#   Number of Good Units: 7
#   Number of MUAs: 22
#   Good units above ignore frequency: 7
#
# Analysis Parameters:
#   Timebin: 100s
#   Ignore Frequency: 0.5Hz
#   Smoothing Window: None

# %%
fire_rates = subj_44.unit_firing_rate_array
avg_fire_rate = np.nanmean(fire_rates, axis=1)
time_axis = np.arange(len(avg_fire_rate)) * subj_44.timebin

print(subj_44.timebin)
# Out:
# 100

# %% [markdown]
# ### Creating Behavior Dict

# %% [markdown]
# ### Setting Event Dict from bouts to spike recording object

# %%
print(type(bouts))
print(bouts.shape)

#in order for the event_dict to be ready to be assigned, it needs to be in dictionary form
sniffing_dict = {'sniff': bouts}
# Out:
# <class 'numpy.ndarray'>
# (15, 2)

# %%
subj_44.set_subject('4.4')
subj_44.set_event_dict(sniffing_dict)

print(subj_44)
# Out:
# SpikeRecording Summary:
#   Recording: 44_rehouse_d7_merged.rec
#   Subject: 4.4
#   Event Dict Assigned: True
#   Recording Length: 30.01 minutes
#
# Unit Overvew:
#   Number of Good Units: 7
#   Number of MUAs: 22
#   Good units above ignore frequency: 7
#
# Analysis Parameters:
#   Timebin: 100s
#   Ignore Frequency: 0.5Hz
#   Smoothing Window: None
#
# Event Overview:
#   sniff: 15 events

# %% [markdown]
# ### Anogenital

# %%
ano_bouts = get_behavior_bouts(
    df,
    subject=['subject'],
    behavior=['anogenital sniffing'],  # Adjust this to the exact label in your CSV
    min_iti=1,
    min_bout=0.5
)

# %%
'''
Swapping evnet dicts for different behaviors

subj_44.set_event_dict({'sniff': fac_bouts})
subj_44.set_event_dict({'sniff': ano_bouts})

'''
# Out:
# "\nSwapping evnet dicts for different behaviors\n\nsubj_44.set_event_dict({'sniff': fac_bouts})\nsubj_44.set_event_dict({'sniff': ano_bouts})\n\n"

# %% [markdown]
# ### Analyzing difference

# %%
# firing rates during facial sniffing bouts

# %% [markdown]
# ### Creating Spike Collection Example

# %%
event_dict = {}
subject_dict = {}
j = 1
for file in os.listdir(r"spike\tests\test_data"):
    recording_name_parts = (file.split(".")[0]).split("_")[:-1]
    recording_name = "_".join(recording_name_parts) + "_merged.rec"
    if file.endswith(".csv"):
        subject =['subject']
        behavior = ['facial sniffing', 'anogenital sniffing']
        min_iti = 1 
        min_bout = 0.5
        behavior_df = pd.read_csv(r"spike\tests\test_data\\" + file)
        mouse_in = np.array(behavior_df[behavior_df['Behavior'] == 'mice back in']['Start (s)'].tolist())
        mouse_out = np.array(behavior_df[behavior_df['Behavior'] == 'mice taken out']['Start (s)'].tolist())
        rec_event_dict = {}
        for i in range(5):
            try:
                exp_df = behavior_df[
                    (behavior_df['Start (s)'] > mouse_in[i]) &
                    (behavior_df['Start (s)'] < mouse_out[i])]
            except IndexError:

                exp_df = behavior_df[
                        (behavior_df['Start (s)'] > mouse_in[i])]
            exp_array = boris.get_behavior_bouts(exp_df,subject = subject, behavior = behavior, min_iti = min_iti, min_bout=min_bout)
            rec_event_dict[f'exp{i+1}'] = exp_array
        event_dict[recording_name] = rec_event_dict
        subject = f"Subject {j}"
        subject_dict[recording_name] = subject
        j += 1
        

example_collection = sc.SpikeCollection(path = r"spike\tests\test_data", event_dict = event_dict, subject_dict = subject_dict)
example_collection.analyze(timebin = 100, ignore_freq=0.5, smoothing_window = None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[99], line 4
#       2 subject_dict = {}
#       3 j = 1
# ----> 4 for file in os.listdir(r"spike\tests\test_data"):
#       5     recording_name_parts = (file.split(".")[0]).split("_")[:-1]
#       6     recording_name = "_".join(recording_name_parts) + "_merged.rec"
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'spike\\tests\\test_data'
