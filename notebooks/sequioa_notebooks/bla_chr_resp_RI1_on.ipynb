# %%
import pandas as pd
import numpy as np
import spikeinterface.extractors as se
import spikeinterface.preprocessing as sp
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import neurokit2 as nk
import tdt
import spikeinterface.extractors as se
import neurokit2 as nk
import matplotlib.pyplot as plt
import numpy as np

# %%
import sys
import os

trodes_path = r"C:\Users\sjs93\Trodes_2-6-0_Windows11\Trodes_2-6-0_Windows11\Resources\TrodesToPython"

sys.path.append(trodes_path)

trodes_path
# Out:
# 'C:\\Users\\sjs93\\Trodes_2-6-0_Windows11\\Trodes_2-6-0_Windows11\\Resources\\TrodesToPython'

# %%
os.listdir(trodes_path)
# Out:
# ['examplePythonImport.py',
#  'readCameraModuleTimeStamps.py',
#  'readTrodesExtractedDataFile2.py',
#  'readTrodesExtractedDataFile3.py',
#  '__pycache__']

# %%
import sys
sys.path.append(
    r"C:\Users\sjs93\Trodes_2-6-0_Windows11\Trodes_2-6-0_Resources\TrodesToPython"
)

from readTrodesExtractedDataFile3 import readTrodesExtractedDataFile

# %%
dat_path = (
    r"D:\BLA_ChR_resp\BLA_ChR_resp_RI1_hc_day1"
    r"\1_1_RI1_f1_d_on_20260111_164638.analog"
    r"\1_1_RI1_f1_d_on_20260111_164638.analog_ECU_Ain1.dat"
)

# %%
fields = readTrodesExtractedDataFile(dat_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 fields = readTrodesExtractedDataFile(dat_path)
#
# File ~\Trodes_2-6-0_Windows11\Trodes_2-6-0_Windows11\Resources\TrodesToPython\readTrodesExtractedDataFile3.py:9, in readTrodesExtractedDataFile(filename)
#       8 def readTrodesExtractedDataFile(filename):
# ----> 9     with open(filename, 'rb') as f:
#      10         # Check if first line is start of settings block
#      11         if f.readline().decode('ascii').strip() != '<Start settings>':
#      12             raise Exception("Settings format not supported")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\BLA_ChR_resp\\BLA_ChR_resp_RI1_hc_day1\\1_1_RI1_f1_d_on_20260111_164638.analog\\1_1_RI1_f1_d_on_20260111_164638.analog_ECU_Ain1.dat'
