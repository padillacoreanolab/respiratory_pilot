# %% [markdown]
# libaraies

# %%
import os
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt, resample_poly
import neurokit2 as nk
from scipy.signal import find_peaks
import seaborn as sns
from scipy.stats import wilcoxon

# Pandas display settings (optional)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 0)

# %% [markdown]
# load files

# %%
# RESP FILE PATHS
RI1_3_6_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5"
RI2_3_6_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5"
BLRI_s3_6_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\BLRI_s3_6_p5_3_nRB3_20250621_123634_merged.h5"
BLRI_s4_7_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\BLRI_s4_7_p5_2_nRB3_20250621_144806_merged.h5"
RI1_4_7_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5"
RI2_4_7_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5"
RI1_2_3_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s2_3_p5_3_nRB3_20250622_104059_merged (1).h5"
RI2_2_3_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5"
RI1_4_8_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5"
RI2_4_8_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5"
RI1_1_1_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5"
RI2_1_1_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5"
RI1_1_2_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5"
RI2_1_2_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5"
RI1_2_4_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5"
RI2_2_4_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5"
RI2_3_5_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5"
RI1_3_5_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5"


# BORIS CSVs (no comma at the end or it makes a tuple)
RI1_3_6_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s3_6_p5_3_nRB3_HEEPS.csv")
RI2_3_6_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s3_6_p_5_3_nRB3_2025062.csv")
RI1_4_7_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s4_7_p5_2_nRB3_HEEPS.csv")
RI2_4_7_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s4_7_p5_2_nRB3_HEEPS.csv")
RI1_2_3_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s2_3_p5_3_nRB3_20250622_104059.1.csv")
RI2_2_3_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s2_3_p5_3_nRB3_20250622_1102116.1.csv")
RI1_4_8_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s4_8_p5_1_nRB3_HEEPS.csv")
RI2_4_8_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s4_8_p5_1_nRB3_20250621_HEEPS.csv")
RI1_1_1_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s1_1_p5_2_nRB6_20250622_143958.1.csv")
RI2_1_1_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s1_1_p5_2_nRB6_20250622_150457.1.csv")
RI1_1_2_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s1_2_p5_1_nRB6_20250622_170742.1.csv")
RI2_1_2_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s1_2_p5_1_nRB6_20250622_173049.1.csv")
RI1_2_4_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s2_4_p5_4_nRB3_20250622_123424.1.csv")
RI2_2_4_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s2_4_p5_4_nRB3_20250622_125648.1.csv")
RI2_3_5_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s3_5_p5_4_nRB3_20250621.csv")

# %%
ri1_h5_paths = {
    "RI1_3_6": RI1_3_6_h5_path,
    "RI1_4_7": RI1_4_7_h5_path,  
    "RI1_2_3": RI1_2_3_h5_path,
    "RI1_4_8": RI1_4_8_h5_path,
    "RI1_1_1": RI1_1_1_h5_path,
    "RI1_1_2": RI1_1_2_h5_path,
    "RI1_2_4": RI1_2_4_h5_path,
    "RI1_3_5": RI1_3_5_h5_path,
}

# %%
ri2_h5_paths = {
    "RI2_3_6": RI2_3_6_h5_path,
    "RI2_4_7": RI2_4_7_h5_path,
    "RI2_2_3": RI2_2_3_h5_path,
    "RI2_4_8": RI2_4_8_h5_path,
    "RI2_1_1": RI2_1_1_h5_path,
    "RI2_1_2": RI2_1_2_h5_path,
    "RI2_2_4": RI2_2_4_h5_path,
    "RI2_3_5": RI2_3_5_h5_path,
}

# %%
ri1_boris_data = {
    "RI1_3_6": RI1_3_6_boris.copy(),
    "RI1_4_7": RI1_4_7_boris.copy(),
    "RI1_2_3": RI1_2_3_boris.copy(),
    "RI1_4_8": RI1_4_8_boris.copy(),
    "RI1_1_1": RI1_1_1_boris.copy(),
    "RI1_1_2": RI1_1_2_boris.copy(),
    "RI1_2_4": RI1_2_4_boris.copy(),
}

# %%
ri2_boris_data = {
    "RI2_3_6": RI2_3_6_boris.copy(),
    "RI2_4_7": RI2_4_7_boris.copy(),
    "RI2_2_3": RI2_2_3_boris.copy(),
    "RI2_4_8": RI2_4_8_boris.copy(),
    "RI2_1_1": RI2_1_1_boris.copy(),
    "RI2_1_2": RI2_1_2_boris.copy(),
    "RI2_2_4": RI2_2_4_boris.copy(),
    "RI2_3_5": RI2_3_5_boris.copy(),
}

# %% [markdown]
# load_clean_resp_signal function for loading and preprocessing respiration data:
#
# Reads raw resp signal and metadata from .h5
#
# Computes original sampling rate (fs)
#
# Applies a low-pass filter before downsampling to avoid aliasing
#
# Downsamples the signal to your target_rate (default 100 Hz)
#
# Applies a bandpass filter (0.1–20 Hz) with NeuroKit to clean the signal further
#
# Creates a time vector that matches the cleaned signal length and sampling rate
#
# This function returns:
# rsp_cleaned: the cleaned, filtered, downsampled respiratory signal array
#
# time_vector: time points corresponding to each sample in seconds
#
# target_rate: the sampling rate after downsampling (e.g., 100 Hz)
#
# You can then pass these outputs to functions like:
# get_percent_change_resp_rate(signal=rsp_cleaned, times=time_vector, sniff_start, sniff_end)
#
# get_delta_resp_rate(signal=rsp_cleaned, times=time_vector, sniff_end)

# %%
def load_clean_resp_signal(h5_file, target_rate=100):
    """
    Loads, filters, downsamples respiration from .h5, returns cleaned signal and time vector.
    """
    try:
        with h5py.File(h5_file, 'r') as f:
            resp = f['resp'][:].flatten()
            ekg_meta = dict(f['ekg_metadata'].attrs)
        duration_sec = ekg_meta['duration_sec']
        fs = len(resp) / duration_sec
    except Exception as e:
        print(f"Error loading {h5_file}: {e}")
        return None, None, None

    # Pre-filter before downsampling
    nyquist = fs / 2
    norm_cutoff = (target_rate / 2) / nyquist
    b, a = butter(N=4, Wn=norm_cutoff, btype='low')
    filtered_resp = filtfilt(b, a, resp)

    # Downsample
    downsample_factor = int(fs // target_rate)
    downsampled = resample_poly(filtered_resp, up=1, down=downsample_factor)

    # Bandpass filter with neurokit
    rsp_cleaned = nk.signal_filter(
        downsampled,
        lowcut=0.1,
        highcut=20,
        method="butterworth",
        sampling_rate=target_rate,
        order=2
    )

    # Generate matching time vector
    time_vector = np.arange(len(rsp_cleaned)) / target_rate

    return rsp_cleaned, time_vector, target_rate

# %%
h5_paths = {
    "RI1_3_6": RI1_3_6_h5_path,
    "RI2_3_6": RI2_3_6_h5_path,
    "RI1_4_7": RI1_4_7_h5_path,
    "RI2_4_7": RI2_4_7_h5_path,
    "RI1_2_3": RI1_2_3_h5_path,
    "RI2_2_3": RI2_2_3_h5_path,
    "RI1_4_8": RI1_4_8_h5_path,
    "RI2_4_8": RI2_4_8_h5_path,
    "RI1_1_1": RI1_1_1_h5_path,
    "RI2_1_1": RI2_1_1_h5_path,
    "RI1_1_2": RI1_1_2_h5_path,
    "RI2_1_2": RI2_1_2_h5_path,
    "RI1_2_4": RI1_2_4_h5_path,
    "RI2_2_4": RI2_2_4_h5_path,
    "RI1_3_5": RI1_3_5_h5_path,
    "RI2_3_5": RI2_3_5_h5_path,
}

# %%
resp_data = {}

for label, path in h5_paths.items():
    print(f"Processing {label}...")
    signal, time, rate = load_clean_resp_signal(path)
    
    if signal is not None:
        resp_data[label] = {
            "signal": signal,
            "time": time,
            "sampling_rate": rate
        }
    else:
        print(f"Skipping {label}: failed to load.")

print("✅ All available signals loaded.")
# Out:
# Processing RI1_3_6...
# Processing RI2_3_6...
# Processing RI1_4_7...
# Processing RI2_4_7...
# Processing RI1_2_3...
# Processing RI2_2_3...
# Processing RI1_4_8...
# Processing RI2_4_8...
# Processing RI1_1_1...
# Processing RI2_1_1...
# Processing RI1_1_2...
# Processing RI2_1_2...
# Processing RI1_2_4...
# Processing RI2_2_4...
# Processing RI1_3_5...
# Processing RI2_3_5...
# ✅ All available signals loaded.

# %% [markdown]
# get_sniff_respiratory_rate function is good for calculating the breathing rate during a sniff bout:
#
# It creates a mask to select the respiratory signal samples between sniff_start and sniff_end.
#
# It uses find_peaks to detect inhalation peaks in that signal segment, with a minimum peak distance of 0.2 seconds (to avoid counting the same breath twice).
#
# It calculates the duration of the sniff bout.
#
# It returns the breathing rate as the number of detected peaks divided by the duration (giving rate in Hz).
#
# A few things to watch out for:
# Sampling rate consistency: Make sure the times array and the signal array are aligned and that sampling_rate matches the sampling frequency of the signal.
#
# Peak detection threshold: You might want to tweak the distance or add a height parameter in find_peaks if you get too many or too few peaks.
#
# Edge cases: If duration is zero or very small, it returns np.nan, which is good.

# %%
def get_sniff_respiratory_rate(signal, time, sniff_start, sniff_end, sampling_rate=100):
    """
    Compute breathing rate (Hz) during a sniff bout or whole trial ie sniff_start = trial_start and sniff_end = trial_end.
    """
    sniff_mask = (time >= sniff_start) & (time < sniff_end)
    signal_sniff = signal[sniff_mask]

    peaks, _ = find_peaks(signal_sniff, distance=sampling_rate * 0.0833)  # 0.0833 seconds corresponds to 12 Hz

    duration = sniff_end - sniff_start
    rate = len(peaks) / duration if duration > 0 else np.nan

    return rate

# %%
ri_session_rates = []

for trial, entry in resp_data.items():
    signal = entry['signal']
    time = entry['time']
    sampling_rate = entry['sampling_rate']

    # Get full duration
    sniff_start = time[0]
    sniff_end = time[-1]

    # Compute respiration rate
    rate = get_sniff_respiratory_rate(signal, time, sniff_start, sniff_end, sampling_rate=sampling_rate)

    # Get valence
    valence = 'RI1' if trial.startswith('RI1') else ('RI2' if trial.startswith('RI2') else 'Other')

    # Extract subject as 3.6 from RI1_3_6
    try:
        parts = trial.split('_')
        subject = f"{parts[1]}.{parts[2]}"
    except IndexError:
        subject = 'Unknown'

    ri_session_rates.append({
        'Trial': trial,
        'Valence': valence,
        'Subject': subject,
        'Respiration Rate (Hz)': rate
    })

# Convert to DataFrame
ri_session_df = pd.DataFrame(ri_session_rates)
print(ri_session_df.head())
# Out:
#      Trial Valence Subject  Respiration Rate (Hz)
# 0  RI1_3_6     RI1     3.6               7.270376
# 1  RI2_3_6     RI2     3.6               5.932787
# 2  RI1_4_7     RI1     4.7               7.564174
# 3  RI2_4_7     RI2     4.7               6.551133
# 4  RI1_2_3     RI1     2.3               7.285965

# %%
def extract_subject_anogenital_sniffs(df):
    """
    Filters BORIS dataframe for anogenital sniffing initiated by the subject.
    """
    df = df.copy()
    df['Start (s)'] = df['Start (s)'].astype(float)
    df['Stop (s)'] = df['Stop (s)'].astype(float)
    df = df.sort_values(by='Start (s)').reset_index(drop=True)

    # Filter for anogenital sniffing by the subject
    subject_mask = df['Subject'].str.lower() == 'subject'
    sniff_mask = df['Behavior'].str.lower() == 'anogenital sniffing'

    return df[subject_mask & sniff_mask]

# %%
# Call the function on your BORIS dataframe
subject_anogenital_sniffs = extract_subject_anogenital_sniffs(RI2_4_7_boris)

# Optional: preview the result
print(subject_anogenital_sniffs.head())
# Out:
# Empty DataFrame
# Columns: [Observation id, Observation date, Description, Observation type, Source, Time offset (s), Coding duration, Media duration (s), FPS (frame/s), Subject, Observation duration by subject by observation, Behavior, Behavioral category, Behavior type, Start (s), Stop (s), Duration (s), Media file name, Image index start, Image index stop, Image file path start, Image file path stop, Comment start, Comment stop]
# Index: []

# %% [markdown]
# ONE SUBJECT 3.6 WORKED

# %% [markdown]
# RUN LOOP ON ALL SUBJECTS WORKS

# %%
# List to collect all subject-initiated anogenital sniffs
all_subject_sniffs = []

# Loop through RI1 trials
for label, boris_df in ri1_boris_data.items():
    subject_sniffs = extract_subject_anogenital_sniffs(boris_df)
    subject_sniffs["Trial"] = label
    subject_sniffs["Group"] = "RI1"
    all_subject_sniffs.append(subject_sniffs)

# Loop through RI2 trials
for label, boris_df in ri2_boris_data.items():
    subject_sniffs = extract_subject_anogenital_sniffs(boris_df)
    subject_sniffs["Trial"] = label
    subject_sniffs["Group"] = "RI2"
    all_subject_sniffs.append(subject_sniffs)

# Combine all into one DataFrame
combined_subject_sniffs_df = pd.concat(all_subject_sniffs, ignore_index=True)

# %%
combined_sniffs_df
# Out:
#                           Observation id         Observation date  \
# 0                     RI1_s3_6_p5_3_nRB3  2025-06-28 22:13:15.619
# 1                     RI1_s3_6_p5_3_nRB3  2025-06-28 22:13:15.619
# 2                     RI1_s3_6_p5_3_nRB3  2025-06-28 22:13:15.619
# 3                     RI1_s3_6_p5_3_nRB3  2025-06-28 22:13:15.619
# 4                     RI1_s3_6_p5_3_nRB3  2025-06-28 22:13:15.619
# 5                     RI1_s4_7_p5_2_nRB3  2025-06-29 10:29:43.592
# 6   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 7                     RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 8                     RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 9                     RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 10                    RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 11                    RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 12                    RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 13  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 14  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 15  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 16  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 17  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 18  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 19                   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 20                   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 21                   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 22                   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 23                   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 24                   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 25                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 26                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 27                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 28                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 29                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 30                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 31                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 32                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 33                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 34                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 35                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 36                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 37                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 38                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 39                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 40                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 41                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 42                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 43                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 44                    RI2_s4_7_p5_2_nRB3  2025-07-01 08:59:12.130
# 45  RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 46  RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 47  RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 48  RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 49  RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 50           RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 51           RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 52           RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 53           RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 54           RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 55           RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 56           RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 57           RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 58           RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 59           RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 60           RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 61           RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 62           RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 63           RI2_s4_8_p5_1_nRB3_20250621  2025-07-03 10:46:03.458
# 64  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 65  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 66  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 67  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 68  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 69  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 70  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 71  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 72  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 73  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 74  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 75  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 76  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 77  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
#
#     Description Observation type  \
# 0           NaN       Media file
# 1           NaN       Media file
# 2           NaN       Media file
# 3           NaN       Media file
# 4           NaN       Media file
# 5           NaN       Media file
# 6           NaN              NaN
# 7           NaN       Media file
# 8           NaN       Media file
# 9           NaN       Media file
# 10          NaN       Media file
# 11          NaN       Media file
# 12          NaN       Media file
# 13          NaN              NaN
# 14          NaN              NaN
# 15          NaN              NaN
# 16          NaN              NaN
# 17          NaN              NaN
# 18          NaN              NaN
# 19          NaN       Media file
# 20          NaN       Media file
# 21          NaN       Media file
# 22          NaN       Media file
# 23          NaN       Media file
# 24          NaN       Media file
# 25          NaN       Media file
# 26          NaN       Media file
# 27          NaN       Media file
# 28          NaN       Media file
# 29          NaN       Media file
# 30          NaN       Media file
# 31          NaN       Media file
# 32          NaN       Media file
# 33          NaN       Media file
# 34          NaN       Media file
# 35          NaN       Media file
# 36          NaN       Media file
# 37          NaN       Media file
# 38          NaN       Media file
# 39          NaN       Media file
# 40          NaN       Media file
# 41          NaN       Media file
# 42          NaN       Media file
# 43          NaN       Media file
# 44          NaN       Media file
# 45          NaN              NaN
# 46          NaN              NaN
# 47          NaN              NaN
# 48          NaN              NaN
# 49          NaN              NaN
# 50          NaN       Media file
# 51          NaN       Media file
# 52          NaN       Media file
# 53          NaN       Media file
# 54          NaN       Media file
# 55          NaN       Media file
# 56          NaN       Media file
# 57          NaN       Media file
# 58          NaN       Media file
# 59          NaN       Media file
# 60          NaN       Media file
# 61          NaN       Media file
# 62          NaN       Media file
# 63          NaN       Media file
# 64          NaN              NaN
# 65          NaN              NaN
# 66          NaN              NaN
# 67          NaN              NaN
# 68          NaN              NaN
# 69          NaN              NaN
# 70          NaN              NaN
# 71          NaN              NaN
# 72          NaN              NaN
# 73          NaN              NaN
# 74          NaN              NaN
# 75          NaN              NaN
# 76          NaN              NaN
# 77          NaN              NaN
#
#                                                                                                                Source  \
# 0                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s3_6_p5_3_nRB3_20250621_125312.1.mp4
# 1                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s3_6_p5_3_nRB3_20250621_125312.1.mp4
# 2                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s3_6_p5_3_nRB3_20250621_125312.1.mp4
# 3                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s3_6_p5_3_nRB3_20250621_125312.1.mp4
# 4                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s3_6_p5_3_nRB3_20250621_125312.1.mp4
# 5                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_7_p5_2_nRB3_20250621_150707.1.mp4
# 6                                                                                                                 NaN
# 7                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 8                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 9                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 10                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 11                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 12                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 13                                                                                                                NaN
# 14                                                                                                                NaN
# 15                                                                                                                NaN
# 16                                                                                                                NaN
# 17                                                                                                                NaN
# 18                                                                                                                NaN
# 19  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 20  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 21  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 22  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 23  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 24  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 25                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 26                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 27                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 28                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 29                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 30                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 31                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 32                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 33                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 34                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 35                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 36                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 37                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 38                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 39                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 40                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 41                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 42                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 43                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 44                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 45                                                                                                                NaN
# 46                                                                                                                NaN
# 47                                                                                                                NaN
# 48                                                                                                                NaN
# 49                                                                                                                NaN
# 50                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 51                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 52                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 53                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 54                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 55                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 56                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 57                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 58                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 59                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 60                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 61                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 62                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 63                     player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 64                                                                                                                NaN
# 65                                                                                                                NaN
# 66                                                                                                                NaN
# 67                                                                                                                NaN
# 68                                                                                                                NaN
# 69                                                                                                                NaN
# 70                                                                                                                NaN
# 71                                                                                                                NaN
# 72                                                                                                                NaN
# 73                                                                                                                NaN
# 74                                                                                                                NaN
# 75                                                                                                                NaN
# 76                                                                                                                NaN
# 77                                                                                                                NaN
#
#     Time offset (s)  Coding duration  Media duration (s)  FPS (frame/s)  \
# 0               0.0          589.517             622.862           29.0
# 1               0.0          589.517             622.862           29.0
# 2               0.0          589.517             622.862           29.0
# 3               0.0          589.517             622.862           29.0
# 4               0.0          589.517             622.862           29.0
# 5               0.0          505.966             627.800           30.0
# 6               NaN              NaN                 NaN            NaN
# 7               0.0          526.234             603.200           30.0
# 8               0.0          526.234             603.200           30.0
# 9               0.0          526.234             603.200           30.0
# 10              0.0          526.234             603.200           30.0
# 11              0.0          526.234             603.200           30.0
# 12              0.0          526.234             603.200           30.0
# 13              NaN              NaN                 NaN            NaN
# 14              NaN              NaN                 NaN            NaN
# 15              NaN              NaN                 NaN            NaN
# 16              NaN              NaN                 NaN            NaN
# 17              NaN              NaN                 NaN            NaN
# 18              NaN              NaN                 NaN            NaN
# 19              0.0          603.900             608.733           30.0
# 20              0.0          603.900             608.733           30.0
# 21              0.0          603.900             608.733           30.0
# 22              0.0          603.900             608.733           30.0
# 23              0.0          603.900             608.733           30.0
# 24              0.0          603.900             608.733           30.0
# 25              0.0          598.466             605.233           30.0
# 26              0.0          598.466             605.233           30.0
# 27              0.0          598.466             605.233           30.0
# 28              0.0          598.466             605.233           30.0
# 29              0.0          598.466             605.233           30.0
# 30              0.0          598.466             605.233           30.0
# 31              0.0          598.466             605.233           30.0
# 32              0.0          598.466             605.233           30.0
# 33              0.0          598.466             605.233           30.0
# 34              0.0          598.466             605.233           30.0
# 35              0.0          598.466             605.233           30.0
# 36              0.0          598.466             605.233           30.0
# 37              0.0          598.466             605.233           30.0
# 38              0.0          598.466             605.233           30.0
# 39              0.0          598.466             605.233           30.0
# 40              0.0          598.466             605.233           30.0
# 41              0.0          598.466             605.233           30.0
# 42              0.0          598.466             605.233           30.0
# 43              0.0          598.466             605.233           30.0
# 44              0.0          598.466             605.233           30.0
# 45              NaN              NaN                 NaN            NaN
# 46              NaN              NaN                 NaN            NaN
# 47              NaN              NaN                 NaN            NaN
# 48              NaN              NaN                 NaN            NaN
# 49              NaN              NaN                 NaN            NaN
# 50              0.0          588.934             602.133           30.0
# 51              0.0          588.934             602.133           30.0
# 52              0.0          588.934             602.133           30.0
# 53              0.0          588.934             602.133           30.0
# 54              0.0          588.934             602.133           30.0
# 55              0.0          588.934             602.133           30.0
# 56              0.0          588.934             602.133           30.0
# 57              0.0          588.934             602.133           30.0
# 58              0.0          588.934             602.133           30.0
# 59              0.0          588.934             602.133           30.0
# 60              0.0          588.934             602.133           30.0
# 61              0.0          588.934             602.133           30.0
# 62              0.0          588.934             602.133           30.0
# 63              0.0          588.934             602.133           30.0
# 64              NaN              NaN                 NaN            NaN
# 65              NaN              NaN                 NaN            NaN
# 66              NaN              NaN                 NaN            NaN
# 67              NaN              NaN                 NaN            NaN
# 68              NaN              NaN                 NaN            NaN
# 69              NaN              NaN                 NaN            NaN
# 70              NaN              NaN                 NaN            NaN
# 71              NaN              NaN                 NaN            NaN
# 72              NaN              NaN                 NaN            NaN
# 73              NaN              NaN                 NaN            NaN
# 74              NaN              NaN                 NaN            NaN
# 75              NaN              NaN                 NaN            NaN
# 76              NaN              NaN                 NaN            NaN
# 77              NaN              NaN                 NaN            NaN
#
#          Subject  Observation duration by subject by observation  \
# 0   social_agent                                          23.313
# 1   social_agent                                          23.313
# 2   social_agent                                          23.313
# 3   social_agent                                          23.313
# 4   social_agent                                          23.313
# 5   social_agent                                           3.399
# 6   social_agent                                             NaN
# 7   social_agent                                          26.430
# 8   social_agent                                          26.430
# 9   social_agent                                          26.430
# 10  social_agent                                          26.430
# 11  social_agent                                          26.430
# 12  social_agent                                          26.430
# 13  social_agent                                             NaN
# 14  social_agent                                             NaN
# 15  social_agent                                             NaN
# 16  social_agent                                             NaN
# 17  social_agent                                             NaN
# 18  social_agent                                             NaN
# 19  social_agent                                         146.335
# 20  social_agent                                         146.335
# 21  social_agent                                         146.335
# 22  social_agent                                         146.335
# 23  social_agent                                         146.335
# 24  social_agent                                         146.335
# 25  social_agent                                         158.001
# 26  social_agent                                         158.001
# 27  social_agent                                         158.001
# 28  social_agent                                         158.001
# 29  social_agent                                         158.001
# 30  social_agent                                         158.001
# 31  social_agent                                         158.001
# 32  social_agent                                         158.001
# 33  social_agent                                         158.001
# 34  social_agent                                         158.001
# 35  social_agent                                         158.001
# 36  social_agent                                         158.001
# 37  social_agent                                         158.001
# 38  social_agent                                         158.001
# 39  social_agent                                         158.001
# 40  social_agent                                         158.001
# 41  social_agent                                         158.001
# 42  social_agent                                         158.001
# 43  social_agent                                         158.001
# 44  social_agent                                         158.001
# 45  social_agent                                             NaN
# 46  social_agent                                             NaN
# 47  social_agent                                             NaN
# 48  social_agent                                             NaN
# 49  social_agent                                             NaN
# 50  social_agent                                         202.519
# 51  social_agent                                         202.519
# 52  social_agent                                         202.519
# 53  social_agent                                         202.519
# 54  social_agent                                         202.519
# 55  social_agent                                         202.519
# 56  social_agent                                         202.519
# 57  social_agent                                         202.519
# 58  social_agent                                         202.519
# 59  social_agent                                         202.519
# 60  social_agent                                         202.519
# 61  social_agent                                         202.519
# 62  social_agent                                         202.519
# 63  social_agent                                         202.519
# 64  social_agent                                             NaN
# 65  social_agent                                             NaN
# 66  social_agent                                             NaN
# 67  social_agent                                             NaN
# 68  social_agent                                             NaN
# 69  social_agent                                             NaN
# 70  social_agent                                             NaN
# 71  social_agent                                             NaN
# 72  social_agent                                             NaN
# 73  social_agent                                             NaN
# 74  social_agent                                             NaN
# 75  social_agent                                             NaN
# 76  social_agent                                             NaN
# 77  social_agent                                             NaN
#
#                Behavior Behavioral category Behavior type  Start (s)  \
# 0   anogenital sniffing         Not defined         STATE      8.862
# 1   anogenital sniffing         Not defined         STATE     80.310
# 2   anogenital sniffing         Not defined         STATE     90.690
# 3   anogenital sniffing         Not defined         STATE    260.862
# 4   anogenital sniffing         Not defined         STATE    597.517
# 5   anogenital sniffing         Not defined         STATE    346.067
# 6   anogenital sniffing                 NaN         STATE     85.222
# 7   anogenital sniffing         Not defined         STATE     18.700
# 8   anogenital sniffing         Not defined         STATE     35.600
# 9   anogenital sniffing         Not defined         STATE     44.800
# 10  anogenital sniffing         Not defined         STATE    176.133
# 11  anogenital sniffing         Not defined         STATE    185.467
# 12  anogenital sniffing         Not defined         STATE    203.733
# 13  anogenital sniffing                 NaN         STATE     85.902
# 14  anogenital sniffing                 NaN         STATE     92.153
# 15  anogenital sniffing                 NaN         STATE    228.906
# 16  anogenital sniffing                 NaN         STATE     81.000
# 17  anogenital sniffing                 NaN         STATE    177.200
# 18  anogenital sniffing                 NaN         STATE    514.667
# 19  anogenital sniffing         Not defined         STATE     26.600
# 20  anogenital sniffing         Not defined         STATE    234.167
# 21  anogenital sniffing         Not defined         STATE    235.567
# 22  anogenital sniffing         Not defined         STATE    430.167
# 23  anogenital sniffing         Not defined         STATE    449.800
# 24  anogenital sniffing         Not defined         STATE    524.333
# 25  anogenital sniffing         Not defined         STATE     31.767
# 26  anogenital sniffing         Not defined         STATE     36.600
# 27  anogenital sniffing         Not defined         STATE     69.900
# 28  anogenital sniffing         Not defined         STATE     73.600
# 29  anogenital sniffing         Not defined         STATE     77.133
# 30  anogenital sniffing         Not defined         STATE    100.467
# 31  anogenital sniffing         Not defined         STATE    168.900
# 32  anogenital sniffing         Not defined         STATE    171.967
# 33  anogenital sniffing         Not defined         STATE    190.433
# 34  anogenital sniffing         Not defined         STATE    214.033
# 35  anogenital sniffing         Not defined         STATE    227.133
# 36  anogenital sniffing         Not defined         STATE    228.533
# 37  anogenital sniffing         Not defined         STATE    305.100
# 38  anogenital sniffing         Not defined         STATE    380.300
# 39  anogenital sniffing         Not defined         STATE    381.732
# 40  anogenital sniffing         Not defined         STATE    429.067
# 41  anogenital sniffing         Not defined         STATE    446.667
# 42  anogenital sniffing         Not defined         STATE    467.333
# 43  anogenital sniffing         Not defined         STATE    556.833
# 44  anogenital sniffing         Not defined         STATE    583.367
# 45  anogenital sniffing                 NaN         STATE      9.905
# 46  anogenital sniffing                 NaN         STATE    102.655
# 47  anogenital sniffing                 NaN         STATE    418.153
# 48  anogenital sniffing                 NaN         STATE    461.653
# 49  anogenital sniffing                 NaN         STATE    541.933
# 50  anogenital sniffing         Not defined         STATE     19.100
# 51  anogenital sniffing         Not defined         STATE     19.900
# 52  anogenital sniffing         Not defined         STATE     66.033
# 53  anogenital sniffing         Not defined         STATE     73.467
# 54  anogenital sniffing         Not defined         STATE     76.033
# 55  anogenital sniffing         Not defined         STATE    111.300
# 56  anogenital sniffing         Not defined         STATE    158.733
# 57  anogenital sniffing         Not defined         STATE    184.100
# 58  anogenital sniffing         Not defined         STATE    210.100
# 59  anogenital sniffing         Not defined         STATE    295.533
# 60  anogenital sniffing         Not defined         STATE    298.000
# 61  anogenital sniffing         Not defined         STATE    426.333
# 62  anogenital sniffing         Not defined         STATE    459.400
# 63  anogenital sniffing         Not defined         STATE    523.433
# 64  anogenital sniffing                 NaN         STATE    199.155
# 65  anogenital sniffing                 NaN         STATE    202.155
# 66  anogenital sniffing                 NaN         STATE    310.467
# 67  anogenital sniffing                 NaN         STATE    324.600
# 68  anogenital sniffing                 NaN         STATE    330.100
# 69  anogenital sniffing                 NaN         STATE    333.233
# 70  anogenital sniffing                 NaN         STATE    518.302
# 71  anogenital sniffing                 NaN         STATE      7.333
# 72  anogenital sniffing                 NaN         STATE     13.333
# 73  anogenital sniffing                 NaN         STATE     30.400
# 74  anogenital sniffing                 NaN         STATE     68.600
# 75  anogenital sniffing                 NaN         STATE    235.267
# 76  anogenital sniffing                 NaN         STATE    242.333
# 77  anogenital sniffing                 NaN         STATE    301.867
#
#     Stop (s)  Duration (s)  \
# 0      9.448         0.586
# 1     85.552         5.242
# 2     91.862         1.172
# 3    265.276         4.414
# 4    597.759         0.242
# 5    346.300         0.233
# 6     92.717         7.495
# 7     19.000         0.300
# 8     36.467         0.867
# 9     45.067         0.267
# 10   180.267         4.134
# 11   187.567         2.100
# 12   204.400         0.667
# 13    87.654         1.752
# 14    93.904         1.751
# 15   231.156         2.250
# 16    81.533         0.533
# 17   177.733         0.533
# 18   516.133         1.466
# 19    26.667         0.067
# 20   234.700         0.533
# 21   238.433         2.866
# 22   432.567         2.400
# 23   452.733         2.933
# 24   528.700         4.367
# 25    35.132         3.365
# 26    37.067         0.467
# 27    70.933         1.033
# 28    75.333         1.733
# 29    77.433         0.300
# 30   104.066         3.599
# 31   171.166         2.266
# 32   172.699         0.732
# 33   191.700         1.267
# 34   214.666         0.633
# 35   227.932         0.799
# 36   232.132         3.599
# 37   305.532         0.432
# 38   381.366         1.066
# 39   381.966         0.234
# 40   429.233         0.166
# 41   448.000         1.333
# 42   467.867         0.534
# 43   557.666         0.833
# 44   583.700         0.333
# 45    12.905         3.000
# 46   104.155         1.500
# 47   419.153         1.000
# 48   469.400         7.747
# 49   542.400         0.467
# 50    19.866         0.766
# 51    21.099         1.199
# 52    68.000         1.967
# 53    74.467         1.000
# 54    78.433         2.400
# 55   112.133         0.833
# 56   158.900         0.167
# 57   186.300         2.200
# 58   210.400         0.300
# 59   295.567         0.034
# 60   298.500         0.500
# 61   426.767         0.434
# 62   462.233         2.833
# 63   525.233         1.800
# 64   200.656         1.501
# 65   203.655         1.500
# 66   310.700         0.233
# 67   325.367         0.767
# 68   331.633         1.533
# 69   333.867         0.634
# 70   521.555         3.253
# 71     7.733         0.400
# 72    14.200         0.867
# 73    30.533         0.133
# 74    69.000         0.400
# 75   236.000         0.733
# 76   245.600         3.267
# 77   302.000         0.133
#
#                                                                                             Media file name  \
# 0                      C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s3_6_p5_3_nRB3_20250621_125312.1.mp4
# 1                      C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s3_6_p5_3_nRB3_20250621_125312.1.mp4
# 2                      C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s3_6_p5_3_nRB3_20250621_125312.1.mp4
# 3                      C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s3_6_p5_3_nRB3_20250621_125312.1.mp4
# 4                      C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s3_6_p5_3_nRB3_20250621_125312.1.mp4
# 5                      C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_7_p5_2_nRB3_20250621_150707.1.mp4
# 6                                                                                                       NaN
# 7                      C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 8                      C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 9                      C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 10                     C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 11                     C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 12                     C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 13                                                                                                      NaN
# 14                                                                                                      NaN
# 15                                                                                                      NaN
# 16                                                                                                      NaN
# 17                                                                                                      NaN
# 18                                                                                                      NaN
# 19  E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 20  E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 21  E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 22  E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 23  E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 24  E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 25                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 26                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 27                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 28                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 29                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 30                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 31                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 32                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 33                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 34                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 35                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 36                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 37                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 38                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 39                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 40                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 41                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 42                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 43                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 44                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_7_p5_2_nRB3_20250621_152519.1.mp4
# 45                                                                                                      NaN
# 46                                                                                                      NaN
# 47                                                                                                      NaN
# 48                                                                                                      NaN
# 49                                                                                                      NaN
# 50                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 51                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 52                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 53                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 54                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 55                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 56                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 57                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 58                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 59                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 60                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 61                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 62                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 63                     C:/Users/thoma/Desktop/BorisVidsObservation/RI2_s4_8_p5_1_nRB3_20250621_171318.1.mp4
# 64                                                                                                      NaN
# 65                                                                                                      NaN
# 66                                                                                                      NaN
# 67                                                                                                      NaN
# 68                                                                                                      NaN
# 69                                                                                                      NaN
# 70                                                                                                      NaN
# 71                                                                                                      NaN
# 72                                                                                                      NaN
# 73                                                                                                      NaN
# 74                                                                                                      NaN
# 75                                                                                                      NaN
# 76                                                                                                      NaN
# 77                                                                                                      NaN
#
#     Image index start  Image index stop  Image file path start  \
# 0               257.0             274.0                    NaN
# 1              2329.0            2481.0                    NaN
# 2              2630.0            2664.0                    NaN
# 3              7565.0            7693.0                    NaN
# 4             17329.0           17336.0                    NaN
# 5             10383.0           10390.0                    NaN
# 6                 NaN               NaN                    NaN
# 7               561.0             570.0                    NaN
# 8              1068.0            1094.0                    NaN
# 9              1344.0            1352.0                    NaN
# 10             5284.0            5408.0                    NaN
# 11             5564.0            5627.0                    NaN
# 12             6112.0            6132.0                    NaN
# 13                NaN               NaN                    NaN
# 14                NaN               NaN                    NaN
# 15                NaN               NaN                    NaN
# 16                NaN               NaN                    NaN
# 17                NaN               NaN                    NaN
# 18                NaN               NaN                    NaN
# 19              798.0             800.0                    NaN
# 20             7025.0            7041.0                    NaN
# 21             7067.0            7153.0                    NaN
# 22            12906.0           12978.0                    NaN
# 23            13495.0           13583.0                    NaN
# 24            15731.0           15863.0                    NaN
# 25              953.0               NaN                    NaN
# 26             1098.0            1112.0                    NaN
# 27             2097.0            2128.0                    NaN
# 28             2208.0            2260.0                    NaN
# ...
# 55             3339.0            3364.0                    NaN
# 56             4762.0            4767.0                    NaN
# 57             5523.0            5589.0                    NaN
# 58             6303.0            6312.0                    NaN
# 59             8866.0            8867.0                    NaN
# 60             8940.0            8955.0                    NaN
# 61            12791.0           12804.0                    NaN
# 62            13783.0           13868.0                    NaN
# 63            15704.0           15758.0                    NaN
# 64                NaN               NaN                    NaN
# 65                NaN               NaN                    NaN
# 66                NaN               NaN                    NaN
# 67                NaN               NaN                    NaN
# 68                NaN               NaN                    NaN
# 69                NaN               NaN                    NaN
# 70                NaN               NaN                    NaN
# 71                NaN               NaN                    NaN
# 72                NaN               NaN                    NaN
# 73                NaN               NaN                    NaN
# 74                NaN               NaN                    NaN
# 75                NaN               NaN                    NaN
# 76                NaN               NaN                    NaN
# 77                NaN               NaN                    NaN
#
#     Image file path stop  Comment start  Comment stop    Trial Group  \
# 0                    NaN            NaN           NaN  RI1_3_6   RI1
# 1                    NaN            NaN           NaN  RI1_3_6   RI1
# 2                    NaN            NaN           NaN  RI1_3_6   RI1
# 3                    NaN            NaN           NaN  RI1_3_6   RI1
# 4                    NaN            NaN           NaN  RI1_3_6   RI1
# 5                    NaN            NaN           NaN  RI1_4_7   RI1
# 6                    NaN            NaN           NaN  RI1_2_3   RI1
# 7                    NaN            NaN           NaN  RI1_4_8   RI1
# 8                    NaN            NaN           NaN  RI1_4_8   RI1
# 9                    NaN            NaN           NaN  RI1_4_8   RI1
# 10                   NaN            NaN           NaN  RI1_4_8   RI1
# 11                   NaN            NaN           NaN  RI1_4_8   RI1
# 12                   NaN            NaN           NaN  RI1_4_8   RI1
# 13                   NaN            NaN           NaN  RI1_1_2   RI1
# 14                   NaN            NaN           NaN  RI1_1_2   RI1
# 15                   NaN            NaN           NaN  RI1_1_2   RI1
# 16                   NaN            NaN           NaN  RI1_2_4   RI1
# 17                   NaN            NaN           NaN  RI1_2_4   RI1
# 18                   NaN            NaN           NaN  RI1_2_4   RI1
# 19                   NaN            NaN           NaN  RI2_3_6   RI2
# 20                   NaN            NaN           NaN  RI2_3_6   RI2
# 21                   NaN            NaN           NaN  RI2_3_6   RI2
# 22                   NaN            NaN           NaN  RI2_3_6   RI2
# 23                   NaN            NaN           NaN  RI2_3_6   RI2
# 24                   NaN            NaN           NaN  RI2_3_6   RI2
# 25                   NaN            NaN           NaN  RI2_4_7   RI2
# 26                   NaN            NaN           NaN  RI2_4_7   RI2
# 27                   NaN            NaN           NaN  RI2_4_7   RI2
# 28                   NaN            NaN           NaN  RI2_4_7   RI2
# 29                   NaN            NaN           NaN  RI2_4_7   RI2
# 30                   NaN            NaN           NaN  RI2_4_7   RI2
# 31                   NaN            NaN           NaN  RI2_4_7   RI2
# 32                   NaN            NaN           NaN  RI2_4_7   RI2
# 33                   NaN            NaN           NaN  RI2_4_7   RI2
# 34                   NaN            NaN           NaN  RI2_4_7   RI2
# 35                   NaN            NaN           NaN  RI2_4_7   RI2
# 36                   NaN            NaN           NaN  RI2_4_7   RI2
# 37                   NaN            NaN           NaN  RI2_4_7   RI2
# 38                   NaN            NaN           NaN  RI2_4_7   RI2
# 39                   NaN            NaN           NaN  RI2_4_7   RI2
# 40                   NaN            NaN           NaN  RI2_4_7   RI2
# 41                   NaN            NaN           NaN  RI2_4_7   RI2
# 42                   NaN            NaN           NaN  RI2_4_7   RI2
# 43                   NaN            NaN           NaN  RI2_4_7   RI2
# 44                   NaN            NaN           NaN  RI2_4_7   RI2
# 45                   NaN            NaN           NaN  RI2_2_3   RI2
# 46                   NaN            NaN           NaN  RI2_2_3   RI2
# 47                   NaN            NaN           NaN  RI2_2_3   RI2
# 48                   NaN            NaN           NaN  RI2_2_3   RI2
# 49                   NaN            NaN           NaN  RI2_2_3   RI2
# 50                   NaN            NaN           NaN  RI2_4_8   RI2
# 51                   NaN            NaN           NaN  RI2_4_8   RI2
# 52                   NaN            NaN           NaN  RI2_4_8   RI2
# 53                   NaN            NaN           NaN  RI2_4_8   RI2
# 54                   NaN            NaN           NaN  RI2_4_8   RI2
# 55                   NaN            NaN           NaN  RI2_4_8   RI2
# 56                   NaN            NaN           NaN  RI2_4_8   RI2
# 57                   NaN            NaN           NaN  RI2_4_8   RI2
# 58                   NaN            NaN           NaN  RI2_4_8   RI2
# 59                   NaN            NaN           NaN  RI2_4_8   RI2
# 60                   NaN            NaN           NaN  RI2_4_8   RI2
# 61                   NaN            NaN           NaN  RI2_4_8   RI2
# 62                   NaN            NaN           NaN  RI2_4_8   RI2
# 63                   NaN            NaN           NaN  RI2_4_8   RI2
# 64                   NaN            NaN           NaN  RI2_1_2   RI2
# 65                   NaN            NaN           NaN  RI2_1_2   RI2
# 66                   NaN            NaN           NaN  RI2_1_2   RI2
# 67                   NaN            NaN           NaN  RI2_1_2   RI2
# 68                   NaN            NaN           NaN  RI2_1_2   RI2
# 69                   NaN            NaN           NaN  RI2_1_2   RI2
# 70                   NaN            NaN           NaN  RI2_1_2   RI2
# 71                   NaN            NaN           NaN  RI2_2_4   RI2
# 72                   NaN            NaN           NaN  RI2_2_4   RI2
# 73                   NaN            NaN           NaN  RI2_2_4   RI2
# 74                   NaN            NaN           NaN  RI2_2_4   RI2
# 75                   NaN            NaN           NaN  RI2_2_4   RI2
# 76                   NaN            NaN           NaN  RI2_2_4   RI2
# 77                   NaN            NaN           NaN  RI2_2_4   RI2
#
#                                                              Media file  \
# 0                                                                   NaN
# 1                                                                   NaN
# 2                                                                   NaN
# 3                                                                   NaN
# 4                                                                   NaN
# 5                                                                   NaN
# 6   /Users/ayushjain/Downloads/RI1_s2_3_p5_3_nRB3_20250622_104059.1.mov
# 7                                                                   NaN
# 8                                                                   NaN
# 9                                                                   NaN
# 10                                                                  NaN
# 11                                                                  NaN
# 12                                                                  NaN
# 13  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 14  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 15  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 16  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 17  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 18  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 19                                                                  NaN
# 20                                                                  NaN
# 21                                                                  NaN
# 22                                                                  NaN
# 23                                                                  NaN
# 24                                                                  NaN
# 25                                                                  NaN
# 26                                                                  NaN
# 27                                                                  NaN
# 28                                                                  NaN
# 29                                                                  NaN
# 30                                                                  NaN
# 31                                                                  NaN
# 32                                                                  NaN
# 33                                                                  NaN
# 34                                                                  NaN
# 35                                                                  NaN
# 36                                                                  NaN
# 37                                                                  NaN
# 38                                                                  NaN
# 39                                                                  NaN
# 40                                                                  NaN
# 41                                                                  NaN
# 42                                                                  NaN
# 43                                                                  NaN
# 44                                                                  NaN
# 45  /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 46  /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 47  /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 48  /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 49  /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 50                                                                  NaN
# 51                                                                  NaN
# 52                                                                  NaN
# 53                                                                  NaN
# 54                                                                  NaN
# 55                                                                  NaN
# 56                                                                  NaN
# 57                                                                  NaN
# 58                                                                  NaN
# 59                                                                  NaN
# 60                                                                  NaN
# 61                                                                  NaN
# 62                                                                  NaN
# 63                                                                  NaN
# 64  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 65  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 66  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 67  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 68  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 69  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 70  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 71  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 72  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 73  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 74  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 75  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 76  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 77  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
#
#     Total length   FPS  Modifiers
# 0            NaN   NaN        NaN
# 1            NaN   NaN        NaN
# 2            NaN   NaN        NaN
# 3            NaN   NaN        NaN
# 4            NaN   NaN        NaN
# 5            NaN   NaN        NaN
# 6         602.00  30.0        NaN
# 7            NaN   NaN        NaN
# 8            NaN   NaN        NaN
# 9            NaN   NaN        NaN
# 10           NaN   NaN        NaN
# 11           NaN   NaN        NaN
# 12           NaN   NaN        NaN
# 13        602.77  30.0        NaN
# 14        602.77  30.0        NaN
# 15        602.77  30.0        NaN
# 16        607.73  15.0        NaN
# 17        607.73  15.0        NaN
# 18        607.73  15.0        NaN
# 19           NaN   NaN        NaN
# 20           NaN   NaN        NaN
# 21           NaN   NaN        NaN
# 22           NaN   NaN        NaN
# 23           NaN   NaN        NaN
# 24           NaN   NaN        NaN
# 25           NaN   NaN        NaN
# 26           NaN   NaN        NaN
# 27           NaN   NaN        NaN
# 28           NaN   NaN        NaN
# 29           NaN   NaN        NaN
# 30           NaN   NaN        NaN
# 31           NaN   NaN        NaN
# 32           NaN   NaN        NaN
# 33           NaN   NaN        NaN
# 34           NaN   NaN        NaN
# 35           NaN   NaN        NaN
# 36           NaN   NaN        NaN
# 37           NaN   NaN        NaN
# 38           NaN   NaN        NaN
# 39           NaN   NaN        NaN
# 40           NaN   NaN        NaN
# 41           NaN   NaN        NaN
# 42           NaN   NaN        NaN
# 43           NaN   NaN        NaN
# 44           NaN   NaN        NaN
# 45        607.83  30.0        NaN
# 46        607.83  30.0        NaN
# 47        607.83  30.0        NaN
# 48        607.83  30.0        NaN
# 49        607.83  30.0        NaN
# 50           NaN   NaN        NaN
# 51           NaN   NaN        NaN
# 52           NaN   NaN        NaN
# 53           NaN   NaN        NaN
# 54           NaN   NaN        NaN
# 55           NaN   NaN        NaN
# 56           NaN   NaN        NaN
# 57           NaN   NaN        NaN
# 58           NaN   NaN        NaN
# 59           NaN   NaN        NaN
# 60           NaN   NaN        NaN
# 61           NaN   NaN        NaN
# 62           NaN   NaN        NaN
# 63           NaN   NaN        NaN
# 64        603.17  30.0        NaN
# 65        603.17  30.0        NaN
# 66        603.17  30.0        NaN
# 67        603.17  30.0        NaN
# 68        603.17  30.0        NaN
# 69        603.17  30.0        NaN
# 70        603.17  30.0        NaN
# 71        604.33  15.0        NaN
# 72        604.33  15.0        NaN
# 73        604.33  15.0        NaN
# 74        604.33  15.0        NaN
# 75        604.33  15.0        NaN
# 76        604.33  15.0        NaN
# 77        604.33  15.0        NaN

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

def calculate_percent_change_resp_subject_anogenital_sniff(signal, time, sniff_start, sampling_rate=100, plot=True,
                                                           baseline_color='gray', sniff_color='black', post_color='skyblue',
                                                           title=None):
    """
    Calculates respiration rate (Hz) changes before, during, and after a subject-initiated anogenital sniff.

    Windows:
    - Baseline (Pre): -5s to -1s before sniff
    - During Sniff:   0s to +0.5s after sniff start
    - Post Sniff:     +0.5s to +1.5s after sniff start

    Returns:
        pct_change_during (float): % change during sniff vs baseline
        pct_change_post (float): % change post sniff vs baseline
        baseline_rate (float), sniff_rate (float), post_rate (float)
    """

    # Time window masks
    baseline_mask = (time >= sniff_start - 5) & (time < sniff_start - 1)
    sniff_mask = (time >= sniff_start) & (time < sniff_start + 0.5)
    post_mask = (time >= sniff_start + 0.5) & (time < sniff_start + 1.5)

    # Segments
    baseline_segment = signal[baseline_mask]
    sniff_segment = signal[sniff_mask]
    post_segment = signal[post_mask]

    # Detect peaks (75ms min between breaths)
    min_distance_samples = int(0.0833 * sampling_rate)

    baseline_peaks, _ = find_peaks(baseline_segment, distance=min_distance_samples)
    sniff_peaks, _ = find_peaks(sniff_segment, distance=min_distance_samples)
    post_peaks, _ = find_peaks(post_segment, distance=min_distance_samples)

    # Convert indices to real times
    baseline_peak_times = time[baseline_mask][baseline_peaks]
    sniff_peak_times = time[sniff_mask][sniff_peaks]
    post_peak_times = time[post_mask][post_peaks]

    # Inter-breath intervals
    baseline_ibis = np.diff(baseline_peak_times)
    sniff_ibis = np.diff(sniff_peak_times)
    post_ibis = np.diff(post_peak_times)

    # Not enough data
    if len(baseline_ibis) == 0 or len(sniff_ibis) == 0 or len(post_ibis) == 0:
        if plot:
            print("⚠️ Not enough peaks to calculate respiration rate.")
        return None, None, None, None, None

    # Respiration rate (Hz)
    baseline_rate = np.mean(1 / baseline_ibis)
    sniff_rate = np.mean(1 / sniff_ibis)
    post_rate = np.mean(1 / post_ibis)

    # Percent change from baseline
    pct_change_during = ((sniff_rate - baseline_rate) / baseline_rate) * 100
    pct_change_post = ((post_rate - baseline_rate) / baseline_rate) * 100

    # Plotting
    if plot:
        plt.figure(figsize=(6, 5))
        plt.bar(
            ['Pre (−5 to −1s)', 'During (0 to +0.5s)', 'Post (+0.5 to +1.5s)'],
            [baseline_rate, sniff_rate, post_rate],
            color=[baseline_color, sniff_color, post_color]
        )
        plt.ylabel('Respiration Rate (Hz)')
        plt.title(title or f'Subject Anogenital Sniff\nΔDuring: {pct_change_during:.2f}%, ΔPost: {pct_change_post:.2f}%')
        plt.tight_layout()
        plt.show()

    return pct_change_during, pct_change_post, baseline_rate, sniff_rate, post_rate

# %%
results = []

for i, sniff_row in combined_subject_sniffs_df.iterrows():
    trial = sniff_row["Trial"]
    sniff_start = sniff_row["Start (s)"]

    # Get respiration data for this trial
    resp_entry = resp_data.get(trial, None)
    if resp_entry is None:
        print(f"Missing respiration data for {trial}, skipping...")
        continue

    signal = resp_entry["signal"]
    time = resp_entry["time"]
    sampling_rate = resp_entry["sampling_rate"]

    # Run updated function with pre, during, post windows
    pct_change_during, pct_change_post, baseline_rate, sniff_rate, post_rate = calculate_percent_change_resp_subject_anogenital_sniff(
        signal, time, sniff_start, sampling_rate=sampling_rate, plot=False
    )

    # Skip if not enough peaks detected
    if pct_change_during is None:
        print(f"Not enough peaks detected for sniff at {sniff_start}s in trial {trial}, skipping...")
        continue

    # Store results
    results.append({
        "Trial": trial,
        "Sniff Start": sniff_start,
        "Percent Change During": pct_change_during,
        "Percent Change Post": pct_change_post,
        "Baseline Rate": baseline_rate,
        "During Sniff Rate": sniff_rate,
        "Post-sniff Rate": post_rate
    })

# Convert to DataFrame
results_df = pd.DataFrame(results)
print(results_df.head())
# Out:
#      Trial  Sniff Start  Percent Change During  Percent Change Post  \
# 0  RI1_3_6       14.483              -4.520752             4.213009
# 1  RI1_3_6       19.069              -5.581489            -0.547382
# 2  RI1_3_6       21.379              -3.083647            -6.829774
# 3  RI1_3_6       25.034             -18.009811            -1.953399
# 4  RI1_3_6       28.862              -4.431935            -2.509589
#
#    Baseline Rate  During Sniff Rate  Post-sniff Rate
# 0      10.424992           9.953704        10.864198
# 1      10.885342          10.277778        10.825758
# 2      10.748100          10.416667        10.014029
# 3      10.295815           8.441558        10.094697
# 4      10.217126           9.764310         9.960718

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define custom color palette
custom_palette = {
    'Positive': (83/255, 161/255, 169/255),  # RI1
    'Negative': (169/255, 83/255, 118/255)   # RI2
}

# Add Valence column based on trial name
results_df['Valence'] = results_df['Trial'].apply(
    lambda x: 'Positive' if 'RI1' in x else ('Negative' if 'RI2' in x else 'Unknown')
)
results_df = results_df[results_df['Valence'] != 'Unknown']

# Melt dataframe for seaborn plotting
plot_df = results_df.melt(
    id_vars=["Trial", "Sniff Start", "Valence"],
    value_vars=["Baseline Rate", "During Sniff Rate", "Post-sniff Rate"],
    var_name="Condition",
    value_name="Respiration Rate (Hz)"
)

# Rename condition levels for nicer x-axis labels
plot_df["Condition"] = plot_df["Condition"].replace({
    "Baseline Rate": "Pre-sniff (−5 to −1 s)",
    "During Sniff Rate": "During Sniff (0 to +0.5 s)",
    "Post-sniff Rate": "Post-sniff (+0.5 to +1.5 s)"
})

# Plotting
plt.figure(figsize=(16, 7))
sns.set_context("talk")

# Boxplot
sns.boxplot(
    x="Condition",
    y="Respiration Rate (Hz)",
    hue="Valence",
    data=plot_df,
    palette=custom_palette,
    fliersize=0
)

# Overlay swarmplot for individual data points
sns.swarmplot(
    x="Condition",
    y="Respiration Rate (Hz)",
    hue="Valence",
    data=plot_df,
    dodge=True,
    color='black',
    edgecolor='black',
    alpha=1,
    size=7,
    marker='o',
    linewidth=0.8,
    legend=False  # avoid duplicate legend
)

# Legend and labels, positioned bottom left to avoid overlap
plt.legend(title='Valence', fontsize=20, title_fontsize=22, loc='lower left', bbox_to_anchor=(0, 0))
plt.title("Respiration Rate: Subject-Initiated Anogenital Sniff", fontsize=26, weight='bold')
plt.ylabel("Respiration Rate (Hz)", fontsize=22, weight='bold')
plt.xlabel('')
plt.xticks(fontsize=20, weight='bold')
plt.yticks(ticks=[4, 6, 8, 10, 12],fontsize=20, weight='bold')
plt.ylim(2.5, 13)

plt.legend(title='Valence', fontsize=16, title_fontsize=16, loc='lower left', bbox_to_anchor=(0, 0))
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sjs93\AppData\Local\Temp\ipykernel_18884\770720665.py:46: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.swarmplot(
