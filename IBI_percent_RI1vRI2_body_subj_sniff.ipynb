# %% [markdown]
# libaraies

# %%
import os
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt, resample_poly
import neurokit2 as nk
from scipy.signal import find_peaks
import seaborn as sns
from scipy.stats import wilcoxon

# Pandas display settings (optional)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 0)

# %% [markdown]
# load files

# %%
# RESP FILE PATHS
RI1_3_6_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s3_6_p5_3_nRB3_20250621_125312_merged.h5"
RI2_3_6_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s3_6_p5_3_nRB3_20250621_131158_merged.h5"
BLRI_s3_6_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\BLRI_s3_6_p5_3_nRB3_20250621_123634_merged.h5"
BLRI_s4_7_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\BLRI_s4_7_p5_2_nRB3_20250621_144806_merged.h5"
RI1_4_7_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s4_7_p5_2_nRB3_20250621_150707_merged.h5"
RI2_4_7_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s4_7_p5_2_nRB3_20250621_152519_merged.h5"
RI1_2_3_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s2_3_p5_3_nRB3_20250622_104059_merged (1).h5"
RI2_2_3_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s2_3_p5_3_nRB3_20250622_110216_merged.h5"
RI1_4_8_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s4_8_p5_1_nRB3_20250621_165214_merged.h5"
RI2_4_8_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s4_8_p5_1_nRB3_20250621_171318_merged.h5"
RI1_1_1_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s1_1_p5_2_nRB6_20250622_143958_merged.h5"
RI2_1_1_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s1_1_p5_2_nRB6_20250622_150457_merged.h5"
RI1_1_2_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s1_2_p5_1_nRB6_20250622_170742_merged.h5"
RI2_1_2_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s1_2_p5_1_nRB6_20250622_173049_merged.h5"
RI1_2_4_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s2_4_p5_4_nRB3_20250622_123424_merged.h5"
RI2_2_4_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s2_4_p5_4_nRB3_20250622_125648_merged.h5"
RI2_3_5_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI2_s3_5_p5_4_nRB3_20250621_112618_merged.h5"
RI1_3_5_h5_path = r"E:\Aim1\AIM1\Day1_new\resp_h5\RI1_s3_5_p5_4_nRB3_20250621_105014_merged.h5"


# BORIS CSVs (no comma at the end or it makes a tuple)
RI1_3_6_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s3_6_p5_3_nRB3_HEEPS.csv")
RI2_3_6_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s3_6_p_5_3_nRB3_2025062.csv")
RI1_4_7_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s4_7_p5_2_nRB3_HEEPS.csv")
RI2_4_7_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s4_7_p5_2_nRB3_HEEPS.csv")
RI1_2_3_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s2_3_p5_3_nRB3_20250622_104059.1.csv")
RI2_2_3_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s2_3_p5_3_nRB3_20250622_1102116.1.csv")
RI1_4_8_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s4_8_p5_1_nRB3_HEEPS.csv")
RI2_4_8_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s4_8_p5_1_nRB3_20250621_HEEPS.csv")
RI1_1_1_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s1_1_p5_2_nRB6_20250622_143958.1.csv")
RI2_1_1_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s1_1_p5_2_nRB6_20250622_150457.1.csv")
RI1_1_2_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s1_2_p5_1_nRB6_20250622_170742.1.csv")
RI2_1_2_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s1_2_p5_1_nRB6_20250622_173049.1.csv")
RI1_2_4_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI1_s2_4_p5_4_nRB3_20250622_123424.1.csv")
RI2_2_4_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s2_4_p5_4_nRB3_20250622_125648.1.csv")
RI2_3_5_boris = pd.read_csv(r"E:\Aim1\AIM1\Day1_new\boris\RI2_s3_5_p5_4_nRB3_20250621.csv")

# %%
ri1_h5_paths = {
    "RI1_3_6": RI1_3_6_h5_path,
    "RI1_4_7": RI1_4_7_h5_path,  
    "RI1_2_3": RI1_2_3_h5_path,
    "RI1_4_8": RI1_4_8_h5_path,
    "RI1_1_1": RI1_1_1_h5_path,
    "RI1_1_2": RI1_1_2_h5_path,
    "RI1_2_4": RI1_2_4_h5_path,
    "RI1_3_5": RI1_3_5_h5_path,
}

# %%
ri2_h5_paths = {
    "RI2_3_6": RI2_3_6_h5_path,
    "RI2_4_7": RI2_4_7_h5_path,
    "RI2_2_3": RI2_2_3_h5_path,
    "RI2_4_8": RI2_4_8_h5_path,
    "RI2_1_1": RI2_1_1_h5_path,
    "RI2_1_2": RI2_1_2_h5_path,
    "RI2_2_4": RI2_2_4_h5_path,
    "RI2_3_5": RI2_3_5_h5_path,
}

# %%
ri1_boris_data = {
    "RI1_3_6": RI1_3_6_boris.copy(),
    "RI1_4_7": RI1_4_7_boris.copy(),
    "RI1_2_3": RI1_2_3_boris.copy(),
    "RI1_4_8": RI1_4_8_boris.copy(),
    "RI1_1_1": RI1_1_1_boris.copy(),
    "RI1_1_2": RI1_1_2_boris.copy(),
    "RI1_2_4": RI1_2_4_boris.copy(),
}

# %%
ri2_boris_data = {
    "RI2_3_6": RI2_3_6_boris.copy(),
    "RI2_4_7": RI2_4_7_boris.copy(),
    "RI2_2_3": RI2_2_3_boris.copy(),
    "RI2_4_8": RI2_4_8_boris.copy(),
    "RI2_1_1": RI2_1_1_boris.copy(),
    "RI2_1_2": RI2_1_2_boris.copy(),
    "RI2_2_4": RI2_2_4_boris.copy(),
    "RI2_3_5": RI2_3_5_boris.copy(),
}

# %% [markdown]
# load_clean_resp_signal function for loading and preprocessing respiration data:
#
# Reads raw resp signal and metadata from .h5
#
# Computes original sampling rate (fs)
#
# Applies a low-pass filter before downsampling to avoid aliasing
#
# Downsamples the signal to your target_rate (default 100 Hz)
#
# Applies a bandpass filter (0.1–20 Hz) with NeuroKit to clean the signal further
#
# Creates a time vector that matches the cleaned signal length and sampling rate
#
# This function returns:
# rsp_cleaned: the cleaned, filtered, downsampled respiratory signal array
#
# time_vector: time points corresponding to each sample in seconds
#
# target_rate: the sampling rate after downsampling (e.g., 100 Hz)
#
# You can then pass these outputs to functions like:
# get_percent_change_resp_rate(signal=rsp_cleaned, times=time_vector, sniff_start, sniff_end)
#
# get_delta_resp_rate(signal=rsp_cleaned, times=time_vector, sniff_end)

# %%
def load_clean_resp_signal(h5_file, target_rate=100):
    """
    Loads, filters, downsamples respiration from .h5, returns cleaned signal and time vector.
    """
    try:
        with h5py.File(h5_file, 'r') as f:
            resp = f['resp'][:].flatten()
            ekg_meta = dict(f['ekg_metadata'].attrs)
        duration_sec = ekg_meta['duration_sec']
        fs = len(resp) / duration_sec
    except Exception as e:
        print(f"Error loading {h5_file}: {e}")
        return None, None, None

    # Pre-filter before downsampling
    nyquist = fs / 2
    norm_cutoff = (target_rate / 2) / nyquist
    b, a = butter(N=4, Wn=norm_cutoff, btype='low')
    filtered_resp = filtfilt(b, a, resp)

    # Downsample
    downsample_factor = int(fs // target_rate)
    downsampled = resample_poly(filtered_resp, up=1, down=downsample_factor)

    # Bandpass filter with neurokit
    rsp_cleaned = nk.signal_filter(
        downsampled,
        lowcut=0.1,
        highcut=20,
        method="butterworth",
        sampling_rate=target_rate,
        order=2
    )

    # Generate matching time vector
    time_vector = np.arange(len(rsp_cleaned)) / target_rate

    return rsp_cleaned, time_vector, target_rate

# %%
h5_paths = {
    "RI1_3_6": RI1_3_6_h5_path,
    "RI2_3_6": RI2_3_6_h5_path,
    "RI1_4_7": RI1_4_7_h5_path,
    "RI2_4_7": RI2_4_7_h5_path,
    "RI1_2_3": RI1_2_3_h5_path,
    "RI2_2_3": RI2_2_3_h5_path,
    "RI1_4_8": RI1_4_8_h5_path,
    "RI2_4_8": RI2_4_8_h5_path,
    "RI1_1_1": RI1_1_1_h5_path,
    "RI2_1_1": RI2_1_1_h5_path,
    "RI1_1_2": RI1_1_2_h5_path,
    "RI2_1_2": RI2_1_2_h5_path,
    "RI1_2_4": RI1_2_4_h5_path,
    "RI2_2_4": RI2_2_4_h5_path,
    "RI1_3_5": RI1_3_5_h5_path,
    "RI2_3_5": RI2_3_5_h5_path,
}

# %%
resp_data = {}

for label, path in h5_paths.items():
    print(f"Processing {label}...")
    signal, time, rate = load_clean_resp_signal(path)
    
    if signal is not None:
        resp_data[label] = {
            "signal": signal,
            "time": time,
            "sampling_rate": rate
        }
    else:
        print(f"Skipping {label}: failed to load.")

print("✅ All available signals loaded.")
# Out:
# Processing RI1_3_6...
# Processing RI2_3_6...
# Processing RI1_4_7...
# Processing RI2_4_7...
# Processing RI1_2_3...
# Processing RI2_2_3...
# Processing RI1_4_8...
# Processing RI2_4_8...
# Processing RI1_1_1...
# Processing RI2_1_1...
# Processing RI1_1_2...
# Processing RI2_1_2...
# Processing RI1_2_4...
# Processing RI2_2_4...
# Processing RI1_3_5...
# Processing RI2_3_5...
# ✅ All available signals loaded.

# %%
def extract_subject_body_sniffs(df):
    """
    Filters BORIS dataframe for body sniffing initiated by the subject.
    """
    df = df.copy()
    df['Start (s)'] = df['Start (s)'].astype(float)
    df['Stop (s)'] = df['Stop (s)'].astype(float)
    df = df.sort_values(by='Start (s)').reset_index(drop=True)

    # Filter for body sniffing by the subject
    subject_mask = df['Subject'].str.lower() == 'subject'
    sniff_mask = df['Behavior'].str.lower() == 'body sniffing'

    return df[subject_mask & sniff_mask]

# %% [markdown]
# ONE SUBJECT 3.6 WORKED

# %%
subject_body_sniffs = extract_subject_body_sniffs(RI2_3_6_boris)

print("\n🔍 Subject-Initiated Body Sniffs (RI2_3_6):")
print(subject_body_sniffs[['Subject', 'Behavior', 'Start (s)', 'Stop (s)']])
# Out:
# 🔍 Subject-Initiated Body Sniffs (RI2_3_6):
#     Subject       Behavior  Start (s)  Stop (s)
# 3   subject  body sniffing      8.700     9.367
# 4   subject  body sniffing     10.300    11.167
# 8   subject  body sniffing     21.067    21.200
# 10  subject  body sniffing     22.367    22.967
# 18  subject  body sniffing     34.833    40.633
# 19  subject  body sniffing     41.300    42.000
# 22  subject  body sniffing     50.900    52.167

# %% [markdown]
# RUN LOOP ON ALL SUBJECTS WORKS

# %%
all_subject_body_sniffs = []

# Process RI1 group
for label, boris_df in ri1_boris_data.items():
    sniffs = extract_subject_body_sniffs(boris_df)
    sniffs["Trial"] = label
    sniffs["Group"] = "RI1"
    all_subject_body_sniffs.append(sniffs)

# Process RI2 group
for label, boris_df in ri2_boris_data.items():
    sniffs = extract_subject_body_sniffs(boris_df)
    sniffs["Trial"] = label
    sniffs["Group"] = "RI2"
    all_subject_body_sniffs.append(sniffs)

# Combine into one DataFrame
combined_subject_body_sniffs_df = pd.concat(all_subject_body_sniffs, ignore_index=True)

# %%
combined_subject_body_sniffs_df
# Out:
#                            Observation id         Observation date  \
# 0                      RI1_s3_6_p5_3_nRB3  2025-06-28 22:13:15.619
# 1                      RI1_s3_6_p5_3_nRB3  2025-06-28 22:13:15.619
# 2                      RI1_s3_6_p5_3_nRB3  2025-06-28 22:13:15.619
# 3                      RI1_s3_6_p5_3_nRB3  2025-06-28 22:13:15.619
# 4                      RI1_s4_7_p5_2_nRB3  2025-06-29 10:29:43.592
# 5                      RI1_s4_7_p5_2_nRB3  2025-06-29 10:29:43.592
# 6                      RI1_s4_7_p5_2_nRB3  2025-06-29 10:29:43.592
# 7                      RI1_s4_7_p5_2_nRB3  2025-06-29 10:29:43.592
# 8                      RI1_s4_7_p5_2_nRB3  2025-06-29 10:29:43.592
# 9                      RI1_s4_7_p5_2_nRB3  2025-06-29 10:29:43.592
# 10                     RI1_s4_7_p5_2_nRB3  2025-06-29 10:29:43.592
# 11   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 12   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 13   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 14   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 15   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 16   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 17   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 18   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 19   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 20   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 21   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 22   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 23   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 24   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 25   RI1_s2_3_p5_3_nRB3_20250622_104059.1      2025-07-01 16:32:15
# 26                     RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 27                     RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 28                     RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 29                     RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 30                     RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 31                     RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 32                     RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 33                     RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 34                     RI1_s4_8_p5_1_nRB3  2025-07-02 21:32:00.524
# 35   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 36   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 37   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 38   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 39   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 40   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 41   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 42   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 43   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 44   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 45   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 46   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 47   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 48   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 49   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 50   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 51   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 52   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 53   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 54   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 55   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 56   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 57   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 58   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 59   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 60   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 61   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 62   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 63   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 64   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 65   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 66   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 67   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 68   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 69   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 70   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 71   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 72   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 73   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 74   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 75   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 76   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 77   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 78   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 79   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 80   RI1_s1_1_p5_2_nRB6_20250622_143958.1      2025-07-03 10:47:38
# 81   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 82   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 83   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 84   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 85   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 86   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 87   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 88   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 89   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 90   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 91   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 92   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 93   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 94   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 95   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 96   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 97   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 98   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 99   RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 100  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 101  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 102  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 103  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 104  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 105  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 106  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 107  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 108  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 109  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 110  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 111  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 112  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 113  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 114  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 115  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 116  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 117  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 118  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 119  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 120  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 121  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 122  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 123  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 124  RI1_s1_2_p5_1_nRB6_20250622_170742.1      2025-07-02 23:25:38
# 125  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 126  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 127  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 128  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 129  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 130  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 131  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 132  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 133  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 134  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 135  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 136  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 137  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 138  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 139  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 140  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 141  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 142  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 143  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 144  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 145  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 146  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 147  RI1_s2_4_p5_4_nRB3_20250622_123424.1      2025-07-03 16:17:44
# 148                   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 149                   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 150                   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 151                   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 152                   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 153                   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 154                   RI2_s3_6_p_5_3_nRB3  2025-06-29 12:05:18.871
# 155  RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 156  RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 157  RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 158  RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 159  RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 160  RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 161  RI2_s2_3_p5_3_nRB3_20250622_110216.1      2025-07-02 21:52:32
# 162  RI2_s1_1_p5_2_nRB6_20250622_150457.1      2025-07-03 14:09:47
# 163  RI2_s1_1_p5_2_nRB6_20250622_150457.1      2025-07-03 14:09:47
# 164  RI2_s1_2_p5_1_nRB6_20250622_173049.1      2025-07-03 10:03:55
# 165  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 166  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
# 167  RI2_s2_4_p5_4_nRB3_20250622_125648.1      2025-07-04 01:24:23
#
#      Description Observation type  \
# 0            NaN       Media file
# 1            NaN       Media file
# 2            NaN       Media file
# 3            NaN       Media file
# 4            NaN       Media file
# 5            NaN       Media file
# 6            NaN       Media file
# 7            NaN       Media file
# 8            NaN       Media file
# 9            NaN       Media file
# 10           NaN       Media file
# 11           NaN              NaN
# 12           NaN              NaN
# 13           NaN              NaN
# 14           NaN              NaN
# 15           NaN              NaN
# 16           NaN              NaN
# 17           NaN              NaN
# 18           NaN              NaN
# 19           NaN              NaN
# 20           NaN              NaN
# 21           NaN              NaN
# 22           NaN              NaN
# 23           NaN              NaN
# 24           NaN              NaN
# 25           NaN              NaN
# 26           NaN       Media file
# 27           NaN       Media file
# 28           NaN       Media file
# 29           NaN       Media file
# 30           NaN       Media file
# 31           NaN       Media file
# 32           NaN       Media file
# 33           NaN       Media file
# 34           NaN       Media file
# 35           NaN              NaN
# 36           NaN              NaN
# 37           NaN              NaN
# 38           NaN              NaN
# 39           NaN              NaN
# 40           NaN              NaN
# 41           NaN              NaN
# 42           NaN              NaN
# 43           NaN              NaN
# 44           NaN              NaN
# 45           NaN              NaN
# 46           NaN              NaN
# 47           NaN              NaN
# 48           NaN              NaN
# 49           NaN              NaN
# 50           NaN              NaN
# 51           NaN              NaN
# 52           NaN              NaN
# 53           NaN              NaN
# 54           NaN              NaN
# 55           NaN              NaN
# 56           NaN              NaN
# 57           NaN              NaN
# 58           NaN              NaN
# 59           NaN              NaN
# 60           NaN              NaN
# 61           NaN              NaN
# 62           NaN              NaN
# 63           NaN              NaN
# 64           NaN              NaN
# 65           NaN              NaN
# 66           NaN              NaN
# 67           NaN              NaN
# 68           NaN              NaN
# 69           NaN              NaN
# 70           NaN              NaN
# 71           NaN              NaN
# 72           NaN              NaN
# 73           NaN              NaN
# 74           NaN              NaN
# 75           NaN              NaN
# 76           NaN              NaN
# 77           NaN              NaN
# 78           NaN              NaN
# 79           NaN              NaN
# 80           NaN              NaN
# 81           NaN              NaN
# 82           NaN              NaN
# 83           NaN              NaN
# 84           NaN              NaN
# 85           NaN              NaN
# 86           NaN              NaN
# 87           NaN              NaN
# 88           NaN              NaN
# 89           NaN              NaN
# 90           NaN              NaN
# 91           NaN              NaN
# 92           NaN              NaN
# 93           NaN              NaN
# 94           NaN              NaN
# 95           NaN              NaN
# 96           NaN              NaN
# 97           NaN              NaN
# 98           NaN              NaN
# 99           NaN              NaN
# 100          NaN              NaN
# 101          NaN              NaN
# 102          NaN              NaN
# 103          NaN              NaN
# 104          NaN              NaN
# 105          NaN              NaN
# 106          NaN              NaN
# 107          NaN              NaN
# 108          NaN              NaN
# 109          NaN              NaN
# 110          NaN              NaN
# 111          NaN              NaN
# 112          NaN              NaN
# 113          NaN              NaN
# 114          NaN              NaN
# 115          NaN              NaN
# 116          NaN              NaN
# 117          NaN              NaN
# 118          NaN              NaN
# 119          NaN              NaN
# 120          NaN              NaN
# 121          NaN              NaN
# 122          NaN              NaN
# 123          NaN              NaN
# 124          NaN              NaN
# 125          NaN              NaN
# 126          NaN              NaN
# 127          NaN              NaN
# 128          NaN              NaN
# 129          NaN              NaN
# 130          NaN              NaN
# 131          NaN              NaN
# 132          NaN              NaN
# 133          NaN              NaN
# 134          NaN              NaN
# 135          NaN              NaN
# 136          NaN              NaN
# 137          NaN              NaN
# 138          NaN              NaN
# 139          NaN              NaN
# 140          NaN              NaN
# 141          NaN              NaN
# 142          NaN              NaN
# 143          NaN              NaN
# 144          NaN              NaN
# 145          NaN              NaN
# 146          NaN              NaN
# 147          NaN              NaN
# 148          NaN       Media file
# 149          NaN       Media file
# 150          NaN       Media file
# 151          NaN       Media file
# 152          NaN       Media file
# 153          NaN       Media file
# 154          NaN       Media file
# 155          NaN              NaN
# 156          NaN              NaN
# 157          NaN              NaN
# 158          NaN              NaN
# 159          NaN              NaN
# 160          NaN              NaN
# 161          NaN              NaN
# 162          NaN              NaN
# 163          NaN              NaN
# 164          NaN              NaN
# 165          NaN              NaN
# 166          NaN              NaN
# 167          NaN              NaN
#
#                                                                                                                 Source  \
# 0                       player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s3_6_p5_3_nRB3_20250621_125312.1.mp4
# 1                       player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s3_6_p5_3_nRB3_20250621_125312.1.mp4
# 2                       player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s3_6_p5_3_nRB3_20250621_125312.1.mp4
# 3                       player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s3_6_p5_3_nRB3_20250621_125312.1.mp4
# 4                       player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_7_p5_2_nRB3_20250621_150707.1.mp4
# 5                       player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_7_p5_2_nRB3_20250621_150707.1.mp4
# 6                       player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_7_p5_2_nRB3_20250621_150707.1.mp4
# 7                       player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_7_p5_2_nRB3_20250621_150707.1.mp4
# 8                       player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_7_p5_2_nRB3_20250621_150707.1.mp4
# 9                       player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_7_p5_2_nRB3_20250621_150707.1.mp4
# 10                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_7_p5_2_nRB3_20250621_150707.1.mp4
# 11                                                                                                                 NaN
# 12                                                                                                                 NaN
# 13                                                                                                                 NaN
# 14                                                                                                                 NaN
# 15                                                                                                                 NaN
# 16                                                                                                                 NaN
# 17                                                                                                                 NaN
# 18                                                                                                                 NaN
# 19                                                                                                                 NaN
# 20                                                                                                                 NaN
# 21                                                                                                                 NaN
# 22                                                                                                                 NaN
# 23                                                                                                                 NaN
# 24                                                                                                                 NaN
# 25                                                                                                                 NaN
# 26                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 27                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 28                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 29                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 30                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 31                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 32                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 33                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 34                      player #1:C:/Users/thoma/Desktop/BorisVidsObservation/RI1_s4_8_p5_1_nRB3_20250621_165214.1.mp4
# 35                                                                                                                 NaN
# 36                                                                                                                 NaN
# 37                                                                                                                 NaN
# 38                                                                                                                 NaN
# 39                                                                                                                 NaN
# 40                                                                                                                 NaN
# 41                                                                                                                 NaN
# 42                                                                                                                 NaN
# 43                                                                                                                 NaN
# 44                                                                                                                 NaN
# 45                                                                                                                 NaN
# 46                                                                                                                 NaN
# 47                                                                                                                 NaN
# 48                                                                                                                 NaN
# 49                                                                                                                 NaN
# 50                                                                                                                 NaN
# 51                                                                                                                 NaN
# 52                                                                                                                 NaN
# 53                                                                                                                 NaN
# 54                                                                                                                 NaN
# 55                                                                                                                 NaN
# 56                                                                                                                 NaN
# 57                                                                                                                 NaN
# 58                                                                                                                 NaN
# 59                                                                                                                 NaN
# 60                                                                                                                 NaN
# 61                                                                                                                 NaN
# 62                                                                                                                 NaN
# 63                                                                                                                 NaN
# 64                                                                                                                 NaN
# 65                                                                                                                 NaN
# 66                                                                                                                 NaN
# 67                                                                                                                 NaN
# 68                                                                                                                 NaN
# 69                                                                                                                 NaN
# 70                                                                                                                 NaN
# 71                                                                                                                 NaN
# 72                                                                                                                 NaN
# 73                                                                                                                 NaN
# 74                                                                                                                 NaN
# 75                                                                                                                 NaN
# 76                                                                                                                 NaN
# 77                                                                                                                 NaN
# 78                                                                                                                 NaN
# 79                                                                                                                 NaN
# 80                                                                                                                 NaN
# 81                                                                                                                 NaN
# 82                                                                                                                 NaN
# 83                                                                                                                 NaN
# 84                                                                                                                 NaN
# 85                                                                                                                 NaN
# 86                                                                                                                 NaN
# 87                                                                                                                 NaN
# 88                                                                                                                 NaN
# 89                                                                                                                 NaN
# 90                                                                                                                 NaN
# 91                                                                                                                 NaN
# 92                                                                                                                 NaN
# 93                                                                                                                 NaN
# 94                                                                                                                 NaN
# 95                                                                                                                 NaN
# 96                                                                                                                 NaN
# 97                                                                                                                 NaN
# 98                                                                                                                 NaN
# 99                                                                                                                 NaN
# 100                                                                                                                NaN
# 101                                                                                                                NaN
# 102                                                                                                                NaN
# 103                                                                                                                NaN
# 104                                                                                                                NaN
# 105                                                                                                                NaN
# 106                                                                                                                NaN
# 107                                                                                                                NaN
# 108                                                                                                                NaN
# 109                                                                                                                NaN
# 110                                                                                                                NaN
# 111                                                                                                                NaN
# 112                                                                                                                NaN
# 113                                                                                                                NaN
# 114                                                                                                                NaN
# 115                                                                                                                NaN
# 116                                                                                                                NaN
# 117                                                                                                                NaN
# 118                                                                                                                NaN
# 119                                                                                                                NaN
# 120                                                                                                                NaN
# 121                                                                                                                NaN
# 122                                                                                                                NaN
# 123                                                                                                                NaN
# 124                                                                                                                NaN
# 125                                                                                                                NaN
# 126                                                                                                                NaN
# 127                                                                                                                NaN
# 128                                                                                                                NaN
# 129                                                                                                                NaN
# 130                                                                                                                NaN
# 131                                                                                                                NaN
# 132                                                                                                                NaN
# 133                                                                                                                NaN
# 134                                                                                                                NaN
# 135                                                                                                                NaN
# 136                                                                                                                NaN
# 137                                                                                                                NaN
# 138                                                                                                                NaN
# 139                                                                                                                NaN
# 140                                                                                                                NaN
# 141                                                                                                                NaN
# 142                                                                                                                NaN
# 143                                                                                                                NaN
# 144                                                                                                                NaN
# 145                                                                                                                NaN
# 146                                                                                                                NaN
# 147                                                                                                                NaN
# 148  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 149  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 150  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 151  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 152  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 153  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 154  player #1:E:/Aim1/AIM1/Day1_new/RI2_s3_6_p_5_3_nRB3_20250621_131158.rec/RI2_s3_6_p_5_3_nRB3_20250621_131158.1.mp4
# 155                                                                                                                NaN
# 156                                                                                                                NaN
# 157                                                                                                                NaN
# 158                                                                                                                NaN
# 159                                                                                                                NaN
# 160                                                                                                                NaN
# 161                                                                                                                NaN
# 162                                                                                                                NaN
# 163                                                                                                                NaN
# 164                                                                                                                NaN
# 165                                                                                                                NaN
# 166                                                                                                                NaN
# 167                                                                                                                NaN
#
#      Time offset (s)  Coding duration  Media duration (s)  FPS (frame/s)  \
# 0                0.0          589.517             622.862           29.0
# 1                0.0          589.517             622.862           29.0
# 2                0.0          589.517             622.862           29.0
# 3                0.0          589.517             622.862           29.0
# 4                0.0          505.966             627.800           30.0
# 5                0.0          505.966             627.800           30.0
# 6                0.0          505.966             627.800           30.0
# 7                0.0          505.966             627.800           30.0
# 8                0.0          505.966             627.800           30.0
# 9                0.0          505.966             627.800           30.0
# 10               0.0          505.966             627.800           30.0
# 11               NaN              NaN                 NaN            NaN
# 12               NaN              NaN                 NaN            NaN
# 13               NaN              NaN                 NaN            NaN
# 14               NaN              NaN                 NaN            NaN
# 15               NaN              NaN                 NaN            NaN
# 16               NaN              NaN                 NaN            NaN
# 17               NaN              NaN                 NaN            NaN
# 18               NaN              NaN                 NaN            NaN
# 19               NaN              NaN                 NaN            NaN
# 20               NaN              NaN                 NaN            NaN
# 21               NaN              NaN                 NaN            NaN
# 22               NaN              NaN                 NaN            NaN
# 23               NaN              NaN                 NaN            NaN
# 24               NaN              NaN                 NaN            NaN
# 25               NaN              NaN                 NaN            NaN
# 26               0.0          526.234             603.200           30.0
# 27               0.0          526.234             603.200           30.0
# 28               0.0          526.234             603.200           30.0
# 29               0.0          526.234             603.200           30.0
# 30               0.0          526.234             603.200           30.0
# 31               0.0          526.234             603.200           30.0
# 32               0.0          526.234             603.200           30.0
# 33               0.0          526.234             603.200           30.0
# 34               0.0          526.234             603.200           30.0
# 35               NaN              NaN                 NaN            NaN
# 36               NaN              NaN                 NaN            NaN
# 37               NaN              NaN                 NaN            NaN
# 38               NaN              NaN                 NaN            NaN
# 39               NaN              NaN                 NaN            NaN
# 40               NaN              NaN                 NaN            NaN
# 41               NaN              NaN                 NaN            NaN
# 42               NaN              NaN                 NaN            NaN
# 43               NaN              NaN                 NaN            NaN
# 44               NaN              NaN                 NaN            NaN
# 45               NaN              NaN                 NaN            NaN
# 46               NaN              NaN                 NaN            NaN
# 47               NaN              NaN                 NaN            NaN
# 48               NaN              NaN                 NaN            NaN
# 49               NaN              NaN                 NaN            NaN
# 50               NaN              NaN                 NaN            NaN
# 51               NaN              NaN                 NaN            NaN
# 52               NaN              NaN                 NaN            NaN
# 53               NaN              NaN                 NaN            NaN
# 54               NaN              NaN                 NaN            NaN
# 55               NaN              NaN                 NaN            NaN
# 56               NaN              NaN                 NaN            NaN
# 57               NaN              NaN                 NaN            NaN
# 58               NaN              NaN                 NaN            NaN
# 59               NaN              NaN                 NaN            NaN
# 60               NaN              NaN                 NaN            NaN
# 61               NaN              NaN                 NaN            NaN
# 62               NaN              NaN                 NaN            NaN
# 63               NaN              NaN                 NaN            NaN
# 64               NaN              NaN                 NaN            NaN
# 65               NaN              NaN                 NaN            NaN
# 66               NaN              NaN                 NaN            NaN
# 67               NaN              NaN                 NaN            NaN
# 68               NaN              NaN                 NaN            NaN
# 69               NaN              NaN                 NaN            NaN
# 70               NaN              NaN                 NaN            NaN
# 71               NaN              NaN                 NaN            NaN
# 72               NaN              NaN                 NaN            NaN
# 73               NaN              NaN                 NaN            NaN
# 74               NaN              NaN                 NaN            NaN
# 75               NaN              NaN                 NaN            NaN
# 76               NaN              NaN                 NaN            NaN
# 77               NaN              NaN                 NaN            NaN
# 78               NaN              NaN                 NaN            NaN
# 79               NaN              NaN                 NaN            NaN
# 80               NaN              NaN                 NaN            NaN
# 81               NaN              NaN                 NaN            NaN
# 82               NaN              NaN                 NaN            NaN
# 83               NaN              NaN                 NaN            NaN
# 84               NaN              NaN                 NaN            NaN
# 85               NaN              NaN                 NaN            NaN
# 86               NaN              NaN                 NaN            NaN
# 87               NaN              NaN                 NaN            NaN
# 88               NaN              NaN                 NaN            NaN
# 89               NaN              NaN                 NaN            NaN
# 90               NaN              NaN                 NaN            NaN
# 91               NaN              NaN                 NaN            NaN
# 92               NaN              NaN                 NaN            NaN
# 93               NaN              NaN                 NaN            NaN
# 94               NaN              NaN                 NaN            NaN
# 95               NaN              NaN                 NaN            NaN
# 96               NaN              NaN                 NaN            NaN
# 97               NaN              NaN                 NaN            NaN
# 98               NaN              NaN                 NaN            NaN
# 99               NaN              NaN                 NaN            NaN
# 100              NaN              NaN                 NaN            NaN
# 101              NaN              NaN                 NaN            NaN
# 102              NaN              NaN                 NaN            NaN
# 103              NaN              NaN                 NaN            NaN
# 104              NaN              NaN                 NaN            NaN
# 105              NaN              NaN                 NaN            NaN
# 106              NaN              NaN                 NaN            NaN
# 107              NaN              NaN                 NaN            NaN
# 108              NaN              NaN                 NaN            NaN
# 109              NaN              NaN                 NaN            NaN
# 110              NaN              NaN                 NaN            NaN
# 111              NaN              NaN                 NaN            NaN
# 112              NaN              NaN                 NaN            NaN
# 113              NaN              NaN                 NaN            NaN
# 114              NaN              NaN                 NaN            NaN
# 115              NaN              NaN                 NaN            NaN
# 116              NaN              NaN                 NaN            NaN
# 117              NaN              NaN                 NaN            NaN
# 118              NaN              NaN                 NaN            NaN
# 119              NaN              NaN                 NaN            NaN
# 120              NaN              NaN                 NaN            NaN
# ...
# 40   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 41   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 42   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 43   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 44   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 45   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 46   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 47   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 48   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 49   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 50   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 51   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 52   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 53   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 54   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 55   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 56   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 57   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 58   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 59   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 60   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 61   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 62   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 63   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 64   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 65   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 66   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 67   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 68   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 69   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 70   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 71   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 72   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 73   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 74   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 75   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 76   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 77   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 78   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 79   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 80   /Users/ayushjain/Downloads/RI1_s1_1_p5_2_nRB6_20250622_143958.1.mov
# 81   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 82   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 83   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 84   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 85   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 86   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 87   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 88   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 89   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 90   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 91   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 92   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 93   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 94   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 95   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 96   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 97   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 98   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 99   /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 100  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 101  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 102  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 103  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 104  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 105  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 106  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 107  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 108  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 109  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 110  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 111  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 112  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 113  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 114  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 115  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 116  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 117  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 118  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 119  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 120  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 121  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 122  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 123  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 124  /Users/ayushjain/Downloads/RI1_s1_2_p5_1_nRB6_20250622_170742.1.mov
# 125  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 126  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 127  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 128  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 129  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 130  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 131  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 132  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 133  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 134  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 135  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 136  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 137  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 138  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 139  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 140  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 141  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 142  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 143  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 144  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 145  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 146  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 147  /Users/ayushjain/Downloads/RI1_s2_4_p5_4_nRB3_20250622_123424.1.mov
# 148                                                                  NaN
# 149                                                                  NaN
# 150                                                                  NaN
# 151                                                                  NaN
# 152                                                                  NaN
# 153                                                                  NaN
# 154                                                                  NaN
# 155  /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 156  /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 157  /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 158  /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 159  /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 160  /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 161  /Users/ayushjain/Downloads/RI2_s2_3_p5_3_nRB3_20250622_110216.1.mov
# 162  /Users/ayushjain/Downloads/RI2_s1_1_p5_2_nRB6_20250622_150457.1.mov
# 163  /Users/ayushjain/Downloads/RI2_s1_1_p5_2_nRB6_20250622_150457.1.mov
# 164  /Users/ayushjain/Downloads/RI2_s1_2_p5_1_nRB6_20250622_173049.1.mov
# 165  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 166  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
# 167  /Users/ayushjain/Downloads/RI2_s2_4_p5_4_nRB3_20250622_125648.1.mov
#
#      Total length   FPS  Modifiers
# 0             NaN   NaN        NaN
# 1             NaN   NaN        NaN
# 2             NaN   NaN        NaN
# 3             NaN   NaN        NaN
# 4             NaN   NaN        NaN
# 5             NaN   NaN        NaN
# 6             NaN   NaN        NaN
# 7             NaN   NaN        NaN
# 8             NaN   NaN        NaN
# 9             NaN   NaN        NaN
# 10            NaN   NaN        NaN
# 11         602.00  30.0        NaN
# 12         602.00  30.0        NaN
# 13         602.00  30.0        NaN
# 14         602.00  30.0        NaN
# 15         602.00  30.0        NaN
# 16         602.00  30.0        NaN
# 17         602.00  30.0        NaN
# 18         602.00  30.0        NaN
# 19         602.00  30.0        NaN
# 20         602.00  30.0        NaN
# 21         602.00  30.0        NaN
# 22         602.00  30.0        NaN
# 23         602.00  30.0        NaN
# 24         602.00  30.0        NaN
# 25         602.00  30.0        NaN
# 26            NaN   NaN        NaN
# 27            NaN   NaN        NaN
# 28            NaN   NaN        NaN
# 29            NaN   NaN        NaN
# 30            NaN   NaN        NaN
# 31            NaN   NaN        NaN
# 32            NaN   NaN        NaN
# 33            NaN   NaN        NaN
# 34            NaN   NaN        NaN
# 35         715.39  13.0        NaN
# 36         715.39  13.0        NaN
# 37         715.39  13.0        NaN
# 38         715.39  13.0        NaN
# 39         715.39  13.0        NaN
# 40         715.39  13.0        NaN
# 41         715.39  13.0        NaN
# 42         715.39  13.0        NaN
# 43         715.39  13.0        NaN
# 44         715.39  13.0        NaN
# 45         715.39  13.0        NaN
# 46         715.39  13.0        NaN
# 47         715.39  13.0        NaN
# 48         715.39  13.0        NaN
# 49         715.39  13.0        NaN
# 50         715.39  13.0        NaN
# 51         715.39  13.0        NaN
# 52         715.39  13.0        NaN
# 53         715.39  13.0        NaN
# 54         715.39  13.0        NaN
# 55         715.39  13.0        NaN
# 56         715.39  13.0        NaN
# 57         715.39  13.0        NaN
# 58         715.39  13.0        NaN
# 59         715.39  13.0        NaN
# 60         715.39  13.0        NaN
# 61         715.39  13.0        NaN
# 62         715.39  13.0        NaN
# 63         715.39  13.0        NaN
# 64         715.39  13.0        NaN
# 65         715.39  13.0        NaN
# 66         715.39  13.0        NaN
# 67         715.39  13.0        NaN
# 68         715.39  13.0        NaN
# 69         715.39  13.0        NaN
# 70         715.39  13.0        NaN
# 71         715.39  13.0        NaN
# 72         715.39  13.0        NaN
# 73         715.39  13.0        NaN
# 74         715.39  13.0        NaN
# 75         715.39  13.0        NaN
# 76         715.39  13.0        NaN
# 77         715.39  13.0        NaN
# 78         715.39  13.0        NaN
# 79         715.39  13.0        NaN
# 80         715.39  13.0        NaN
# 81         602.77  30.0        NaN
# 82         602.77  30.0        NaN
# 83         602.77  30.0        NaN
# 84         602.77  30.0        NaN
# 85         602.77  30.0        NaN
# 86         602.77  30.0        NaN
# 87         602.77  30.0        NaN
# 88         602.77  30.0        NaN
# 89         602.77  30.0        NaN
# 90         602.77  30.0        NaN
# 91         602.77  30.0        NaN
# 92         602.77  30.0        NaN
# 93         602.77  30.0        NaN
# 94         602.77  30.0        NaN
# 95         602.77  30.0        NaN
# 96         602.77  30.0        NaN
# 97         602.77  30.0        NaN
# 98         602.77  30.0        NaN
# 99         602.77  30.0        NaN
# 100        602.77  30.0        NaN
# 101        602.77  30.0        NaN
# 102        602.77  30.0        NaN
# 103        602.77  30.0        NaN
# 104        602.77  30.0        NaN
# 105        602.77  30.0        NaN
# 106        602.77  30.0        NaN
# 107        602.77  30.0        NaN
# 108        602.77  30.0        NaN
# 109        602.77  30.0        NaN
# 110        602.77  30.0        NaN
# 111        602.77  30.0        NaN
# 112        602.77  30.0        NaN
# 113        602.77  30.0        NaN
# 114        602.77  30.0        NaN
# 115        602.77  30.0        NaN
# 116        602.77  30.0        NaN
# 117        602.77  30.0        NaN
# 118        602.77  30.0        NaN
# 119        602.77  30.0        NaN
# 120        602.77  30.0        NaN
# 121        602.77  30.0        NaN
# 122        602.77  30.0        NaN
# 123        602.77  30.0        NaN
# 124        602.77  30.0        NaN
# 125        607.73  15.0        NaN
# 126        607.73  15.0        NaN
# 127        607.73  15.0        NaN
# 128        607.73  15.0        NaN
# 129        607.73  15.0        NaN
# 130        607.73  15.0        NaN
# 131        607.73  15.0        NaN
# 132        607.73  15.0        NaN
# 133        607.73  15.0        NaN
# 134        607.73  15.0        NaN
# 135        607.73  15.0        NaN
# 136        607.73  15.0        NaN
# 137        607.73  15.0        NaN
# 138        607.73  15.0        NaN
# 139        607.73  15.0        NaN
# 140        607.73  15.0        NaN
# 141        607.73  15.0        NaN
# 142        607.73  15.0        NaN
# 143        607.73  15.0        NaN
# 144        607.73  15.0        NaN
# 145        607.73  15.0        NaN
# 146        607.73  15.0        NaN
# 147        607.73  15.0        NaN
# 148           NaN   NaN        NaN
# 149           NaN   NaN        NaN
# 150           NaN   NaN        NaN
# 151           NaN   NaN        NaN
# 152           NaN   NaN        NaN
# 153           NaN   NaN        NaN
# 154           NaN   NaN        NaN
# 155        607.83  30.0        NaN
# 156        607.83  30.0        NaN
# 157        607.83  30.0        NaN
# 158        607.83  30.0        NaN
# 159        607.83  30.0        NaN
# 160        607.83  30.0        NaN
# 161        607.83  30.0        NaN
# 162        603.53  15.0        NaN
# 163        603.53  15.0        NaN
# 164        603.17  30.0        NaN
# 165        604.33  15.0        NaN
# 166        604.33  15.0        NaN
# 167        604.33  15.0        NaN

# %%
def calculate_subject_body_sniff_resp_change(signal, time, sniff_start, sampling_rate=100, plot=True,
                                             baseline_color='gray', sniff_color='black', title=None):
    """
    Calculates % change in respiration rate (Hz) around a subject-initiated body sniff.

    Time Windows:
    - Baseline:    -5s to -1s before sniff_start (4 sec)
    - Sniff period: 0s to +0.5s after sniff_start (0.5 sec)

    Args:
        signal (np.array): respiration signal array
        time (np.array): corresponding time array
        sniff_start (float): timestamp of subject sniff onset (in seconds)
        sampling_rate (int): sampling rate of the signal (Hz)
        plot (bool): whether to show bar plot
        baseline_color (str): color of baseline bar
        sniff_color (str): color of sniff window bar
        title (str): optional custom plot title

    Returns:
        percent_change (float): % increase from baseline to sniff
        baseline_mean_rate (float): mean baseline respiration rate (Hz)
        sniff_mean_rate (float): mean rate during sniff (Hz)
    """
    # Define time masks
    baseline_mask = (time >= sniff_start - 5) & (time < sniff_start - 1)
    sniff_mask = (time >= sniff_start) & (time < sniff_start + 0.5)

    baseline_segment = signal[baseline_mask]
    sniff_segment = signal[sniff_mask]

    # Require a minimum spacing of 75ms between breaths
    min_distance_samples = int(0.0833 * sampling_rate)

    # Detect peaks in each segment
    baseline_peaks, _ = find_peaks(baseline_segment, distance=min_distance_samples)
    sniff_peaks, _ = find_peaks(sniff_segment, distance=min_distance_samples)

    # Convert peak indices to actual times
    baseline_peak_times = time[baseline_mask][baseline_peaks]
    sniff_peak_times = time[sniff_mask][sniff_peaks]

    # Calculate instantaneous breathing rates
    baseline_ibis = np.diff(baseline_peak_times)
    sniff_ibis = np.diff(sniff_peak_times)

    # Fail case: too few peaks
    if len(baseline_ibis) == 0 or len(sniff_ibis) == 0:
        if plot:
            print("⚠️ Not enough peaks detected in one or both windows.")
        return None, None, None

    # Convert IBIs to Hz
    baseline_rates = 1 / baseline_ibis
    sniff_rates = 1 / sniff_ibis

    # Mean respiration rates
    baseline_mean_rate = np.mean(baseline_rates)
    sniff_mean_rate = np.mean(sniff_rates)

    # Percent change from baseline to sniff
    percent_change = ((sniff_mean_rate - baseline_mean_rate) / baseline_mean_rate) * 100

    if plot:
        plt.figure(figsize=(5, 4))
        plt.bar(['Baseline', 'Subject Body Sniff'], 
                [baseline_mean_rate, sniff_mean_rate],
                color=[baseline_color, sniff_color])
        plt.ylabel('Respiration Rate (Hz)')
        if title:
            plt.title(title)
        else:
            plt.title(f'Subject Body Sniff Resp Change\n% Increase: {percent_change:.2f}%')
        plt.tight_layout()
        plt.show()

    return percent_change, baseline_mean_rate, sniff_mean_rate

# %%
subject_body_sniff_results = []

for i, sniff_row in combined_subject_body_sniffs_df.iterrows():
    trial = sniff_row["Trial"]
    sniff_start = sniff_row["Start (s)"]

    # Look up respiration data
    resp_entry = resp_data.get(trial, None)
    if resp_entry is None:
        print(f"⚠️ Missing respiration data for {trial}, skipping...")
        continue

    signal = resp_entry["signal"]
    time = resp_entry["time"]
    sampling_rate = resp_entry["sampling_rate"]

    # Calculate % change in respiration rate during body sniff
    percent_change, baseline_rate, sniff_rate = calculate_subject_body_sniff_resp_change(
        signal, time, sniff_start, sampling_rate=sampling_rate, plot=False
    )

    if percent_change is None:
        print(f"⚠️ Not enough peaks at {sniff_start}s in {trial}, skipping...")
        continue

    subject_body_sniff_results.append({
        "Trial": trial,
        "Sniff Start": sniff_start,
        "Percent Change": percent_change,
        "Baseline Rate": baseline_rate,
        "Sniff Rate": sniff_rate
    })

# Create DataFrame of results
subject_body_sniff_df = pd.DataFrame(subject_body_sniff_results)
print(subject_body_sniff_df.head())
# Out:
#      Trial  Sniff Start  Percent Change  Baseline Rate  Sniff Rate
# 0  RI1_3_6       13.276       -2.669301       9.538808    9.284188
# 1  RI1_3_6       27.793       -2.751738      10.334894   10.050505
# 2  RI1_3_6       29.862       -0.860710       9.946724    9.861111
# 3  RI1_3_6       53.897       30.148401       8.590621   11.180556
# 4  RI1_4_7       23.533       -7.038996      10.829638   10.067340

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define color palette
custom_palette = {
    'Positive': (83/255, 161/255, 169/255),  # RI1
    'Negative': (169/255, 83/255, 118/255)   # RI2
}

# Assign valence labels based on Trial
subject_body_sniff_df['Valence'] = subject_body_sniff_df['Trial'].apply(
    lambda x: 'Positive' if 'RI1' in x else ('Negative' if 'RI2' in x else 'Unknown')
)
subject_body_sniff_df = subject_body_sniff_df[subject_body_sniff_df['Valence'] != 'Unknown']

# Melt for plotting
plot_df = subject_body_sniff_df.melt(
    id_vars=["Trial", "Sniff Start", "Valence"],
    value_vars=["Baseline Rate", "Sniff Rate"],
    var_name="Condition",
    value_name="Respiration Rate (Hz)"
)

# Rename conditions for clarity
plot_df["Condition"] = plot_df["Condition"].replace({
    "Baseline Rate": "Pre-sniff (−4 to 0 s)",
    "Sniff Rate": "During sniff"
})

# Plotting
plt.figure(figsize=(15, 7))
sns.set_context("talk")

# Boxplot
sns.boxplot(
    x="Condition",
    y="Respiration Rate (Hz)",
    hue="Valence",
    data=plot_df,
    palette=custom_palette,
    fliersize=0
)

# Swarmplot (individual points)
sns.swarmplot(
    x="Condition",
    y="Respiration Rate (Hz)",
    hue="Valence",
    data=plot_df,
    dodge=True,
    color='black',
    edgecolor='black',
    alpha=1,
    size=7,
    marker='o',
    linewidth=0.8,
    legend=False
)

# Labels and formatting
plt.title("Respiration Rate Before and During Subject-Initiated Body Sniff", fontsize=26, weight='bold')
plt.ylabel("Respiration Rate (Hz)", fontsize=24, weight='bold')
plt.xlabel('', fontsize=22)
plt.xticks(fontsize=20, weight='bold')
plt.yticks(fontsize=20, weight='bold')
plt.legend(title='Valence', fontsize=20, title_fontsize=22, loc='lower left', bbox_to_anchor=(0, 0))
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sjs93\AppData\Local\Temp\ipykernel_57268\4074568182.py:45: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.swarmplot(

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define color palette
custom_palette = {
    'Positive': (83/255, 161/255, 169/255),  # RI1
    'Negative': (169/255, 83/255, 118/255)   # RI2
}

# Assign valence labels based on Trial
subject_body_sniff_df['Valence'] = subject_body_sniff_df['Trial'].apply(
    lambda x: 'Positive' if 'RI1' in x else ('Negative' if 'RI2' in x else 'Unknown')
)
subject_body_sniff_df = subject_body_sniff_df[subject_body_sniff_df['Valence'] != 'Unknown']

# Melt for plotting
plot_df = subject_body_sniff_df.melt(
    id_vars=["Trial", "Sniff Start", "Valence"],
    value_vars=["Baseline Rate", "Sniff Rate"],
    var_name="Condition",
    value_name="Respiration Rate (Hz)"
)

# Rename conditions for clarity
plot_df["Condition"] = plot_df["Condition"].replace({
    "Baseline Rate": "Pre-sniff (−4 to 0 s)",
    "Sniff Rate": "During sniff"
})

# Plotting
plt.figure(figsize=(15, 7))
sns.set_context("talk")

# Boxplot
sns.boxplot(
    x="Condition",
    y="Respiration Rate (Hz)",
    hue="Valence",
    data=plot_df,
    palette=custom_palette,
    fliersize=0
)

# Swarmplot (individual points)
sns.swarmplot(
    x="Condition",
    y="Respiration Rate (Hz)",
    hue="Valence",
    data=plot_df,
    dodge=True,
    color='black',
    edgecolor='black',
    alpha=1,
    size=7,
    marker='o',
    linewidth=0.8,
    legend=False
)

# Labels and formatting
plt.title("Respiration Rate Before and During Subject-Initiated Body Sniff", fontsize=26, weight='bold')
plt.ylabel("Respiration Rate (Hz)", fontsize=24, weight='bold')
plt.xlabel('', fontsize=22)
plt.xticks(fontsize=20, weight='bold')
plt.yticks(fontsize=20, weight='bold')

# Legend bottom right
plt.legend(title='Valence', fontsize=20, title_fontsize=22, loc='lower right', bbox_to_anchor=(1, 0))

plt.tight_layout()
plt.show()
# Out:
# C:\Users\sjs93\AppData\Local\Temp\ipykernel_57268\678101202.py:45: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
#   sns.swarmplot(
